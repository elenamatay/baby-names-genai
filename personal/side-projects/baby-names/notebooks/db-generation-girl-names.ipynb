# %% [markdown]
# # Baby Names - Girl Names DB Creation
#
# This notebook aims to create the girls/female names dataset for the project TheName 👶🏽✨, using Gemini.
#
# ## Setup
#
# ### Installation
#
# The necessary dependencies in the `requirements.txt` file (in the parent folder of this notebook). You should install them. It's recommended to use a virtual environment to manage dependencies.
#
# ### Imports

# %%
import sys, os
import pandas as pd
import json

# Add the root directory to the Python path
sys.path.append(os.path.abspath(os.path.join('..')))

from utils import * # Helper Functions
# Out:
# /Users/elenamatay/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ### Environment variables
#
# **⚠️ Important Note ⚠️:** To run this notebook, you will need to place environment variables such as the project ID and region in the `utils.py` file. This file is located in the parent folder of this notebook.

# %% [markdown]
# ### Helper functions
#
# Helper functions can be found in the `utils.py` file. A summary of all functions used in this notebook can be found here:
#
# - `generate_names_info_async` - Async function to be able to process Gemini calls in parallel. This is needed for the names' synthetic data generation: we'll have input lists of 16 names each to avoid hitting output context window limit. Each of this calls will produce the initial JSONs version with exhaustive info on each name. We will be using Gemini-Flash-002 (experimented better results than 001, especially in returning valid JSON data).
#
# - `process_all_lists` goes through each of the sublists in the huge list of girl names, and processes each list using `generate_names_info_async`
#
# - `process_remaining_girl_remaining_names` - As I'm having a quota of 100 requests to Gemini per minute and girl names need 400+ lists, I needed to run `generate_names_info_async` various (4-5) times. In order not to process the same list twice, I defined this function which outputs the lists that have NOT been generated yet. This function uses the `get_created_names` and `filter_remaining_girl_names` helper functions.
#
# - `clean_json_files` - Takes each JSON in a folder (with this folder containing the output JSONs of `process_all_lists`) and cleans them.
#
# - `merge_json_files_by_letter` - Takes all JSONs in a directory starting with the same letter (e.g. "G", from girl) and merges them into one master JSON (`G_master_initial.json`, which will be further enhanced and cleansed -that's why we say "_initial"-).
#
# - `add_attributes_field` - Enriches each name from a master JSON with attributes based on certain keywords defined (e.g. if a name's meaning, family_meaning and/or other_info contain the word "God", the name will be given the attribute "religious").
#
# - `remove_duplicates_from_json` - Removes duplicates in `likely liked`, `famous` other elements in the master JSON file. Uses `remove_duplicates` function to recursively remove duplicates while preserving order.
#
# - `load_json_and_find_names` - Goes through the master JSON and detect names that are not of the desired gender, based on keywords. E.g. in the girls case, it will look for the words `boy`, `man` and `masculine`, and if the name's meaning or other info contains these, it will put the name into a list. Later we'll check which of these names are girl or gender-neutral names, with another call to Gemini, to leave these.
#
# - `upload_to_gcs` - Uploads a local file to Google Cloud Storage, allowing us to rename the file in the process.

# %% [markdown]
# ## Produce source data
#
# We'll start from [this Kaggle dataset](https://kaggle.com/datasets/ryanburnsworth/popular-names-by-birth-year-1880-2022/data). I downloaded it in CSV format. We'll only be using names with > 1,000 occurrences.

# %%
# Load the CSV, filter for girl names with a count higher than 1000
df = pd.read_csv("../data/raw/gender_name.csv", usecols=["Name", "Gender", "Count"])
filtered_df = df.query("Gender == 'F' and Count > 1000")

# Select only the "Name" column and convert it to a list
all_girl_names_list = filtered_df["Name"].dropna().tolist()
all_girl_names_list.sort()

print(all_girl_names_list)
# Out:
# ['Aadhya', 'Aadya', 'Aaleyah', 'Aaliya', 'Aaliyah', 'Aaniyah', 'Aanya', 'Aaralyn', 'Aarna', 'Aaron', 'Aarya', 'Aaryn', 'Abagail', 'Abbe', 'Abbey', 'Abbi', 'Abbie', 'Abbigail', 'Abbigale', 'Abbigayle', 'Abby', 'Abbygail', 'Abigael', 'Abigail', 'Abigale', 'Abigayle', 'Abilene', 'Abriana', 'Abrianna', 'Abriella', 'Abrielle', 'Abril', 'Abygail', 'Acacia', 'Ada', 'Adah', 'Adair', 'Adalee', 'Adaleigh', 'Adalia', 'Adalie', 'Adalina', 'Adaline', 'Adalyn', 'Adalynn', 'Adam', 'Adamari', 'Adamaris', 'Adara', 'Addalyn', 'Addalynn', 'Addelyn', 'Addie', 'Addilyn', 'Addilynn', 'Addisen', 'Addison', 'Addisyn', 'Addy', 'Addysen', 'Addyson', 'Adel', 'Adela', 'Adelaida', 'Adelaide', 'Adele', 'Adelene', 'Adelia', 'Adelina', 'Adeline', 'Adelita', 'Adell', 'Adella', 'Adelle', 'Adelyn', 'Adelynn', 'Adena', 'Adia', 'Adilene', 'Adilyn', 'Adilynn', 'Adina', 'Adison', 'Adisyn', 'Aditi', 'Adley', 'Adline', 'Adora', 'Adreanna', 'Adria', 'Adrian', 'Adriana', 'Adriane', 'Adrianna', 'Adrianne', 'Adrien', 'Adriene', 'Adrienne', 'Adrina', 'Adyson', 'Aerial', 'Aeris', 'Aeryn', 'Africa', 'Afton', 'Agatha', 'Aggie', 'Agnes', 'Agustina', 'Ahna', 'Ahsley', 'Ahtziri', 'Ahuva', 'Aida', 'Aidan', 'Aide', 'Aiden', 'Aiesha', 'Aiko', 'Aila', 'Ailani', 'Aileen', 'Ailene', 'Aili', 'Ailyn', 'Aime', 'Aimee', 'Aine', 'Ainslee', 'Ainsley', 'Aisha', 'Aishah', 'Aislin', 'Aisling', 'Aislinn', 'Aislyn', 'Aislynn', 'Aitana', 'Aixa', 'Aiyana', 'Aiyanna', 'Aiza', 'Aja', 'Ajah', 'Akasha', 'Akayla', 'Akeelah', 'Akia', 'Akilah', 'Akira', 'Akshara', 'Alaa', 'Alaia', 'Alaina', 'Alaine', 'Alan', 'Alana', 'Alanah', 'Alane', 'Alani', 'Alanis', 'Alanna', 'Alannah', 'Alasia', 'Alaura', 'Alaya', 'Alayah', 'Alayla', 'Alayna', 'Alayne', 'Alaysha', 'Alaysia', 'Alba', 'Albert', 'Alberta', 'Albertha', 'Albertina', 'Albertine', 'Albina', 'Alda', 'Alea', 'Aleah', 'Alean', 'Alease', 'Aleasha', 'Alecia', 'Aleda', 'Aleeah', 'Aleen', 'Aleena', 'Aleesha', 'Aleeya', 'Aleeyah', 'Aleeza', 'Aleia', 'Aleida', 'Aleigha', 'Aleisha', 'Alejandra', 'Alejandrina', 'Aleksandra', 'Alena', 'Alene', 'Alesha', 'Aleshia', 'Alesia', 'Alessa', 'Alessandra', 'Alessia', 'Aleta', 'Aletha', 'Alethea', 'Alethia', 'Alex', 'Alexa', 'Alexander', 'Alexandra', 'Alexandrea', 'Alexandria', 'Alexcia', 'Alexi', 'Alexia', 'Alexie', 'Alexis', 'Alexius', 'Alexsandra', 'Alexsis', 'Alexus', 'Alexxis', 'Alexys', 'Alexzandra', 'Alexzandria', 'Aleya', 'Aleyah', 'Aleyda', 'Aleyna', 'Alfred', 'Alfreda', 'Alfredia', 'Ali', 'Alia', 'Aliah', 'Aliana', 'Alianna', 'Alica', 'Alice', 'Alicea', 'Alicen', 'Alicia', 'Alida', 'Alijah', 'Alina', 'Aline', 'Alisa', 'Alise', 'Alisha', 'Alishia', 'Alisia', 'Alison', 'Alissa', 'Alisson', 'Alita', 'Alivia', 'Alix', 'Alixandra', 'Aliya', 'Aliyah', 'Aliyana', 'Aliza', 'Alizabeth', 'Alize', 'Alla', 'Allana', 'Allean', 'Allee', 'Allegra', 'Allen', 'Allena', 'Allene', 'Alli', 'Allie', 'Alline', 'Allisa', 'Allison', 'Allissa', 'Allisson', 'Alliyah', 'Ally', 'Allyn', 'Allysa', 'Allyson', 'Allyssa', 'Alma', 'Almeda', 'Almeta', 'Almira', 'Alona', 'Alondra', 'Alonna', 'Alora', 'Alpha', 'Alta', 'Altha', 'Althea', 'Alva', 'Alvena', 'Alvera', 'Alverta', 'Alvin', 'Alvina', 'Aly', 'Alya', 'Alyah', 'Alyana', 'Alyanna', 'Alyce', 'Alycia', 'Alyna', 'Alys', 'Alysa', 'Alyse', 'Alysha', 'Alyshia', 'Alysia', 'Alyson', 'Alyssa', 'Alysse', 'Alyssia', 'Alysson', 'Alyvia', 'Alyx', 'Alyza', 'Amada', 'Amaia', 'Amairani', 'Amairany', 'Amaiya', 'Amal', 'Amalia', 'Amalie', 'Amanda', 'Amani', 'Amara', 'Amarah', 'Amari', 'Amaria', 'Amariah', 'Amarie', 'Amaris', 'Amaryllis', 'Amaya', 'Amayah', 'Ambar', 'Amber', 'Amberlee', 'Amberly', 'Amberlyn', 'Amberlynn', 'Ambria', 'Ambrosia', 'Amee', 'Ameena', 'Ameera', 'Ameerah', 'Amelia', 'Amelie', 'America', 'Amerie', 'Amethyst', 'Ami', 'Amia', 'Amiah', 'Amie', 'Amiee', 'Amilia', 'Amina', 'Aminah', 'Aminata', 'Amira', 'Amiracle', 'Amirah', 'Amity', 'Amiya', 'Amiyah', 'Ammie', 'Ammy', 'Amna', 'Amoni', 'Amor', 'Amora', 'Amparo', 'Amrita', 'Amy', 'Amya', 'Amyah', 'Amyra', 'An', 'Ana', 'Anabel', 'Anabell', 'Anabel ...

# %% [markdown]
# Then producing 16-names length lists so that the input (output from call 1) fits into Gemini's input context window later.

# %%
# Split the list into 16 equal parts
chunk_size = 16
all_girl_names_list = [all_girl_names_list[i:i+chunk_size] for i in range(0, len(all_girl_names_list), chunk_size)]

print(all_girl_names_list)
print("Lists number (of 16 names each):",len(all_girl_names_list), ", so total girl names = ", len(all_girl_names_list*chunk_size))
# Out:
# [['Aadhya', 'Aadya', 'Aaleyah', 'Aaliya', 'Aaliyah', 'Aaniyah', 'Aanya', 'Aaralyn', 'Aarna', 'Aaron', 'Aarya', 'Aaryn', 'Abagail', 'Abbe', 'Abbey', 'Abbi'], ['Abbie', 'Abbigail', 'Abbigale', 'Abbigayle', 'Abby', 'Abbygail', 'Abigael', 'Abigail', 'Abigale', 'Abigayle', 'Abilene', 'Abriana', 'Abrianna', 'Abriella', 'Abrielle', 'Abril'], ['Abygail', 'Acacia', 'Ada', 'Adah', 'Adair', 'Adalee', 'Adaleigh', 'Adalia', 'Adalie', 'Adalina', 'Adaline', 'Adalyn', 'Adalynn', 'Adam', 'Adamari', 'Adamaris'], ['Adara', 'Addalyn', 'Addalynn', 'Addelyn', 'Addie', 'Addilyn', 'Addilynn', 'Addisen', 'Addison', 'Addisyn', 'Addy', 'Addysen', 'Addyson', 'Adel', 'Adela', 'Adelaida'], ['Adelaide', 'Adele', 'Adelene', 'Adelia', 'Adelina', 'Adeline', 'Adelita', 'Adell', 'Adella', 'Adelle', 'Adelyn', 'Adelynn', 'Adena', 'Adia', 'Adilene', 'Adilyn'], ['Adilynn', 'Adina', 'Adison', 'Adisyn', 'Aditi', 'Adley', 'Adline', 'Adora', 'Adreanna', 'Adria', 'Adrian', 'Adriana', 'Adriane', 'Adrianna', 'Adrianne', 'Adrien'], ['Adriene', 'Adrienne', 'Adrina', 'Adyson', 'Aerial', 'Aeris', 'Aeryn', 'Africa', 'Afton', 'Agatha', 'Aggie', 'Agnes', 'Agustina', 'Ahna', 'Ahsley', 'Ahtziri'], ['Ahuva', 'Aida', 'Aidan', 'Aide', 'Aiden', 'Aiesha', 'Aiko', 'Aila', 'Ailani', 'Aileen', 'Ailene', 'Aili', 'Ailyn', 'Aime', 'Aimee', 'Aine'], ['Ainslee', 'Ainsley', 'Aisha', 'Aishah', 'Aislin', 'Aisling', 'Aislinn', 'Aislyn', 'Aislynn', 'Aitana', 'Aixa', 'Aiyana', 'Aiyanna', 'Aiza', 'Aja', 'Ajah'], ['Akasha', 'Akayla', 'Akeelah', 'Akia', 'Akilah', 'Akira', 'Akshara', 'Alaa', 'Alaia', 'Alaina', 'Alaine', 'Alan', 'Alana', 'Alanah', 'Alane', 'Alani'], ['Alanis', 'Alanna', 'Alannah', 'Alasia', 'Alaura', 'Alaya', 'Alayah', 'Alayla', 'Alayna', 'Alayne', 'Alaysha', 'Alaysia', 'Alba', 'Albert', 'Alberta', 'Albertha'], ['Albertina', 'Albertine', 'Albina', 'Alda', 'Alea', 'Aleah', 'Alean', 'Alease', 'Aleasha', 'Alecia', 'Aleda', 'Aleeah', 'Aleen', 'Aleena', 'Aleesha', 'Aleeya'], ['Aleeyah', 'Aleeza', 'Aleia', 'Aleida', 'Aleigha', 'Aleisha', 'Alejandra', 'Alejandrina', 'Aleksandra', 'Alena', 'Alene', 'Alesha', 'Aleshia', 'Alesia', 'Alessa', 'Alessandra'], ['Alessia', 'Aleta', 'Aletha', 'Alethea', 'Alethia', 'Alex', 'Alexa', 'Alexander', 'Alexandra', 'Alexandrea', 'Alexandria', 'Alexcia', 'Alexi', 'Alexia', 'Alexie', 'Alexis'], ['Alexius', 'Alexsandra', 'Alexsis', 'Alexus', 'Alexxis', 'Alexys', 'Alexzandra', 'Alexzandria', 'Aleya', 'Aleyah', 'Aleyda', 'Aleyna', 'Alfred', 'Alfreda', 'Alfredia', 'Ali'], ['Alia', 'Aliah', 'Aliana', 'Alianna', 'Alica', 'Alice', 'Alicea', 'Alicen', 'Alicia', 'Alida', 'Alijah', 'Alina', 'Aline', 'Alisa', 'Alise', 'Alisha'], ['Alishia', 'Alisia', 'Alison', 'Alissa', 'Alisson', 'Alita', 'Alivia', 'Alix', 'Alixandra', 'Aliya', 'Aliyah', 'Aliyana', 'Aliza', 'Alizabeth', 'Alize', 'Alla'], ['Allana', 'Allean', 'Allee', 'Allegra', 'Allen', 'Allena', 'Allene', 'Alli', 'Allie', 'Alline', 'Allisa', 'Allison', 'Allissa', 'Allisson', 'Alliyah', 'Ally'], ['Allyn', 'Allysa', 'Allyson', 'Allyssa', 'Alma', 'Almeda', 'Almeta', 'Almira', 'Alona', 'Alondra', 'Alonna', 'Alora', 'Alpha', 'Alta', 'Altha', 'Althea'], ['Alva', 'Alvena', 'Alvera', 'Alverta', 'Alvin', 'Alvina', 'Aly', 'Alya', 'Alyah', 'Alyana', 'Alyanna', 'Alyce', 'Alycia', 'Alyna', 'Alys', 'Alysa'], ['Alyse', 'Alysha', 'Alyshia', 'Alysia', 'Alyson', 'Alyssa', 'Alysse', 'Alyssia', 'Alysson', 'Alyvia', 'Alyx', 'Alyza', 'Amada', 'Amaia', 'Amairani', 'Amairany'], ['Amaiya', 'Amal', 'Amalia', 'Amalie', 'Amanda', 'Amani', 'Amara', 'Amarah', 'Amari', 'Amaria', 'Amariah', 'Amarie', 'Amaris', 'Amaryllis', 'Amaya', 'Amayah'], ['Ambar', 'Amber', 'Amberlee', 'Amberly', 'Amberlyn', 'Amberlynn', 'Ambria', 'Ambrosia', 'Amee', 'Ameena', 'Ameera', 'Ameerah', 'Amelia', 'Amelie', 'America', 'Amerie'], ['Amethyst', 'Ami', 'Amia', 'Amiah', 'Amie', 'Amiee', 'Amilia', 'Amina', 'Aminah', 'Aminata', 'Amira', 'Amiracle', 'Amirah', 'Amity', 'Amiya', 'Amiyah'], ['Ammie', 'Ammy', 'Amna', 'Amoni', 'Amor', 'Amora', 'Amparo', 'Amrita', 'Amy', 'Amya', 'Amyah', ' ...
# Lists number (of 16 names each): 436 , so total girl names =  6976

# %% [markdown]
# Now, let's process each of this lists with our `generate_names_info_async` function, called recursively by `process_all_lists`. This function takes the input list of names, and generates relevant info in JSON for for each name. The propmt to Gemini and model configuration (e.g. temp=0.2) can be found in `utils.py`.
#
# Let's start by generating 3 JSONs only. The following cell should take around 30s to run, and create a `generated` folder in the `data/generated` folder, with 3 initial versions of JSONs, cleansed a bit below in this notebook.

# %%
# Test with only 3 lists
async def produce_names_json_async_3():
    lists_of_names = all_girl_names_list[:3] # Only process the first 3 lists for testing

    results = await process_all_lists(lists_of_names)
    print(f"All lists processed successfully. Results: {results}")
    
await produce_names_json_async_3()
# Out:
# JSON data for list 3 has been written to ../data/generated/G_A3.json
# JSON data for list 1 has been written to ../data/generated/G_A1.json
# JSON data for list 2 has been written to ../data/generated/G_A2.json
# All lists processed successfully. Results: ['{"response": "{\\"Aadhya\\": {\\"meaning\\": \\"first born, beginning, primordial, the first\\", \\"origin\\": [\\"Indian\\", \\"Sanskrit\\"], \\"sound_details\\": {\\"phonemes\\": [\\"aː\\", \\"d\\", \\"j\\", \\"ə\\", \\"jɑː\\"], \\"syllables\\": 2}, \\"variants\\": [\\"Aadya\\", \\"Aditi\\"], \\"famous\\": null, \\"other_info\\": \\"Aadhya is a popular Indian name, primarily used in Hindu culture.  It signifies the beginning or the first of something, often associated with creation and new beginnings. The name has gained popularity in recent years, both within India and among Indian diaspora communities worldwide.\\", \\"family_meaning\\": \\"A family choosing Aadhya likely values tradition, spirituality, and the significance of beginnings. They may see their child as a pioneer, someone who will start new things and make their mark on the world. They might envision a creative, intelligent, and compassionate individual.\\", \\"likely_liked\\": [\\"Aanya\\", \\"Aarya\\", \\"Ira\\", \\"Maya\\", \\"Saanvi\\", \\"Ananya\\", \\"Disha\\"]}, \\"Aadya\\": {\\"meaning\\": \\"first born, beginning, primordial, the first\\", \\"origin\\": [\\"Indian\\", \\"Sanskrit\\"], \\"sound_details\\": {\\"phonemes\\": [\\"aː\\", \\"d\\", \\"j\\", \\"ɑː\\"], \\"syllables\\": 2}, \\"variants\\": [\\"Aadhya\\", \\"Aditi\\"], \\"famous\\": null, \\"other_info\\": \\"Aadya is a popular Indian name, primarily used in Hindu culture.  It signifies the beginning or the first of something, often associated with creation and new beginnings. The name has gained popularity in recent years, both within India and among Indian diaspora communities worldwide.\\", \\"family_meaning\\": \\"A family choosing Aadya likely values tradition, spirituality, and the significance of beginnings. They may see their child as a pioneer, someone who will start new things and make their mark on the world. They might envision a creative, intelligent, and compassionate individual.\\", \\"likely_liked\\": [\\"Aanya\\", \\"Aarya\\", \\"Ira\\", \\"Maya\\", \\"Saanvi\\", \\"Ananya\\", \\"Disha\\"]}, \\"Aaleyah\\": {\\"meaning\\": \\"ascending\\", \\"origin\\": [\\"Arabic\\"], \\"sound_details\\": {\\"phonemes\\": [\\"aː\\", \\"lɪː\\", \\"jɑː\\"], \\"syllables\\": 3}, \\"variants\\": [\\"Aaliyah\\", \\"Aleeya\\"], \\"famous\\": null, \\"other_info\\": \\"Aaleyah is a variation of the name Aaliyah, of Arabic origin. It suggests a sense of ascension or rising above.  The name has a melodic quality and is relatively modern in its usage.\\", \\"family_meaning\\": \\"Parents selecting Aaleyah might envision a child who is ambitious, determined, and reaches for their goals.  They may value strength, grace, and a positive outlook. They might see their child as someone who will achieve great things.\\", \\"likely_liked\\": [\\"Aaliyah\\", \\"Aliyah\\", \\"Layla\\", \\"Zaynab\\", \\"Asiya\\", \\"Inaya\\"]}, \\"Aaliya\\": {\\"meaning\\": \\"exalted, sublime\\", \\"origin\\": [\\"Arabic\\", \\"Muslim\\"], \\"sound_details\\": {\\"phonemes\\": [\\"aː\\", \\"lɪː\\", \\"jɑː\\"], \\"syllables\\": 3}, \\"variants\\": [\\"Aaliyah\\", \\"Aaliyaa\\"], \\"famous\\": null, \\"other_info\\": \\"Aaliya is an Arabic name meaning `exalted` or `sublime`. It carries a sense of dignity and high status. The name is relatively modern and has gained popularity in recent years.\\", \\"family_meaning\\": \\"A family choosing Aaliya likely values elegance, sophistication, and high ideals. They may envision their child as someone who is graceful, intelligent, and possesses a strong moral compass. They might hope their child will lead a life of purpose and meaning.\\", \\"likely_liked\\": [\\"Aaliyah\\", \\"Aliyah\\", \\"Layla\\", \\"Zaynab\\", \\"Asiya\\", \\"Inaya\\"]}, \\"Aaliyah\\": {\\"meaning\\": \\"exalted, sublime\\", \\"origin\\": [\\"Arabic\\"], \\"sound_details\\": {\\"phonemes\\": [\\"aː\\", \\"lɪː\\", \\"jɑː\\"], \\"syllables\\": 3}, \\"variants\\": [\\"Aaliya\\",  ...

# %% [markdown]
# ⚠️⚠️⚠️ **WARNING:** Uncommenting and running the next cell will make many calls to Gemini in parallel.
# - You may hit limit of requests to Gemini per minute. If you don't want to hit this limit, you should [request a quota increase](https://cloud.google.com/docs/quotas/help/request_increase) of 500 calls per minute. This can take up to 24h, usually less than 1h. Otherwise no worries, you can use the `process_remaining_girl_remaining_names` helper function to make different calls to Gemini without repeating the lists being processed, but depending on your limit this may be a bit of an overhead.
# - Generation of the whole dataset typically costs around 1-2 USD (depending on the region).

# %%
# # Run for all lists
# async def produce_names_json_async():
#     # List of lists of baby names to be computed (16 names each in order not to hit Gemini's output context limits)
#     lists_of_names = all_girl_names_list

#     results = await process_all_lists(lists_of_names)
#     print(f"All lists processed successfully. Results: {results}")

# await produce_names_json_async()

# %% [markdown]
# ## Clean JSONs
#
# This code will clean the JSONs and print them in pretty JSON format, saving them to a `cleaned` folder. If any of the generated JSONs is not valid, it will return an error "Error processing file (...)" indicating where the error is, and skip that file. You'll need to either fix that file manually, or try luck running the generation again.

# %%
clean_json_files('../data/generated')
# Out:
# Creating processed directory at: ../data/generated/cleaned
# All files in directory: ['cleaned', 'G_A1.json', 'G_A2.json', 'G_A3.json']
# Checking file: cleaned
# Checking file: G_A1.json
# Processing file: ../data/generated/G_A1.json
# Read content from ../data/generated/G_A1.json: "{\"response\": \"{\\\"Aadhya\\\": {\\\"meaning\\\": \\\"first born, beginning, primordial, the first\\\", \\\"origin\\\": [\\\"Indian\\\", \\\"Sanskrit\\\"], \\\"sound_details\\\": {\\\"phonemes\\\": [\\\"aː\\\", \\\"d\\\", \\\"j\\\", \\\"ə\\\", \\\"jɑː\\\"], \\\"syllables\\\": 2}, \\\"variants\\\": [\\\"Aadya\\\", \\\"Aditi\\\"], \\\"famous\\\": null, \\\"other_info\\\": \\\"Aadhya is a popular Indian name, primarily used in Hindu culture.  It signifies the beginning or the first of something, often associated with creation and new beginnings. The name has gained popularity in recent years, both within India and among Indian diaspora communities worldwide.\\\", \\\"family_meaning\\\": \\\"A family choosing Aadhya likely values tradition, spirituality, and the significance of beginnings. They may see their child as a pioneer, someone who will start new things and make their mark on the world. They might envision a creative, intelligent, and compassionate individual.\\\", \\\"likely_liked\\\": [\\\"Aanya\\\", \\\"Aarya\\\", \\\"Ira\\\", \\\"Maya\\\", \\\"Saanvi\\\", \\\"Ananya\\\", \\\"Disha\\\"]}, \\\"Aadya\\\": {\\\"meaning\\\": \\\"first born, beginning, primordial, the first\\\", \\\"origin\\\": [\\\"Indian\\\", \\\"Sanskrit\\\"], \\\"sound_details\\\": {\\\"phonemes\\\": [\\\"aː\\\", \\\"d\\\", \\\"j\\\", \\\"ɑː\\\"], \\\"syllables\\\": 2}, \\\"variants\\\": [\\\"Aadhya\\\", \\\"Aditi\\\"], \\\"famous\\\": null, \\\"other_info\\\": \\\"Aadya is a popular Indian name, primarily used in Hindu culture.  It signifies the beginning or the first of something, often associated with creation and new beginnings. The name has gained popularity in recent years, both within India and among Indian diaspora communities worldwide.\\\", \\\"family_meaning\\\": \\\"A family choosing Aadya likely values tradition, spirituality, and the significance of beginnings. They may see their child as a pioneer, someone who will start new things and make their mark on the world. They might envision a creative, intelligent, and compassionate individual.\\\", \\\"likely_liked\\\": [\\\"Aanya\\\", \\\"Aarya\\\", \\\"Ira\\\", \\\"Maya\\\", \\\"Saanvi\\\", \\\"Ananya\\\", \\\"Disha\\\"]}, \\\"Aaleyah\\\": {\\\"meaning\\\": \\\"ascending\\\", \\\"origin\\\": [\\\"Arabic\\\"], \\\"sound_details\\\": {\\\"phonemes\\\": [\\\"aː\\\", \\\"lɪː\\\", \\\"jɑː\\\"], \\\"syllables\\\": 3}, \\\"variants\\\": [\\\"Aaliyah\\\", \\\"Aleeya\\\"], \\\"famous\\\": null, \\\"other_info\\\": \\\"Aaleyah is a variation of the name Aaliyah, of Arabic origin. It suggests a sense of ascension or rising above.  The name has a melodic quality and is relatively modern in its usage.\\\", \\\"family_meaning\\\": \\\"Parents selecting Aaleyah might envision a child who is ambitious, determined, and reaches for their goals.  They may value strength, grace, and a positive outlook. They might see their child as someone who will achieve great things.\\\", \\\"likely_liked\\\": [\\\"Aaliyah\\\", \\\"Aliyah\\\", \\\"Layla\\\", \\\"Zaynab\\\", \\\"Asiya\\\", \\\"Inaya\\\"]}, \\\"Aaliya\\\": {\\\"meaning\\\": \\\"exalted, sublime\\\", \\\"origin\\\": [\\\"Arabic\\\", \\\"Muslim\\\"], \\\"sound_details\\\": {\\\"phonemes\\\": [\\\"aː\\\", \\\"lɪː\\\", \\\"jɑː\\\"], \\\"syllables\\\": 3}, \\\"variants\\\": [\\\"Aaliyah\\\", \\\"Aaliyaa\\\"], \\\"famous\\\": null, \\\"other_info\\\": \\\"Aaliya is an Arabic name meaning `exalted` or `sublime`. It carries a sense of dignity and high status. The name is relatively modern and has gained popularity in recent years.\\\", \\\"family_meaning\\\": \\\"A family choosing Aaliya likely values elegance, sophistication, and high ideals. They may envision their child as someone who is graceful, intelligent, and possesses a strong moral compass. They might hope their child will lead a life of purpose and meaning.\\\", \\\"likely_liked\\\": [\\\"Aaliyah\\\", \\\"Aliyah\\\", \\\"Layla\\\", \\\"Zaynab\\\", \\\"Asiya\\ ...
# Cleaned response content: {"response": {"Aadhya": {"meaning": "first born, beginning, primordial, the first", "origin": ["Indian", "Sanskrit"], "sound_details": {"phonemes": ["aː", "d", "j", "ə", "jɑː"], "syllables": 2}, "variants": ["Aadya", "Aditi"], "famous": null, "other_info": "Aadhya is a popular Indian name, primarily used in Hindu culture.  It signifies the beginning or the first of something, often associated with creation and new beginnings. The name has gained popularity in recent years, both within India and among Indian diaspora communities worldwide.", "family_meaning": "A family choosing Aadhya likely values tradition, spirituality, and the significance of beginnings. They may see their child as a pioneer, someone who will start new things and make their mark on the world. They might envision a creative, intelligent, and compassionate individual.", "likely_liked": ["Aanya", "Aarya", "Ira", "Maya", "Saanvi", "Ananya", "Disha"]}, "Aadya": {"meaning": "first born, beginning, primordial, the first", "origin": ["Indian", "Sanskrit"], "sound_details": {"phonemes": ["aː", "d", "j", "ɑː"], "syllables": 2}, "variants": ["Aadhya", "Aditi"], "famous": null, "other_info": "Aadya is a popular Indian name, primarily used in Hindu culture.  It signifies the beginning or the first of something, often associated with creation and new beginnings. The name has gained popularity in recent years, both within India and among Indian diaspora communities worldwide.", "family_meaning": "A family choosing Aadya likely values tradition, spirituality, and the significance of beginnings. They may see their child as a pioneer, someone who will start new things and make their mark on the world. They might envision a creative, intelligent, and compassionate individual.", "likely_liked": ["Aanya", "Aarya", "Ira", "Maya", "Saanvi", "Ananya", "Disha"]}, "Aaleyah": {"meaning": "ascending", "origin": ["Arabic"], "sound_details": {"phonemes": ["aː", "lɪː", "jɑː"], "syllables": 3}, "variants": ["Aaliyah", "Aleeya"], "famous": null, "other_info": "Aaleyah is a variation of the name Aaliyah, of Arabic origin. It suggests a sense of ascension or rising above.  The name has a melodic quality and is relatively modern in its usage.", "family_meaning": "Parents selecting Aaleyah might envision a child who is ambitious, determined, and reaches for their goals.  They may value strength, grace, and a positive outlook. They might see their child as someone who will achieve great things.", "likely_liked": ["Aaliyah", "Aliyah", "Layla", "Zaynab", "Asiya", "Inaya"]}, "Aaliya": {"meaning": "exalted, sublime", "origin": ["Arabic", "Muslim"], "sound_details": {"phonemes": ["aː", "lɪː", "jɑː"], "syllables": 3}, "variants": ["Aaliyah", "Aaliyaa"], "famous": null, "other_info": "Aaliya is an Arabic name meaning `exalted` or `sublime`. It carries a sense of dignity and high status. The name is relatively modern and has gained popularity in recent years.", "family_meaning": "A family choosing Aaliya likely values elegance, sophistication, and high ideals. They may envision their child as someone who is graceful, intelligent, and possesses a strong moral compass. They might hope their child will lead a life of purpose and meaning.", "likely_liked": ["Aaliyah", "Aliyah", "Layla", "Zaynab", "Asiya", "Inaya"]}, "Aaliyah": {"meaning": "exalted, sublime", "origin": ["Arabic"], "sound_details": {"phonemes": ["aː", "lɪː", "jɑː"], "syllables": 3}, "variants": ["Aaliya", "Aaliyaa"], "famous": ["Aaliyah (Aaliyah Haughton) - American singer and actress"], "other_info": "Aaliyah is a popular name of Arabic origin, meaning `exalted` or `sublime`. It has a beautiful sound and is associated with grace and elegance. The name gained significant recognition through the successful career of the late singer Aaliyah Haughton.", "family_meaning": "A family choosing Aaliyah likely values elegance, sophistication, and high ideals. They may envision their child as someone who is graceful, intellig ...
# Parsed outer JSON with type <class 'dict'>: {'response': {'Aadhya': {'meaning': 'first born, beginning, primordial, the first', 'origin': ['Indian', 'Sanskrit'], 'sound_details': {'phonemes': ['aː', 'd', 'j', 'ə', 'jɑː'], 'syllables': 2}, 'variants': ['Aadya', 'Aditi'], 'famous': None, 'other_info': 'Aadhya is a popular Indian name, primarily used in Hindu culture.  It signifies the beginning or the first of something, often associated with creation and new beginnings. The name has gained popularity in recent years, both within India and among Indian diaspora communities worldwide.', 'family_meaning': 'A family choosing Aadhya likely values tradition, spirituality, and the significance of beginnings. They may see their child as a pioneer, someone who will start new things and make their mark on the world. They might envision a creative, intelligent, and compassionate individual.', 'likely_liked': ['Aanya', 'Aarya', 'Ira', 'Maya', 'Saanvi', 'Ananya', 'Disha']}, 'Aadya': {'meaning': 'first born, beginning, primordial, the first', 'origin': ['Indian', 'Sanskrit'], 'sound_details': {'phonemes': ['aː', 'd', 'j', 'ɑː'], 'syllables': 2}, 'variants': ['Aadhya', 'Aditi'], 'famous': None, 'other_info': 'Aadya is a popular Indian name, primarily used in Hindu culture.  It signifies the beginning or the first of something, often associated with creation and new beginnings. The name has gained popularity in recent years, both within India and among Indian diaspora communities worldwide.', 'family_meaning': 'A family choosing Aadya likely values tradition, spirituality, and the significance of beginnings. They may see their child as a pioneer, someone who will start new things and make their mark on the world. They might envision a creative, intelligent, and compassionate individual.', 'likely_liked': ['Aanya', 'Aarya', 'Ira', 'Maya', 'Saanvi', 'Ananya', 'Disha']}, 'Aaleyah': {'meaning': 'ascending', 'origin': ['Arabic'], 'sound_details': {'phonemes': ['aː', 'lɪː', 'jɑː'], 'syllables': 3}, 'variants': ['Aaliyah', 'Aleeya'], 'famous': None, 'other_info': 'Aaleyah is a variation of the name Aaliyah, of Arabic origin. It suggests a sense of ascension or rising above.  The name has a melodic quality and is relatively modern in its usage.', 'family_meaning': 'Parents selecting Aaleyah might envision a child who is ambitious, determined, and reaches for their goals.  They may value strength, grace, and a positive outlook. They might see their child as someone who will achieve great things.', 'likely_liked': ['Aaliyah', 'Aliyah', 'Layla', 'Zaynab', 'Asiya', 'Inaya']}, 'Aaliya': {'meaning': 'exalted, sublime', 'origin': ['Arabic', 'Muslim'], 'sound_details': {'phonemes': ['aː', 'lɪː', 'jɑː'], 'syllables': 3}, 'variants': ['Aaliyah', 'Aaliyaa'], 'famous': None, 'other_info': 'Aaliya is an Arabic name meaning `exalted` or `sublime`. It carries a sense of dignity and high status. The name is relatively modern and has gained popularity in recent years.', 'family_meaning': 'A family choosing Aaliya likely values elegance, sophistication, and high ideals. They may envision their child as someone who is graceful, intelligent, and possesses a strong moral compass. They might hope their child will lead a life of purpose and meaning.', 'likely_liked': ['Aaliyah', 'Aliyah', 'Layla', 'Zaynab', 'Asiya', 'Inaya']}, 'Aaliyah': {'meaning': 'exalted, sublime', 'origin': ['Arabic'], 'sound_details': {'phonemes': ['aː', 'lɪː', 'jɑː'], 'syllables': 3}, 'variants': ['Aaliya', 'Aaliyaa'], 'famous': ['Aaliyah (Aaliyah Haughton) - American singer and actress'], 'other_info': 'Aaliyah is a popular name of Arabic origin, meaning `exalted` or `sublime`. It has a beautiful sound and is associated with grace and elegance. The name gained significant recognition through the successful career of the late singer Aaliyah Haughton.', 'family_meaning': 'A family choosing Aaliyah likely values elegance, sophistication, and high ideals. They may envision their child as someone who is  ...
# Extracted response content: {'Aadhya': {'meaning': 'first born, beginning, primordial, the first', 'origin': ['Indian', 'Sanskrit'], 'sound_details': {'phonemes': ['aː', 'd', 'j', 'ə', 'jɑː'], 'syllables': 2}, 'variants': ['Aadya', 'Aditi'], 'famous': None, 'other_info': 'Aadhya is a popular Indian name, primarily used in Hindu culture.  It signifies the beginning or the first of something, often associated with creation and new beginnings. The name has gained popularity in recent years, both within India and among Indian diaspora communities worldwide.', 'family_meaning': 'A family choosing Aadhya likely values tradition, spirituality, and the significance of beginnings. They may see their child as a pioneer, someone who will start new things and make their mark on the world. They might envision a creative, intelligent, and compassionate individual.', 'likely_liked': ['Aanya', 'Aarya', 'Ira', 'Maya', 'Saanvi', 'Ananya', 'Disha']}, 'Aadya': {'meaning': 'first born, beginning, primordial, the first', 'origin': ['Indian', 'Sanskrit'], 'sound_details': {'phonemes': ['aː', 'd', 'j', 'ɑː'], 'syllables': 2}, 'variants': ['Aadhya', 'Aditi'], 'famous': None, 'other_info': 'Aadya is a popular Indian name, primarily used in Hindu culture.  It signifies the beginning or the first of something, often associated with creation and new beginnings. The name has gained popularity in recent years, both within India and among Indian diaspora communities worldwide.', 'family_meaning': 'A family choosing Aadya likely values tradition, spirituality, and the significance of beginnings. They may see their child as a pioneer, someone who will start new things and make their mark on the world. They might envision a creative, intelligent, and compassionate individual.', 'likely_liked': ['Aanya', 'Aarya', 'Ira', 'Maya', 'Saanvi', 'Ananya', 'Disha']}, 'Aaleyah': {'meaning': 'ascending', 'origin': ['Arabic'], 'sound_details': {'phonemes': ['aː', 'lɪː', 'jɑː'], 'syllables': 3}, 'variants': ['Aaliyah', 'Aleeya'], 'famous': None, 'other_info': 'Aaleyah is a variation of the name Aaliyah, of Arabic origin. It suggests a sense of ascension or rising above.  The name has a melodic quality and is relatively modern in its usage.', 'family_meaning': 'Parents selecting Aaleyah might envision a child who is ambitious, determined, and reaches for their goals.  They may value strength, grace, and a positive outlook. They might see their child as someone who will achieve great things.', 'likely_liked': ['Aaliyah', 'Aliyah', 'Layla', 'Zaynab', 'Asiya', 'Inaya']}, 'Aaliya': {'meaning': 'exalted, sublime', 'origin': ['Arabic', 'Muslim'], 'sound_details': {'phonemes': ['aː', 'lɪː', 'jɑː'], 'syllables': 3}, 'variants': ['Aaliyah', 'Aaliyaa'], 'famous': None, 'other_info': 'Aaliya is an Arabic name meaning `exalted` or `sublime`. It carries a sense of dignity and high status. The name is relatively modern and has gained popularity in recent years.', 'family_meaning': 'A family choosing Aaliya likely values elegance, sophistication, and high ideals. They may envision their child as someone who is graceful, intelligent, and possesses a strong moral compass. They might hope their child will lead a life of purpose and meaning.', 'likely_liked': ['Aaliyah', 'Aliyah', 'Layla', 'Zaynab', 'Asiya', 'Inaya']}, 'Aaliyah': {'meaning': 'exalted, sublime', 'origin': ['Arabic'], 'sound_details': {'phonemes': ['aː', 'lɪː', 'jɑː'], 'syllables': 3}, 'variants': ['Aaliya', 'Aaliyaa'], 'famous': ['Aaliyah (Aaliyah Haughton) - American singer and actress'], 'other_info': 'Aaliyah is a popular name of Arabic origin, meaning `exalted` or `sublime`. It has a beautiful sound and is associated with grace and elegance. The name gained significant recognition through the successful career of the late singer Aaliyah Haughton.', 'family_meaning': 'A family choosing Aaliyah likely values elegance, sophistication, and high ideals. They may envision their child as someone who is graceful, intelligent, and po ...
# Pretty JSON content: {
#     "Aadhya": {
#         "meaning": "first born, beginning, primordial, the first",
#         "origin": [
#             "Indian",
#             "Sanskrit"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "aː",
#                 "d",
#                 "j",
#                 "ə",
#                 "jɑː"
#             ],
#             "syllables": 2
#         },
#         "variants": [
#             "Aadya",
#             "Aditi"
#         ],
#         "famous": null,
#         "other_info": "Aadhya is a popular Indian name, primarily used in Hindu culture.  It signifies the beginning or the first of something, often associated with creation and new beginnings. The name has gained popularity in recent years, both within India and among Indian diaspora communities worldwide.",
#         "family_meaning": "A family choosing Aadhya likely values tradition, spirituality, and the significance of beginnings. They may see their child as a pioneer, someone who will start new things and make their mark on the world. They might envision a creative, intelligent, and compassionate individual.",
#         "likely_liked": [
#             "Aanya",
#             "Aarya",
#             "Ira",
#             "Maya",
#             "Saanvi",
#             "Ananya",
#             "Disha"
#         ]
#     },
#     "Aadya": {
#         "meaning": "first born, beginning, primordial, the first",
#         "origin": [
#             "Indian",
#             "Sanskrit"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "aː",
#                 "d",
#                 "j",
#                 "ɑː"
#             ],
#             "syllables": 2
#         },
#         "variants": [
#             "Aadhya",
#             "Aditi"
#         ],
#         "famous": null,
#         "other_info": "Aadya is a popular Indian name, primarily used in Hindu culture.  It signifies the beginning or the first of something, often associated with creation and new beginnings. The name has gained popularity in recent years, both within India and among Indian diaspora communities worldwide.",
#         "family_meaning": "A family choosing Aadya likely values tradition, spirituality, and the significance of beginnings. They may see their child as a pioneer, someone who will start new things and make their mark on the world. They might envision a creative, intelligent, and compassionate individual.",
#         "likely_liked": [
#             "Aanya",
#             "Aarya",
#             "Ira",
#             "Maya",
#             "Saanvi",
#             "Ananya",
#             "Disha"
#         ]
#     },
#     "Aaleyah": {
#         "meaning": "ascending",
#         "origin": [
#             "Arabic"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "aː",
#                 "lɪː",
#                 "jɑː"
#             ],
#             "syllables": 3
#         },
#         "variants": [
#             "Aaliyah",
#             "Aleeya"
#         ],
#         "famous": null,
#         "other_info": "Aaleyah is a variation of the name Aaliyah, of Arabic origin. It suggests a sense of ascension or rising above.  The name has a melodic quality and is relatively modern in its usage.",
#         "family_meaning": "Parents selecting Aaleyah might envision a child who is ambitious, determined, and reaches for their goals.  They may value strength, grace, and a positive outlook. They might see their child as someone who will achieve great things.",
#         "likely_liked": [
#             "Aaliyah",
#             "Aliyah",
#             "Layla",
#             "Zaynab",
#             "Asiya",
#             "Inaya"
#         ]
#     },
#     "Aaliya": {
#         "meaning": "exalted, sublime",
#         "origin": [
#             "Arabic",
#             "Muslim"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "aː",
#                 "lɪː",
#                 "jɑː"
#             ],
#             "syllables": 3
#         },
#         "variants": [
#             "Aaliyah",
#             "Aaliyaa"
#         ],
#         "famous": null,
#         "other_info": "Aaliya is an Arabic name meaning `exalted` or `sublime`. It carries a sense of dignity and high status. The name is relatively modern and has gained popularity in recent years.",
#         "family_meaning": "A family choosing Aaliya likely values elegance, sophistication, and high ideals. They may envision their child as someone who is graceful, intelligent, and possesses a strong moral compass. They might hope their child will lead a life of purpose and meaning.",
#         "likely_liked": [
#             "Aaliyah",
#             "Aliyah",
#             "Layla",
#             "Zaynab",
#             "Asiya",
#             "Inaya"
#         ]
#     },
#     "Aaliyah": {
#         "meaning": "exalted, sublime",
#         "origin": [
#             "Arabic"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "aː",
#                 "lɪː",
#                 "jɑː"
#             ],
#             "syllables": 3
#         },
#         "variants": [
#             "Aaliya",
#             "Aaliyaa"
#         ],
#         "famous": [
#             "Aaliyah (Aaliyah Haughton) - American singer and actress"
#         ],
#         "other_info": "Aaliyah is a popular name of Arabic origin, meaning `exalted` or `sublime`. It has a beautiful sound and is associated with grace and elegance. The name gained significant recognition through the successful career of the late singer Aaliyah Haughton.",
#         "family_meaning": "A family choosing Aaliyah likely values elegance, sophistication, and high ideals. They may envision their child as someone who is graceful, intelligent, and possesses a strong moral compass. They might hope their child will lead a life of purpose and meaning.",
#         "likely_liked": [
#             "Aaliya",
#             "Aliyah",
#             "Layla",
#             "Zaynab",
#             "Asiya",
#             "Inaya"
#         ]
#     },
#     "Aaniyah": {
#         "meaning": "gift from God",
#         "origin": [
#             "Arabic"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "aː",
#                 "nɪː",
#                 "jɑː"
#             ],
#             "syllables": 3
#         },
#         "variants": [
#             "Aniya",
#             "Anya"
#         ],
#         "famous": null,
#         "other_info": "Aaniyah is an Arabic name that means `gift from God`. It carries a spiritual significance and is associated with blessings and gratitude.",
#         "family_meaning": "A family choosing Aaniyah likely values faith, spirituality, and the importance of gratitude. They may see their child as a blessing and a source of joy. They might envision a kind, compassionate, and thoughtful individual.",
#         "likely_liked": [
#             "Aaliyah",
#             "Layla",
#             "Zaynab",
#             "Asiya",
#             "Inaya",
#             "Amirah"
#         ]
#     },
#     "Aanya": {
#         "meaning": "inexhaustible, immeasurable, limitless",
#         "origin": [
#             "Indian"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "aː",
#                 "njɑː"
#             ],
#             "syllables": 2
#         },
#         "variants": [
#             "Aana",
#             "Ananya"
#         ],
#         "famous": null,
#         "other_info": "Aanya is a modern and popular Indian name. It suggests a sense of boundless potential and limitless possibilities.",
#         "family_meaning": "A family choosing Aanya likely values ambition, creativity, and the pursuit of knowledge. They may see their child as someone who will achieve great things and make a difference in the world. They might envision a curious, intelligent, and driven individual.",
#         "likely_liked": [
#             "Aadhya",
#             "Aarya",
#             "Ira",
#             "Maya",
#             "Saanvi",
#             "Ananya",
#             "Disha"
#         ]
#     },
#     "Aaralyn": {
#         "meaning": "combination of Aaron and Lynn",
#         "origin": [
#             "American",
#             "Hebrew",
#             "Celtic"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "æ",
#                 "r",
#                 "əl",
#                 "ɪ",
#                 "n"
#             ],
#             "syllables": 3
#         },
#         "variants": [
#             "Aryn",
#             "Aralynn"
#         ],
#         "famous": null,
#         "other_info": "Aaralyn is a modern American name, often considered a combination of Aaron (Hebrew origin) and Lynn (Celtic origin). It blends different cultural influences and creates a unique sound.",
#         "family_meaning": "A family choosing Aaralyn might value creativity, individuality, and a blend of cultural traditions. They may see their child as someone who is unique, imaginative, and embraces their heritage. They might envision a thoughtful, artistic, and independent individual.",
#         "likely_liked": [
#             "Aurora",
#             "Alana",
#             "Ariel",
#             "Aubrey",
#             "Rylee",
#             "Avery"
#         ]
#     },
#     "Aarna": {
#         "meaning": "earth, land",
#         "origin": [
#             "Indian"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "aː",
#                 "r",
#                 "nɑː"
#             ],
#             "syllables": 2
#         },
#         "variants": [
#             "Aarnav",
#             "Arnav"
#         ],
#         "famous": null,
#         "other_info": "Aarna is a relatively modern Indian name, often associated with the earth or land. It has a simple yet elegant sound.",
#         "family_meaning": "A family choosing Aarna might value nature, grounding, and stability. They may see their child as someone who is connected to the earth and possesses a strong sense of self. They might envision a practical, reliable, and compassionate individual.",
#         "likely_liked": [
#             "Aanya",
#             "Aarya",
#             "Ira",
#             "Maya",
#             "Saanvi",
#             "Ananya",
#             "Disha"
#         ]
#     },
#     "Aaron": {
#         "meaning": "enlightened, mountain of strength",
#         "origin": [
#             "Hebrew"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "eɪ",
#                 "r",
#                 "ən"
#             ],
#             "syllables": 2
#         },
#         "variants": [
#             "Aron",
#             "Ron",
#             "Ronnie"
#         ],
#         "famous": [
#             "Aaron Burr - American politician",
#             "Aaron Copland - American composer",
#             "Aaron Sorkin - American screenwriter and playwright"
#         ],
#         "other_info": "Aaron is a classic and popular name of Hebrew origin. It has strong biblical connections and is associated with leadership and strength. The name has remained consistently popular over many years.",
#         "family_meaning": "A family choosing Aaron likely values strength, intelligence, and leadership qualities. They may see their child as someone who will achieve great things and make a positive impact on the world. They might envision a confident, ambitious, and responsible individual.",
#         "likely_liked": [
#             "Ethan",
#             "Caleb",
#             "Liam",
#             "Noah",
#             "Owen",
#             "Elijah",
#             "Samuel"
#         ]
#     },
#     "Aarya": {
#         "meaning": "respect, honorable, worthy of respect",
#         "origin": [
#             "Indian",
#             "Sanskrit"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "aː",
#                 "r",
#                 "jɑː"
#             ],
#             "syllables": 2
#         },
#         "variants": [
#             "Arya",
#             "Aaryaana"
#         ],
#         "famous": null,
#         "other_info": "Aarya is a popular Indian name, often associated with respect, honor, and nobility. It has a sophisticated and elegant sound.",
#         "family_meaning": "A family choosing Aarya likely values integrity, honor, and strong moral principles. They may see their child as someone who will be respected and admired by others. They might envision a kind, compassionate, and responsible individual.",
#         "likely_liked": [
#             "Aanya",
#             "Aadhya",
#             "Ira",
#             "Maya",
#             "Saanvi",
#             "Ananya",
#             "Disha"
#         ]
#     },
#     "Aaryn": {
#         "meaning": "high mountain",
#         "origin": [
#             "Irish"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "eɪ",
#                 "r",
#                 "ɪ",
#                 "n"
#             ],
#             "syllables": 2
#         },
#         "variants": [
#             "Aaron",
#             "Aaren"
#         ],
#         "famous": null,
#         "other_info": "Aaryn is a modern variation of the name Aaron, often associated with strength and resilience. It has a slightly more unique sound than the traditional Aaron.",
#         "family_meaning": "A family choosing Aaryn might value strength, resilience, and a connection to nature. They may see their child as someone who is strong, independent, and capable of overcoming challenges. They might envision a confident, determined, and adventurous individual.",
#         "likely_liked": [
#             "Aaron",
#             "Ethan",
#             "Caleb",
#             "Liam",
#             "Noah",
#             "Owen",
#             "Elijah"
#         ]
#     },
#     "Abagail": {
#         "meaning": "father is joy",
#         "origin": [
#             "Hebrew"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "æ",
#                 "b",
#                 "ə",
#                 "ɡ",
#                 "eɪ",
#                 "l"
#             ],
#             "syllables": 3
#         },
#         "variants": [
#             "Abigail",
#             "Abbie",
#             "Abby"
#         ],
#         "famous": [
#             "Abigail Adams - American political figure",
#             "Abigail Breslin - American actress"
#         ],
#         "other_info": "Abagail is a variation of the name Abigail, a classic name of Hebrew origin. It means `father of joy` and is associated with happiness and good fortune.",
#         "family_meaning": "A family choosing Abagail likely values happiness, family, and strong relationships. They may see their child as a source of joy and a bringer of good fortune. They might envision a kind, compassionate, and loving individual.",
#         "likely_liked": [
#             "Olivia",
#             "Sophia",
#             "Emma",
#             "Ava",
#             "Isabella",
#             "Mia",
#             "Chloe"
#         ]
#     },
#     "Abbe": {
#         "meaning": "father is joy",
#         "origin": [
#             "Hebrew"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "æ",
#                 "biː"
#             ],
#             "syllables": 1
#         },
#         "variants": [
#             "Abbey",
#             "Abigail",
#             "Abagail"
#         ],
#         "famous": null,
#         "other_info": "Abbe is a short and sweet variation of the name Abigail, of Hebrew origin. It retains the essence of the original meaning while offering a more modern and concise feel.",
#         "family_meaning": "A family choosing Abbe likely values simplicity, happiness, and strong family bonds. They may see their child as a source of joy and a bringer of good fortune. They might envision a kind, compassionate, and loving individual.",
#         "likely_liked": [
#             "Olivia",
#             "Sophia",
#             "Emma",
#             "Ava",
#             "Isabella",
#             "Mia",
#             "Chloe"
#         ]
#     },
#     "Abbey": {
#         "meaning": "father is joy",
#         "origin": [
#             "Hebrew"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "æ",
#                 "biː"
#             ],
#             "syllables": 1
#         },
#         "variants": [
#             "Abbe",
#             "Abigail",
#             "Abagail"
#         ],
#         "famous": null,
#         "other_info": "Abbey is a short and sweet variation of the name Abigail, of Hebrew origin. It retains the essence of the original meaning while offering a more modern and concise feel. It can also refer to a place of religious retreat.",
#         "family_meaning": "A family choosing Abbey likely values simplicity, happiness, and strong family bonds. They may see their child as a source of joy and a bringer of good fortune. They might envision a kind, compassionate, and loving individual.",
#         "likely_liked": [
#             "Olivia",
#             "Sophia",
#             "Emma",
#             "Ava",
#             "Isabella",
#             "Mia",
#             "Chloe"
#         ]
#     },
#     "Abbi": {
#         "meaning": "father is joy",
#         "origin": [
#             "Hebrew"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "æ",
#                 "biː"
#             ],
#             "syllables": 1
#         },
#         "variants": [
#             "Abbey",
#             "Abigail",
#             "Abagail"
#         ],
#         "famous": null,
#         "other_info": "Abbi is a short and modern variation of the name Abigail, of Hebrew origin. It retains the essence of the original meaning while offering a more modern and concise feel.",
#         "family_meaning": "A family choosing Abbi likely values simplicity, happiness, and strong family bonds. They may see their child as a source of joy and a bringer of good fortune. They might envision a kind, compassionate, and loving individual.",
#         "likely_liked": [
#             "Olivia",
#             "Sophia",
#             "Emma",
#             "Ava",
#             "Isabella",
#             "Mia",
#             "Chloe"
#         ]
#     }
# }
# Saving pretty JSON to ../data/generated/cleaned/G_A1_clean.json
# Saved pretty JSON to ../data/generated/cleaned/G_A1_clean.json
# Processed and saved: ../data/generated/cleaned/G_A1_clean.json
# Checking file: G_A2.json
# Processing file: ../data/generated/G_A2.json
# Read content from ../data/generated/G_A2.json: "{\"response\": \"{\\\"Abbie\\\": {\\\"meaning\\\": \\\"God is my father\\\", \\\"origin\\\": [\\\"Hebrew\\\"], \\\"sound_details\\\": {\\\"phonemes\\\": [\\\"æ\\\", \\\"b\\\", \\\"iː\\\"], \\\"syllables\\\": 1}, \\\"variants\\\": [\\\"Abby\\\", \\\"Abigail\\\", \\\"Abigale\\\"], \\\"famous\\\": [\\\"Abbie Hoffman - American political activist\\\"], \\\"other_info\\\": \\\"Abbie is a diminutive of Abigail. It has been in use since the Middle Ages and has a sweet and simple sound. It is a good choice for parents who are looking for a name that is both classic and modern.\\\", \\\"family_meaning\\\": \\\"A family choosing the name Abbie for their baby girl likely values faith, family, and tradition. They might envision their daughter as a kind, compassionate, and strong-willed individual. The name's meaning, `God is my father`, suggests a spiritual connection and a belief in a higher power. They might hope their daughter will grow up to be a devout and caring person, possibly pursuing a career in social work, education, or healthcare.\\\", \\\"likely_liked\\\": [\\\"Katie\\\", \\\"Maggie\\\", \\\"Ellie\\\", \\\"Sophie\\\", \\\"Grace\\\", \\\"Lily\\\", \\\"Chloe\\\", \\\"Olivia\\\", \\\"Emma\\\", \\\"Ava\\\"]}, \\\"Abbigail\\\": {\\\"meaning\\\": \\\"God is my father\\\", \\\"origin\\\": [\\\"Hebrew\\\"], \\\"sound_details\\\": {\\\"phonemes\\\": [\\\"æ\\\", \\\"b\\\", \\\"ɪ\\\", \\\"ɡ\\\", \\\"eɪ\\\", \\\"l\\\"], \\\"syllables\\\": 3}, \\\"variants\\\": [\\\"Abbie\\\", \\\"Abby\\\", \\\"Abigail\\\", \\\"Abigale\\\"], \\\"famous\\\": [], \\\"other_info\\\": \\\"Abbigail is a variation of the name Abigail, which has Hebrew origins and means `God is my father`. It is a classic name with a strong and elegant sound. It is a good choice for parents who are looking for a name that is both traditional and sophisticated.\\\", \\\"family_meaning\\\": \\\"A family choosing the name Abbigail for their baby girl likely values faith, family, and tradition. They might envision their daughter as a kind, compassionate, and strong-willed individual. The name's meaning, `God is my father`, suggests a spiritual connection and a belief in a higher power. They might hope their daughter will grow up to be a devout and caring person, possibly pursuing a career in social work, education, or healthcare.\\\", \\\"likely_liked\\\": [\\\"Katherine\\\", \\\"Margaret\\\", \\\"Eleanor\\\", \\\"Sophia\\\", \\\"Grace\\\", \\\"Lily\\\", \\\"Chloe\\\", \\\"Olivia\\\", \\\"Emma\\\", \\\"Ava\\\"]}, \\\"Abbigale\\\": {\\\"meaning\\\": \\\"God is my father\\\", \\\"origin\\\": [\\\"Hebrew\\\"], \\\"sound_details\\\": {\\\"phonemes\\\": [\\\"æ\\\", \\\"b\\\", \\\"ɪ\\\", \\\"ɡ\\\", \\\"eɪ\\\", \\\"l\\\"], \\\"syllables\\\": 3}, \\\"variants\\\": [\\\"Abbie\\\", \\\"Abby\\\", \\\"Abigail\\\", \\\"Abbigail\\\"], \\\"famous\\\": [], \\\"other_info\\\": \\\"Abbigale is a variation of the name Abigail, which has Hebrew origins and means `God is my father`. It is a classic name with a strong and elegant sound. It is a good choice for parents who are looking for a name that is both traditional and sophisticated.\\\", \\\"family_meaning\\\": \\\"A family choosing the name Abbigale for their baby girl likely values faith, family, and tradition. They might envision their daughter as a kind, compassionate, and strong-willed individual. The name's meaning, `God is my father`, suggests a spiritual connection and a belief in a higher power. They might hope their daughter will grow up to be a devout and caring person, possibly pursuing a career in social work, education, or healthcare.\\\", \\\"likely_liked\\\": [\\\"Katherine\\\", \\\"Margaret\\\", \\\"Eleanor\\\", \\\"Sophia\\\", \\\"Grace\\\", \\\"Lily\\\", \\\"Chloe\\\", \\\"Olivia\\\", \\\"Emma\\\", \\\"Ava\\\"]}, \\\"Abbigayle\\\": {\\\"meaning\\\": \\\"God is my father\\\", \\\"origin\\\": [\\\"Hebrew\\\"], \\\"sound_details\\\": {\\\"phonemes\\\": [\\\"æ\\\", \\\"b\\\", \\\"ɪ\\\", ...
# Cleaned response content: {"response": {"Abbie": {"meaning": "God is my father", "origin": ["Hebrew"], "sound_details": {"phonemes": ["æ", "b", "iː"], "syllables": 1}, "variants": ["Abby", "Abigail", "Abigale"], "famous": ["Abbie Hoffman - American political activist"], "other_info": "Abbie is a diminutive of Abigail. It has been in use since the Middle Ages and has a sweet and simple sound. It is a good choice for parents who are looking for a name that is both classic and modern.", "family_meaning": "A family choosing the name Abbie for their baby girl likely values faith, family, and tradition. They might envision their daughter as a kind, compassionate, and strong-willed individual. The name's meaning, `God is my father`, suggests a spiritual connection and a belief in a higher power. They might hope their daughter will grow up to be a devout and caring person, possibly pursuing a career in social work, education, or healthcare.", "likely_liked": ["Katie", "Maggie", "Ellie", "Sophie", "Grace", "Lily", "Chloe", "Olivia", "Emma", "Ava"]}, "Abbigail": {"meaning": "God is my father", "origin": ["Hebrew"], "sound_details": {"phonemes": ["æ", "b", "ɪ", "ɡ", "eɪ", "l"], "syllables": 3}, "variants": ["Abbie", "Abby", "Abigail", "Abigale"], "famous": [], "other_info": "Abbigail is a variation of the name Abigail, which has Hebrew origins and means `God is my father`. It is a classic name with a strong and elegant sound. It is a good choice for parents who are looking for a name that is both traditional and sophisticated.", "family_meaning": "A family choosing the name Abbigail for their baby girl likely values faith, family, and tradition. They might envision their daughter as a kind, compassionate, and strong-willed individual. The name's meaning, `God is my father`, suggests a spiritual connection and a belief in a higher power. They might hope their daughter will grow up to be a devout and caring person, possibly pursuing a career in social work, education, or healthcare.", "likely_liked": ["Katherine", "Margaret", "Eleanor", "Sophia", "Grace", "Lily", "Chloe", "Olivia", "Emma", "Ava"]}, "Abbigale": {"meaning": "God is my father", "origin": ["Hebrew"], "sound_details": {"phonemes": ["æ", "b", "ɪ", "ɡ", "eɪ", "l"], "syllables": 3}, "variants": ["Abbie", "Abby", "Abigail", "Abbigail"], "famous": [], "other_info": "Abbigale is a variation of the name Abigail, which has Hebrew origins and means `God is my father`. It is a classic name with a strong and elegant sound. It is a good choice for parents who are looking for a name that is both traditional and sophisticated.", "family_meaning": "A family choosing the name Abbigale for their baby girl likely values faith, family, and tradition. They might envision their daughter as a kind, compassionate, and strong-willed individual. The name's meaning, `God is my father`, suggests a spiritual connection and a belief in a higher power. They might hope their daughter will grow up to be a devout and caring person, possibly pursuing a career in social work, education, or healthcare.", "likely_liked": ["Katherine", "Margaret", "Eleanor", "Sophia", "Grace", "Lily", "Chloe", "Olivia", "Emma", "Ava"]}, "Abbigayle": {"meaning": "God is my father", "origin": ["Hebrew"], "sound_details": {"phonemes": ["æ", "b", "ɪ", "ɡ", "eɪ", "l"], "syllables": 3}, "variants": ["Abbie", "Abby", "Abigail", "Abbigail"], "famous": [], "other_info": "Abbigayle is a variation of the name Abigail, which has Hebrew origins and means `God is my father`. It is a classic name with a strong and elegant sound. It is a good choice for parents who are looking for a name that is both traditional and sophisticated.", "family_meaning": "A family choosing the name Abbigayle for their baby girl likely values faith, family, and tradition. They might envision their daughter as a kind, compassionate, and strong-willed individual. The name's meaning, `God is my father`, suggests a spiritual connection and a belief in a higher power. They  ...
# Parsed outer JSON with type <class 'dict'>: {'response': {'Abbie': {'meaning': 'God is my father', 'origin': ['Hebrew'], 'sound_details': {'phonemes': ['æ', 'b', 'iː'], 'syllables': 1}, 'variants': ['Abby', 'Abigail', 'Abigale'], 'famous': ['Abbie Hoffman - American political activist'], 'other_info': 'Abbie is a diminutive of Abigail. It has been in use since the Middle Ages and has a sweet and simple sound. It is a good choice for parents who are looking for a name that is both classic and modern.', 'family_meaning': "A family choosing the name Abbie for their baby girl likely values faith, family, and tradition. They might envision their daughter as a kind, compassionate, and strong-willed individual. The name's meaning, `God is my father`, suggests a spiritual connection and a belief in a higher power. They might hope their daughter will grow up to be a devout and caring person, possibly pursuing a career in social work, education, or healthcare.", 'likely_liked': ['Katie', 'Maggie', 'Ellie', 'Sophie', 'Grace', 'Lily', 'Chloe', 'Olivia', 'Emma', 'Ava']}, 'Abbigail': {'meaning': 'God is my father', 'origin': ['Hebrew'], 'sound_details': {'phonemes': ['æ', 'b', 'ɪ', 'ɡ', 'eɪ', 'l'], 'syllables': 3}, 'variants': ['Abbie', 'Abby', 'Abigail', 'Abigale'], 'famous': [], 'other_info': 'Abbigail is a variation of the name Abigail, which has Hebrew origins and means `God is my father`. It is a classic name with a strong and elegant sound. It is a good choice for parents who are looking for a name that is both traditional and sophisticated.', 'family_meaning': "A family choosing the name Abbigail for their baby girl likely values faith, family, and tradition. They might envision their daughter as a kind, compassionate, and strong-willed individual. The name's meaning, `God is my father`, suggests a spiritual connection and a belief in a higher power. They might hope their daughter will grow up to be a devout and caring person, possibly pursuing a career in social work, education, or healthcare.", 'likely_liked': ['Katherine', 'Margaret', 'Eleanor', 'Sophia', 'Grace', 'Lily', 'Chloe', 'Olivia', 'Emma', 'Ava']}, 'Abbigale': {'meaning': 'God is my father', 'origin': ['Hebrew'], 'sound_details': {'phonemes': ['æ', 'b', 'ɪ', 'ɡ', 'eɪ', 'l'], 'syllables': 3}, 'variants': ['Abbie', 'Abby', 'Abigail', 'Abbigail'], 'famous': [], 'other_info': 'Abbigale is a variation of the name Abigail, which has Hebrew origins and means `God is my father`. It is a classic name with a strong and elegant sound. It is a good choice for parents who are looking for a name that is both traditional and sophisticated.', 'family_meaning': "A family choosing the name Abbigale for their baby girl likely values faith, family, and tradition. They might envision their daughter as a kind, compassionate, and strong-willed individual. The name's meaning, `God is my father`, suggests a spiritual connection and a belief in a higher power. They might hope their daughter will grow up to be a devout and caring person, possibly pursuing a career in social work, education, or healthcare.", 'likely_liked': ['Katherine', 'Margaret', 'Eleanor', 'Sophia', 'Grace', 'Lily', 'Chloe', 'Olivia', 'Emma', 'Ava']}, 'Abbigayle': {'meaning': 'God is my father', 'origin': ['Hebrew'], 'sound_details': {'phonemes': ['æ', 'b', 'ɪ', 'ɡ', 'eɪ', 'l'], 'syllables': 3}, 'variants': ['Abbie', 'Abby', 'Abigail', 'Abbigail'], 'famous': [], 'other_info': 'Abbigayle is a variation of the name Abigail, which has Hebrew origins and means `God is my father`. It is a classic name with a strong and elegant sound. It is a good choice for parents who are looking for a name that is both traditional and sophisticated.', 'family_meaning': "A family choosing the name Abbigayle for their baby girl likely values faith, family, and tradition. They might envision their daughter as a kind, compassionate, and strong-willed individual. The name's meaning, `God is my father`, suggests a spiritual connection and a belief in a h ...
# ...
#         "family_meaning": "A family choosing Acacia might appreciate nature's beauty and resilience. They might envision their child as someone who is strong, independent, and connected to the natural world.",
#         "likely_liked": [
#             "Willow",
#             "Hazel",
#             "Ivy",
#             "Lily",
#             "Rose",
#             "Daisy",
#             "Violet",
#             "Iris",
#             "Poppy",
#             "Luna"
#         ]
#     },
#     "Ada": {
#         "meaning": "noble",
#         "origin": [
#             "German"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "eɪ",
#                 "d",
#                 "ə"
#             ],
#             "syllables": 1
#         },
#         "variants": [
#             "Adah",
#             "Addie",
#             "Adelaide"
#         ],
#         "famous": [
#             "Ada Lovelace - Pioneer of computer programming"
#         ],
#         "other_info": "Ada is a short, sweet, and classic name with a rich history and a modern appeal. It is a versatile name that can suit a variety of personalities.",
#         "family_meaning": "A family choosing Ada likely values intelligence, creativity, and a strong sense of self. They might envision their child as someone who is innovative, independent, and makes a positive contribution to society.",
#         "likely_liked": [
#             "Ava",
#             "Mia",
#             "Grace",
#             "Emma",
#             "Olivia",
#             "Sophia",
#             "Chloe",
#             "Harper",
#             "Amelia",
#             "Abigail"
#         ]
#     },
#     "Adah": {
#         "meaning": "ornament",
#         "origin": [
#             "Hebrew"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "eɪ",
#                 "d",
#                 "ə"
#             ],
#             "syllables": 1
#         },
#         "variants": [
#             "Ada",
#             "Addie"
#         ],
#         "famous": [],
#         "other_info": "Adah is a biblical name with a simple yet elegant sound. It is a less common name, offering a unique and distinctive choice for parents.",
#         "family_meaning": "A family choosing Adah might value beauty, grace, and refinement. They might envision their child as someone who is elegant, kind, and brings beauty to the world.",
#         "likely_liked": [
#             "Ruth",
#             "Leah",
#             "Rachel",
#             "Sarah",
#             "Esther",
#             "Rebecca",
#             "Deborah",
#             "Hannah",
#             "Eve",
#             "Abigail"
#         ]
#     },
#     "Adair": {
#         "meaning": "from the ford of the river",
#         "origin": [
#             "Scottish",
#             "Irish"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "eɪ",
#                 "d",
#                 "eɪ",
#                 "r"
#             ],
#             "syllables": 2
#         },
#         "variants": [],
#         "famous": [],
#         "other_info": "Adair is a nature-inspired name with a strong and distinctive sound. It is a less common name, offering a unique and memorable choice for parents.",
#         "family_meaning": "A family choosing Adair might value strength, resilience, and a connection to nature. They might envision their child as someone who is adventurous, independent, and grounded.",
#         "likely_liked": [
#             "River",
#             "Brooks",
#             "Forrest",
#             "Hunter",
#             "Asher",
#             "Rowan",
#             "Rhys",
#             "Griffin",
#             "Liam",
#             "Owen"
#         ]
#     },
#     "Adalee": {
#         "meaning": "noble",
#         "origin": [
#             "German"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "æ",
#                 "d",
#                 "ə",
#                 "liː"
#             ],
#             "syllables": 2
#         },
#         "variants": [
#             "Adalie",
#             "Adalyn"
#         ],
#         "famous": [],
#         "other_info": "Adalee is a modern variation of a classic name, combining a traditional feel with a contemporary sound. It is a versatile name that can suit a variety of personalities.",
#         "family_meaning": "A family choosing Adalee likely values intelligence, creativity, and a strong sense of self. They might envision their child as someone who is innovative, independent, and makes a positive contribution to society.",
#         "likely_liked": [
#             "Audrey",
#             "Natalie",
#             "Madeline",
#             "Eleanor",
#             "Genevieve",
#             "Josephine",
#             "Scarlett",
#             "Violet",
#             "Lily",
#             "Rose"
#         ]
#     },
#     "Adaleigh": {
#         "meaning": "noble kind",
#         "origin": [
#             "German",
#             "English"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "æ",
#                 "d",
#                 "ə",
#                 "leɪ"
#             ],
#             "syllables": 3
#         },
#         "variants": [
#             "Adaline",
#             "Adalyn",
#             "Adaleigh"
#         ],
#         "famous": [],
#         "other_info": "Adaleigh is a modern and elegant name with a sweet and sophisticated sound. It is a relatively uncommon name, offering a unique and memorable choice for parents.",
#         "family_meaning": "A family choosing Adaleigh likely values kindness, compassion, and intelligence. They might envision their child as someone who is thoughtful, empathetic, and makes a positive impact on the world.",
#         "likely_liked": [
#             "Aubrey",
#             "Genevieve",
#             "Josephine",
#             "Eleanor",
#             "Madeline",
#             "Scarlett",
#             "Violet",
#             "Lily",
#             "Rose",
#             "Willow"
#         ]
#     },
#     "Adalia": {
#         "meaning": "noble",
#         "origin": [
#             "German"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "ə",
#                 "ˈdeɪliə"
#             ],
#             "syllables": 3
#         },
#         "variants": [
#             "Adaline",
#             "Adalyn",
#             "Adalie"
#         ],
#         "famous": [],
#         "other_info": "Adalia is a beautiful and elegant name with a classic feel. It is a versatile name that can suit a variety of personalities.",
#         "family_meaning": "A family choosing Adalia likely values intelligence, creativity, and a strong sense of self. They might envision their child as someone who is innovative, independent, and makes a positive contribution to society.",
#         "likely_liked": [
#             "Audrey",
#             "Natalie",
#             "Madeline",
#             "Eleanor",
#             "Genevieve",
#             "Josephine",
#             "Scarlett",
#             "Violet",
#             "Lily",
#             "Rose"
#         ]
#     },
#     "Adalie": {
#         "meaning": "noble",
#         "origin": [
#             "German"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "æ",
#                 "d",
#                 "ə",
#                 "liː"
#             ],
#             "syllables": 2
#         },
#         "variants": [
#             "Adalee",
#             "Adalyn"
#         ],
#         "famous": [],
#         "other_info": "Adalie is a modern and elegant name with a sweet and sophisticated sound. It is a relatively uncommon name, offering a unique and memorable choice for parents.",
#         "family_meaning": "A family choosing Adalie likely values intelligence, creativity, and a strong sense of self. They might envision their child as someone who is innovative, independent, and makes a positive contribution to society.",
#         "likely_liked": [
#             "Audrey",
#             "Natalie",
#             "Madeline",
#             "Eleanor",
#             "Genevieve",
#             "Josephine",
#             "Scarlett",
#             "Violet",
#             "Lily",
#             "Rose"
#         ]
#     },
#     "Adalina": {
#         "meaning": "noble",
#         "origin": [
#             "German"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "æ",
#                 "d",
#                 "ə",
#                 "liː",
#                 "n",
#                 "ə"
#             ],
#             "syllables": 3
#         },
#         "variants": [
#             "Adaline",
#             "Adalyn",
#             "Adalynn"
#         ],
#         "famous": [],
#         "other_info": "Adalina is a beautiful and elegant name with a classic feel. It is a versatile name that can suit a variety of personalities.",
#         "family_meaning": "A family choosing Adalina likely values intelligence, creativity, and a strong sense of self. They might envision their child as someone who is innovative, independent, and makes a positive contribution to society.",
#         "likely_liked": [
#             "Audrey",
#             "Natalie",
#             "Madeline",
#             "Eleanor",
#             "Genevieve",
#             "Josephine",
#             "Scarlett",
#             "Violet",
#             "Lily",
#             "Rose"
#         ]
#     },
#     "Adaline": {
#         "meaning": "noble",
#         "origin": [
#             "German"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "æ",
#                 "d",
#                 "ə",
#                 "laɪn"
#             ],
#             "syllables": 3
#         },
#         "variants": [
#             "Adalyn",
#             "Adalynn",
#             "Adalina",
#             "Ada"
#         ],
#         "famous": [],
#         "other_info": "Adaline is a classic name with a timeless elegance. It is a versatile name that can suit a variety of personalities.",
#         "family_meaning": "A family choosing Adaline likely values intelligence, creativity, and a strong sense of self. They might envision their child as someone who is innovative, independent, and makes a positive contribution to society.",
#         "likely_liked": [
#             "Audrey",
#             "Natalie",
#             "Madeline",
#             "Eleanor",
#             "Genevieve",
#             "Josephine",
#             "Scarlett",
#             "Violet",
#             "Lily",
#             "Rose"
#         ]
#     },
#     "Adalyn": {
#         "meaning": "noble",
#         "origin": [
#             "German"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "æ",
#                 "d",
#                 "ə",
#                 "laɪn"
#             ],
#             "syllables": 2
#         },
#         "variants": [
#             "Adaline",
#             "Adalynn",
#             "Adalina",
#             "Adalee"
#         ],
#         "famous": [],
#         "other_info": "Adalyn is a modern and elegant name with a sweet and sophisticated sound. It is a relatively uncommon name, offering a unique and memorable choice for parents.",
#         "family_meaning": "A family choosing Adalyn likely values intelligence, creativity, and a strong sense of self. They might envision their child as someone who is innovative, independent, and makes a positive contribution to society.",
#         "likely_liked": [
#             "Audrey",
#             "Natalie",
#             "Madeline",
#             "Eleanor",
#             "Genevieve",
#             "Josephine",
#             "Scarlett",
#             "Violet",
#             "Lily",
#             "Rose"
#         ]
#     },
#     "Adalynn": {
#         "meaning": "noble",
#         "origin": [
#             "German"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "æ",
#                 "d",
#                 "ə",
#                 "lɪn"
#             ],
#             "syllables": 2
#         },
#         "variants": [
#             "Adaline",
#             "Adalyn",
#             "Adalina"
#         ],
#         "famous": [],
#         "other_info": "Adalynn is a modern and elegant name with a sweet and sophisticated sound. It is a relatively uncommon name, offering a unique and memorable choice for parents.",
#         "family_meaning": "A family choosing Adalynn likely values intelligence, creativity, and a strong sense of self. They might envision their child as someone who is innovative, independent, and makes a positive contribution to society.",
#         "likely_liked": [
#             "Audrey",
#             "Natalie",
#             "Madeline",
#             "Eleanor",
#             "Genevieve",
#             "Josephine",
#             "Scarlett",
#             "Violet",
#             "Lily",
#             "Rose"
#         ]
#     },
#     "Adam": {
#         "meaning": "earthly",
#         "origin": [
#             "Hebrew"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "æ",
#                 "d",
#                 "əm"
#             ],
#             "syllables": 1
#         },
#         "variants": [
#             "Adham",
#             "Adem"
#         ],
#         "famous": [
#             "Adam Sandler - American actor and comedian",
#             "Adam Levine - American singer and songwriter",
#             "Adam Driver - American actor"
#         ],
#         "other_info": "Adam is a classic and timeless name with biblical origins. It is a popular and versatile name that suits a variety of personalities.",
#         "family_meaning": "A family choosing Adam likely values strength, kindness, and a strong sense of self. They might envision their child as someone who is grounded, compassionate, and makes a positive impact on the world.",
#         "likely_liked": [
#             "Noah",
#             "Liam",
#             "William",
#             "James",
#             "Oliver",
#             "Benjamin",
#             "Elijah",
#             "Lucas",
#             "Henry",
#             "Alexander"
#         ]
#     },
#     "Adamari": {
#         "meaning": "my earth",
#         "origin": [
#             "Hebrew",
#             "Spanish"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "æ",
#                 "d",
#                 "ə",
#                 "m",
#                 "ɑː",
#                 "riː"
#             ],
#             "syllables": 3
#         },
#         "variants": [],
#         "famous": [
#             "Adamari López - Puerto Rican actress and television host"
#         ],
#         "other_info": "Adamari is a unique and beautiful name with a blend of Hebrew and Spanish influences. It is a less common name, offering a distinctive and memorable choice for parents.",
#         "family_meaning": "A family choosing Adamari likely values family, tradition, and a strong sense of heritage. They might envision their child as someone who is warm, loving, and connected to their roots.",
#         "likely_liked": [
#             "Sofia",
#             "Isabella",
#             "Camila",
#             "Valentina",
#             "Gabriela",
#             "Selena",
#             "Ariana",
#             "Maria",
#             "Elena",
#             "Olivia"
#         ]
#     },
#     "Adamaris": {
#         "meaning": "my earth",
#         "origin": [
#             "Hebrew",
#             "Spanish"
#         ],
#         "sound_details": {
#             "phonemes": [
#                 "æ",
#                 "d",
#                 "ə",
#                 "m",
#                 "ɑː",
#                 "rɪs"
#             ],
#             "syllables": 3
#         },
#         "variants": [],
#         "famous": [],
#         "other_info": "Adamaris is a unique and beautiful name with a blend of Hebrew and Spanish influences. It is a less common name, offering a distinctive and memorable choice for parents.",
#         "family_meaning": "A family choosing Adamaris likely values family, tradition, and a strong sense of heritage. They might envision their child as someone who is warm, loving, and connected to their roots.",
#         "likely_liked": [
#             "Sofia",
#             "Isabella",
#             "Camila",
#             "Valentina",
#             "Gabriela",
#             "Selena",
#             "Ariana",
#             "Maria",
#             "Elena",
#             "Olivia"
#         ]
#     }
# }
# Saving pretty JSON to ../data/generated/cleaned/G_A3_clean.json
# Saved pretty JSON to ../data/generated/cleaned/G_A3_clean.json
# Processed and saved: ../data/generated/cleaned/G_A3_clean.json

# %% [markdown]
# In case there were invalid JSONs or you hit any quotas, you can run the following cell to check which and how many lists are pending the data generation yet. This function will return a list with all sublists pending a valid generation.

# %%
process_remaining_girl_names('../data/generated/cleaned', all_girl_names_list)
# Out:
# Created lists start with names: {'Aadhya', 'Abygail', 'Abbie'}
# Remaining lists start with names: [['Adara', 'Addalyn', 'Addalynn', 'Addelyn', 'Addie', 'Addilyn', 'Addilynn', 'Addisen', 'Addison', 'Addisyn', 'Addy', 'Addysen', 'Addyson', 'Adel', 'Adela', 'Adelaida'], ['Adelaide', 'Adele', 'Adelene', 'Adelia', 'Adelina', 'Adeline', 'Adelita', 'Adell', 'Adella', 'Adelle', 'Adelyn', 'Adelynn', 'Adena', 'Adia', 'Adilene', 'Adilyn'], ['Adilynn', 'Adina', 'Adison', 'Adisyn', 'Aditi', 'Adley', 'Adline', 'Adora', 'Adreanna', 'Adria', 'Adrian', 'Adriana', 'Adriane', 'Adrianna', 'Adrianne', 'Adrien'], ['Adriene', 'Adrienne', 'Adrina', 'Adyson', 'Aerial', 'Aeris', 'Aeryn', 'Africa', 'Afton', 'Agatha', 'Aggie', 'Agnes', 'Agustina', 'Ahna', 'Ahsley', 'Ahtziri'], ['Ahuva', 'Aida', 'Aidan', 'Aide', 'Aiden', 'Aiesha', 'Aiko', 'Aila', 'Ailani', 'Aileen', 'Ailene', 'Aili', 'Ailyn', 'Aime', 'Aimee', 'Aine'], ['Ainslee', 'Ainsley', 'Aisha', 'Aishah', 'Aislin', 'Aisling', 'Aislinn', 'Aislyn', 'Aislynn', 'Aitana', 'Aixa', 'Aiyana', 'Aiyanna', 'Aiza', 'Aja', 'Ajah'], ['Akasha', 'Akayla', 'Akeelah', 'Akia', 'Akilah', 'Akira', 'Akshara', 'Alaa', 'Alaia', 'Alaina', 'Alaine', 'Alan', 'Alana', 'Alanah', 'Alane', 'Alani'], ['Alanis', 'Alanna', 'Alannah', 'Alasia', 'Alaura', 'Alaya', 'Alayah', 'Alayla', 'Alayna', 'Alayne', 'Alaysha', 'Alaysia', 'Alba', 'Albert', 'Alberta', 'Albertha'], ['Albertina', 'Albertine', 'Albina', 'Alda', 'Alea', 'Aleah', 'Alean', 'Alease', 'Aleasha', 'Alecia', 'Aleda', 'Aleeah', 'Aleen', 'Aleena', 'Aleesha', 'Aleeya'], ['Aleeyah', 'Aleeza', 'Aleia', 'Aleida', 'Aleigha', 'Aleisha', 'Alejandra', 'Alejandrina', 'Aleksandra', 'Alena', 'Alene', 'Alesha', 'Aleshia', 'Alesia', 'Alessa', 'Alessandra'], ['Alessia', 'Aleta', 'Aletha', 'Alethea', 'Alethia', 'Alex', 'Alexa', 'Alexander', 'Alexandra', 'Alexandrea', 'Alexandria', 'Alexcia', 'Alexi', 'Alexia', 'Alexie', 'Alexis'], ['Alexius', 'Alexsandra', 'Alexsis', 'Alexus', 'Alexxis', 'Alexys', 'Alexzandra', 'Alexzandria', 'Aleya', 'Aleyah', 'Aleyda', 'Aleyna', 'Alfred', 'Alfreda', 'Alfredia', 'Ali'], ['Alia', 'Aliah', 'Aliana', 'Alianna', 'Alica', 'Alice', 'Alicea', 'Alicen', 'Alicia', 'Alida', 'Alijah', 'Alina', 'Aline', 'Alisa', 'Alise', 'Alisha'], ['Alishia', 'Alisia', 'Alison', 'Alissa', 'Alisson', 'Alita', 'Alivia', 'Alix', 'Alixandra', 'Aliya', 'Aliyah', 'Aliyana', 'Aliza', 'Alizabeth', 'Alize', 'Alla'], ['Allana', 'Allean', 'Allee', 'Allegra', 'Allen', 'Allena', 'Allene', 'Alli', 'Allie', 'Alline', 'Allisa', 'Allison', 'Allissa', 'Allisson', 'Alliyah', 'Ally'], ['Allyn', 'Allysa', 'Allyson', 'Allyssa', 'Alma', 'Almeda', 'Almeta', 'Almira', 'Alona', 'Alondra', 'Alonna', 'Alora', 'Alpha', 'Alta', 'Altha', 'Althea'], ['Alva', 'Alvena', 'Alvera', 'Alverta', 'Alvin', 'Alvina', 'Aly', 'Alya', 'Alyah', 'Alyana', 'Alyanna', 'Alyce', 'Alycia', 'Alyna', 'Alys', 'Alysa'], ['Alyse', 'Alysha', 'Alyshia', 'Alysia', 'Alyson', 'Alyssa', 'Alysse', 'Alyssia', 'Alysson', 'Alyvia', 'Alyx', 'Alyza', 'Amada', 'Amaia', 'Amairani', 'Amairany'], ['Amaiya', 'Amal', 'Amalia', 'Amalie', 'Amanda', 'Amani', 'Amara', 'Amarah', 'Amari', 'Amaria', 'Amariah', 'Amarie', 'Amaris', 'Amaryllis', 'Amaya', 'Amayah'], ['Ambar', 'Amber', 'Amberlee', 'Amberly', 'Amberlyn', 'Amberlynn', 'Ambria', 'Ambrosia', 'Amee', 'Ameena', 'Ameera', 'Ameerah', 'Amelia', 'Amelie', 'America', 'Amerie'], ['Amethyst', 'Ami', 'Amia', 'Amiah', 'Amie', 'Amiee', 'Amilia', 'Amina', 'Aminah', 'Aminata', 'Amira', 'Amiracle', 'Amirah', 'Amity', 'Amiya', 'Amiyah'], ['Ammie', 'Ammy', 'Amna', 'Amoni', 'Amor', 'Amora', 'Amparo', 'Amrita', 'Amy', 'Amya', 'Amyah', 'Amyra', 'An', 'Ana', 'Anabel', 'Anabell'], ['Anabella', 'Anabelle', 'Anahi', 'Anahy', 'Anai', 'Anaiah', 'Anais', 'Anaiya', 'Anaiyah', 'Analeah', 'Analee', 'Analeigh', 'Anali', 'Analia', 'Analicia', 'Analiese'], ['Analisa', 'Analise', 'Analy', 'Anamaria', 'Anamarie', 'Ananda', 'Ananya', 'Anastacia', 'Anastasia', 'Anaya', 'Anayah', 'Anayeli', 'Andee', 'Andi', 'Andie', 'Andra'], ['Andraya', 'Andre', 'Andrea', 'Andreana', 'Andree', 'Andreina', 'Andrew', 'Andreya',  ...
# Total girl names yet to generate data for: 433
# Repeated names and their corresponding files:
# [['Adara',
#   'Addalyn',
#   'Addalynn',
#   'Addelyn',
#   'Addie',
#   'Addilyn',
#   'Addilynn',
#   'Addisen',
#   'Addison',
#   'Addisyn',
#   'Addy',
#   'Addysen',
#   'Addyson',
#   'Adel',
#   'Adela',
#   'Adelaida'],
#  ['Adelaide',
#   'Adele',
#   'Adelene',
#   'Adelia',
#   'Adelina',
#   'Adeline',
#   'Adelita',
#   'Adell',
#   'Adella',
#   'Adelle',
#   'Adelyn',
#   'Adelynn',
#   'Adena',
#   'Adia',
#   'Adilene',
#   'Adilyn'],
#  ['Adilynn',
#   'Adina',
#   'Adison',
#   'Adisyn',
#   'Aditi',
#   'Adley',
#   'Adline',
#   'Adora',
#   'Adreanna',
#   'Adria',
#   'Adrian',
#   'Adriana',
#   'Adriane',
#   'Adrianna',
#   'Adrianne',
#   'Adrien'],
#  ['Adriene',
#   'Adrienne',
#   'Adrina',
#   'Adyson',
#   'Aerial',
#   'Aeris',
#   'Aeryn',
#   'Africa',
#   'Afton',
#   'Agatha',
#   'Aggie',
#   'Agnes',
#   'Agustina',
#   'Ahna',
#   'Ahsley',
#   'Ahtziri'],
#  ['Ahuva',
#   'Aida',
#   'Aidan',
#   'Aide',
#   'Aiden',
#   'Aiesha',
#   'Aiko',
#   'Aila',
#   'Ailani',
#   'Aileen',
#   'Ailene',
#   'Aili',
#   'Ailyn',
#   'Aime',
#   'Aimee',
#   'Aine'],
#  ['Ainslee',
#   'Ainsley',
#   'Aisha',
#   'Aishah',
#   'Aislin',
#   'Aisling',
#   'Aislinn',
#   'Aislyn',
#   'Aislynn',
#   'Aitana',
#   'Aixa',
#   'Aiyana',
#   'Aiyanna',
#   'Aiza',
#   'Aja',
#   'Ajah'],
#  ['Akasha',
#   'Akayla',
#   'Akeelah',
#   'Akia',
#   'Akilah',
#   'Akira',
#   'Akshara',
#   'Alaa',
#   'Alaia',
#   'Alaina',
#   'Alaine',
#   'Alan',
#   'Alana',
#   'Alanah',
#   'Alane',
#   'Alani'],
#  ['Alanis',
#   'Alanna',
#   'Alannah',
#   'Alasia',
#   'Alaura',
#   'Alaya',
#   'Alayah',
#   'Alayla',
#   'Alayna',
#   'Alayne',
#   'Alaysha',
#   'Alaysia',
#   'Alba',
#   'Albert',
#   'Alberta',
#   'Albertha'],
#  ['Albertina',
#   'Albertine',
#   'Albina',
#   'Alda',
#   'Alea',
#   'Aleah',
#   'Alean',
#   'Alease',
#   'Aleasha',
#   'Alecia',
#   'Aleda',
#   'Aleeah',
#   'Aleen',
#   'Aleena',
#   'Aleesha',
#   'Aleeya'],
#  ['Aleeyah',
#   'Aleeza',
#   'Aleia',
#   'Aleida',
#   'Aleigha',
#   'Aleisha',
#   'Alejandra',
#   'Alejandrina',
#   'Aleksandra',
#   'Alena',
#   'Alene',
#   'Alesha',
#   'Aleshia',
#   'Alesia',
#   'Alessa',
#   'Alessandra'],
#  ['Alessia',
#   'Aleta',
#   'Aletha',
#   'Alethea',
#   'Alethia',
#   'Alex',
#   'Alexa',
#   'Alexander',
#   'Alexandra',
#   'Alexandrea',
#   'Alexandria',
#   'Alexcia',
#   'Alexi',
#   'Alexia',
#   'Alexie',
#   'Alexis'],
#  ['Alexius',
#   'Alexsandra',
#   'Alexsis',
#   'Alexus',
#   'Alexxis',
#   'Alexys',
#   'Alexzandra',
#   'Alexzandria',
#   'Aleya',
#   'Aleyah',
#   'Aleyda',
#   'Aleyna',
#   'Alfred',
#   'Alfreda',
#   'Alfredia',
#   'Ali'],
#  ['Alia',
#   'Aliah',
#   'Aliana',
#   'Alianna',
#   'Alica',
#   'Alice',
#   'Alicea',
#   'Alicen',
#   'Alicia',
#   'Alida',
#   'Alijah',
#   'Alina',
#   'Aline',
#   'Alisa',
#   'Alise',
#   'Alisha'],
#  ['Alishia',
#   'Alisia',
#   'Alison',
#   'Alissa',
#   'Alisson',
#   'Alita',
#   'Alivia',
#   'Alix',
#   'Alixandra',
#   'Aliya',
#   'Aliyah',
#   'Aliyana',
#   'Aliza',
#   'Alizabeth',
#   'Alize',
#   'Alla'],
#  ['Allana',
#   'Allean',
#   'Allee',
#   'Allegra',
#   'Allen',
#   'Allena',
#   'Allene',
#   'Alli',
#   'Allie',
#   'Alline',
#   'Allisa',
#   'Allison',
#   'Allissa',
#   'Allisson',
#   'Alliyah',
#   'Ally'],
#  ['Allyn',
#   'Allysa',
#   'Allyson',
#   'Allyssa',
#   'Alma',
#   'Almeda',
#   'Almeta',
#   'Almira',
#   'Alona',
#   'Alondra',
#   'Alonna',
#   'Alora',
#   'Alpha',
#   'Alta',
#   'Altha',
#   'Althea'],
#  ['Alva',
#   'Alvena',
#   'Alvera',
#   'Alverta',
#   'Alvin',
#   'Alvina',
#   'Aly',
#   'Alya',
#   'Alyah',
#   'Alyana',
#   'Alyanna',
#   'Alyce',
#   'Alycia',
#   'Alyna',
#   'Alys',
#   'Alysa'],
#  ['Alyse',
#   'Alysha',
#   'Alyshia',
#   'Alysia',
#   'Alyson',
#   'Alyssa',
#   'Alysse',
#   'Alyssia',
#   'Alysson',
#   'Alyvia',
#   'Alyx',
#   'Alyza',
#   'Amada',
#   'Amaia',
#   'Amairani',
#   'Amairany'],
#  ['Amaiya',
#   'Amal',
#   'Amalia',
#   'Amalie',
#   'Amanda',
#   'Amani',
#   'Amara',
#   'Amarah',
#   'Amari',
#   'Amaria',
#   'Amariah',
#   'Amarie',
#   'Amaris',
#   'Amaryllis',
#   'Amaya',
#   'Amayah'],
#  ['Ambar',
#   'Amber',
#   'Amberlee',
#   'Amberly',
#   'Amberlyn',
#   'Amberlynn',
#   'Ambria',
#   'Ambrosia',
#   'Amee',
#   'Ameena',
#   'Ameera',
#   'Ameerah',
#   'Amelia',
#   'Amelie',
#   'America',
#   'Amerie'],
#  ['Amethyst',
#   'Ami',
#   'Amia',
#   'Amiah',
#   'Amie',
#   'Amiee',
#   'Amilia',
#   'Amina',
#   'Aminah',
#   'Aminata',
#   'Amira',
#   'Amiracle',
#   'Amirah',
#   'Amity',
#   'Amiya',
#   'Amiyah'],
#  ['Ammie',
#   'Ammy',
#   'Amna',
#   'Amoni',
#   'Amor',
#   'Amora',
#   'Amparo',
#   'Amrita',
#   'Amy',
#   'Amya',
#   'Amyah',
#   'Amyra',
#   'An',
#   'Ana',
#   'Anabel',
#   'Anabell'],
#  ['Anabella',
#   'Anabelle',
#   'Anahi',
#   'Anahy',
#   'Anai',
#   'Anaiah',
#   'Anais',
#   'Anaiya',
#   'Anaiyah',
#   'Analeah',
#   'Analee',
#   'Analeigh',
#   'Anali',
#   'Analia',
#   'Analicia',
#   'Analiese'],
#  ['Analisa',
#   'Analise',
#   'Analy',
#   'Anamaria',
#   'Anamarie',
#   'Ananda',
#   'Ananya',
#   'Anastacia',
#   'Anastasia',
#   'Anaya',
#   'Anayah',
#   'Anayeli',
#   'Andee',
#   'Andi',
#   'Andie',
#   'Andra'],
#  ['Andraya',
#   'Andre',
#   'Andrea',
#   'Andreana',
#   'Andree',
#   'Andreina',
#   'Andrew',
#   'Andreya',
#   'Andria',
#   'Andriana',
#   'Andy',
#   'Aneesa',
#   'Anel',
#   'Anela',
#   'Anessa',
#   'Anette'],
#  ['Angel',
#   'Angela',
#   'Angele',
#   'Angelea',
#   'Angelee',
#   'Angelena',
#   'Angelene',
#   'Angeles',
#   'Angeli',
#   'Angelia',
#   'Angelic',
#   'Angelica',
#   'Angelie',
#   'Angelika',
#   'Angelina',
#   'Angeline'],
#  ['Angelique',
#   'Angelita',
#   'Angella',
#   'Angelle',
#   'Angely',
#   'Angelyn',
#   'Angie',
#   'Angle',
#   'Anglea',
#   'Anh',
#   'Ani',
#   'Ania',
#   'Aniah',
#   'Anica',
#   'Anice',
#   'Anijah'],
#  ['Anika',
#   'Anisa',
#   'Anise',
#   'Anisha',
#   'Anissa',
#   'Aniston',
#   'Anita',
#   'Anitra',
#   'Aniya',
#   'Aniyah',
#   'Anja',
#   'Anjali',
#   'Anjanette',
#   'Anjelica',
#   'Ann',
#   'Anna'],
#  ['Annabel',
#   'Annabell',
#   'Annabella',
#   'Annabelle',
#   'Annabeth',
#   'Annah',
#   'Annalee',
#   'Annaleigh',
#   'Annaliese',
#   'Annalisa',
#   'Annalise',
#   'Annalyn',
#   'Annalynn',
#   'Annalyse',
#   'Annamae',
#   'Annamaria'],
#  ['Annamarie',
#   'Annastasia',
#   'Anne',
#   'Anneliese',
#   'Annelise',
#   'Annelle',
#   'Annemarie',
#   'Anner',
#   'Annett',
#   'Annetta',
#   'Annette',
#   'Annice',
#   'Annie',
#   'Annika',
#   'Annis',
#   'Annissa'],
#  ['Anniston',
#   'Annita',
#   'Annmarie',
#   'Anny',
#   'Anslee',
#   'Ansleigh',
#   'Ansley',
#   'Anthea',
#   'Anthony',
#   'Antionette',
#   'Antoinette',
#   'Antonella',
#   'Antonetta',
#   'Antonette',
#   'Antonia',
#   'Antonietta'],
#  ['Antonina',
#   'Antonio',
#   'Anusha',
#   'Anushka',
#   'Anya',
#   'Anyah',
#   'Anyla',
#   'Anylah',
#   'Anyssa',
#   'Aoife',
#   'Apolonia',
#   'April',
#   'Apryl',
#   'Aquilla',
#   'Ara',
#   'Arabella'],
#  ['Arabelle',
#   'Araceli',
#   'Aracelis',
#   'Aracely',
#   'Aranza',
#   'Araseli',
#   'Araya',
#   'Arbutus',
#   'Arcelia',
#   'Archie',
#   'Ardath',
#   'Ardelia',
#   'Ardell',
#   'Ardella',
#   'Ardelle',
#   'Arden'],
#  ['Ardeth',
#   'Ardis',
#   'Ardith',
#   'Ardyce',
#   'Areli',
#   'Arely',
#   'Aretha',
#   'Aretta',
#   'Ari',
#   'Aria',
#   'Ariadna',
#   'Ariadne',
#   'Ariah',
#   'Arial',
#   'Arian',
#   'Ariana'],
#  ['Ariane',
#   'Arianna',
#   'Arianne',
#   'Arianny',
#   'Arica',
#   'Arie',
#   'Arieanna',
#   'Ariel',
#   'Ariela',
#   'Ariella',
#   'Arielle',
#   'Aries',
#   'Arika',
#   'Arin',
#   'Arionna',
#   'Aris'],
#  ['Arissa',
#   'Ariya',
#   'Ariyah',
#   'Ariyana',
#   'Ariyanna',
#   'Arizona',
#   'Arla',
#   'Arlean',
#   'Arlee',
#   'Arleen',
#   'Arlena',
#   'Arlene',
#   'Arlet',
#   'Arleta',
#   'Arleth',
#   'Arletha'],
#  ['Arletta',
#   'Arlette',
#   'Arlie',
#   'Arlinda',
#   'Arline',
#   'Arlyn',
#   'Arlyne',
#   'Arlys',
#   'Armanda',
#   'Armani',
#   'Armida',
#   'Arminda',
#   'Armoni',
#   'Arnetta',
#   'Arnette',
#   'Arnita'],
#  ['Arriana',
#   'Arrianna',
#   'Arrie',
#   'Artemis',
#   'Arthur',
#   'Artie',
#   'Arvella',
#   'Arvilla',
#   'Arwen',
#   'Arya',
#   'Aryah',
#   'Aryana',
#   'Aryanna',
#   'Aryn',
#   'Asa',
#   'Asha'],
#  ['Ashante',
#   'Ashanti',
#   'Ashely',
#   'Ashia',
#   'Ashlan',
#   'Ashlea',
#   'Ashlee',
#   'Ashlei',
#   'Ashleigh',
#   'Ashlen',
#   'Ashley',
#   'Ashli',
#   'Ashlie',
#   'Ashlin',
#   'Ashly',
#   'Ashlyn'],
#  ['Ashlynn',
#   'Ashlynne',
#   'Ashten',
#   'Ashtin',
#   'Ashton',
#   'Ashtyn',
#   'Asia',
#   'Asiah',
#   'Asiya',
#   'Asiyah',
#   'Asma',
#   'Aspen',
#   'Aspyn',
#   'Assunta',
#   'Astrid',
#   'Asya'],
#  ['Atha',
#   'Athena',
#   'Atiya',
#   'Aubree',
#   'Aubreigh',
#   'Aubrey',
#   'Aubri',
#   'Aubriana',
#   'Aubrianna',
#   'Aubrie',
#   'Aubriella',
#   'Aubrielle',
#   'Aubry',
#   'Auburn',
#   'Audie',
#   'Audra'],
#  ['Audrea',
#   'Audree',
#   'Audrey',
#   'Audri',
#   'Audria',
#   'Audriana',
#   'Audrianna',
#   'Audrie',
#   'Audrina',
#   'Audry',
#   'August',
#   'Augusta',
#   'Augustina',
#   'Augustine',
#   'Aundrea',
#   'Aura'],
#  ['Aurea',
#   'Aurelia',
#   'Aurora',
#   'Austin',
#   'Austyn',
#   'Autum',
#   'Autumn',
#   'Ava',
#   'Avah',
#   'Avalee',
#   'Avalon',
#   'Avalyn',
#   'Avalynn',
#   'Avani',
#   'Avarie',
#   'Avary'],
#  ['Avaya',
#   'Avelina',
#   'Aven',
#   'Averi',
#   'Averie',
#   'Avery',
#   'Avia',
#   'Aviana',
#   'Avianna',
#   'Avie',
#   'Avigail',
#   'Avis',
#   'Aviva',
#   'Avneet',
#   'Avni',
#   'Avril'],
#  ['Awilda',
#   'Aya',
#   'Ayah',
#   'Ayana',
#   'Ayanna',
#   'Ayden',
#   'Ayesha',
#   'Ayla',
#   'Aylah',
#   'Ayleen',
#   'Aylin',
#   'Ayonna',
#   'Aysha',
#   'Aysia',
#   'Ayva',
#   'Ayvah'],
#  ['Azalea',
#   'Azalee',
#   'Azalia',
#   'Azaria',
#   'Azariah',
#   'Azia',
#   'Aziyah',
#   'Aziza',
#   'Azucena',
#   'Azul',
#   'Azure',
#   'Babette',
#   'Baby',
#   'Babygirl',
#   'Baila',
#   'Bailee'],
#  ['Baileigh',
#   'Bailey',
#   'Bailie',
#   'Baily',
#   'Baleigh',
#   'Bambi',
#   'Barb',
#   'Barbara',
#   'Barbie',
#   'Barbra',
#   'Bari',
#   'Barrie',
#   'Batsheva',
#   'Baylee',
#   'Bayleigh',
#   'Bayley'],
#  ['Bayli',
#   'Baylie',
#   'Baylor',
#   'Bea',
#   'Beatrice',
#   'Beatris',
#   'Beatrix',
#   'Beatriz',
#   'Beaulah',
#   'Bebe',
#   'Becca',
#   'Becki',
#   'Beckie',
#   'Becky',
#   'Belen',
#   'Belia'],
#  ['Belinda',
#   'Bell',
#   'Bella',
#   'Bellamy',
#   'Belle',
#   'Belva',
#   'Benita',
#   'Benjamin',
#   'Bennett',
#   'Bennie',
#   'Bentley',
#   'Berdie',
#   'Berenice',
#   'Berkeley',
#   'Berkley',
#   'Berlin'],
#  ['Berna',
#   'Bernadette',
#   'Bernadine',
#   'Bernardine',
#   'Berneice',
#   'Bernetta',
#   'Bernice',
#   'Bernie',
#   'Berniece',
#   'Bernita',
#   'Beronica',
#   'Berta',
#   'Bertha',
#   'Bertie',
#   'Bertina',
#   'Beryl'],
#  ['Bess',
#   'Bessie',
#   'Beth',
#   'Bethani',
#   'Bethanie',
#   'Bethann',
#   'Bethanne',
#   'Bethany',
#   'Bethel',
#   'Betina',
#   'Betsey',
#   'Betsy',
#   'Bette',
#   'Bettie',
#   'Bettina',
#   'Betty'],
#  ['Bettyann',
#   'Bettye',
#   'Bettylou',
#   'Betzaida',
#   'Beula',
#   'Beulah',
#   'Beverlee',
#   'Beverley',
#   'Beverly',
#   'Bevin',
#   'Bexley',
#   'Beyonce',
#   'Bianca',
#   'Bianka',
#   'Bibiana',
#   'Billi'],
#  ['Billie',
#   'Billiejo',
#   'Billy',
#   'Billye',
#   'Bina',
#   'Birdie',
#   'Birtha',
#   'Blaine',
#   'Blair',
#   'Blaire',
#   'Blake',
#   'Blakely',
#   'Blanca',
#   'Blanch',
#   'Blanche',
#   'Blanchie'],
#  ['Blenda',
#   'Blessing',
#   'Blima',
#   'Bliss',
#   'Blondell',
#   'Blossom',
#   'Blythe',
#   'Bobbi',
#   'Bobbie',
#   'Bobbiejo',
#   'Bobbijo',
#   'Bobby',
#   'Bobbye',
#   'Bobette',
#   'Bonita',
#   'Bonna'],
#  ['Bonni',
#   'Bonnie',
#   'Bonny',
#   'Bracha',
#   'Bradley',
#   'Brady',
#   'Braelyn',
#   'Braelynn',
#   'Branda',
#   'Brande',
#   'Brandee',
#   'Brandi',
#   'Brandice',
#   'Brandie',
#   'Brandon',
#   'Brandy'],
#  ['Braylee',
#   'Brayleigh',
#   'Braylin',
#   'Braylynn',
#   'Brea',
#   'Breana',
#   'Breann',
#   'Breanna',
#   'Breanne',
#   'Breasia',
#   'Breauna',
#   'Bree',
#   'Breeana',
#   'Breeann',
#   'Breeanna',
#   'Breelyn'],
#  ['Brenda',
#   'Brenna',
#   'Brennan',
#   'Breona',
#   'Breonna',
#   'Brett',
#   'Breyana',
#   'Breyanna',
#   'Bria',
#   'Briahna',
#   'Brian',
#   'Briana',
#   'Brianda',
#   'Briann',
#   'Brianna',
#   'Briannah'],
#  ['Brianne',
#   'Briar',
#   'Briauna',
#   'Bridget',
#   'Bridgett',
#   'Bridgette',
#   'Bridgit',
#   'Brie',
#   'Brieana',
#   'Brieanna',
#   'Briella',
#   'Brielle',
#   'Brienna',
#   'Brienne',
#   'Brigette',
#   'Brighton'],
#  ['Brigid',
#   'Brigit',
#   'Brigitte',
#   'Brilee',
#   'Briley',
#   'Brina',
#   'Brinda',
#   'Brinkley',
#   'Brinlee',
#   'Brinley',
#   'Briona',
#   'Brionna',
#   'Brisa',
#   'Briseida',
#   'Briseis',
#   'Briseyda'],
#  ['Brissa',
#   'Bristol',
#   'Brita',
#   'Britani',
#   'Britany',
#   'Britnee',
#   'Britney',
#   'Britni',
#   'Britnie',
#   'Britny',
#   'Britt',
#   'Britta',
#   'Brittaney',
#   'Brittani',
#   'Brittanie',
#   'Brittany'],
#  ['Britteny',
#   'Brittnay',
#   'Brittnee',
#   'Brittney',
#   'Brittni',
#   'Brittnie',
#   'Brittny',
#   'Britton',
#   'Briza',
#   'Bronte',
#   'Bronwen',
#   'Bronwyn',
#   'Brook',
#   'Brooke',
#   'Brookelyn',
#   'Brookelynn'],
#  ['Brooklin',
#   'Brooklyn',
#   'Brooklynn',
#   'Brooklynne',
#   'Brooks',
#   'Bruce',
#   'Brunilda',
#   'Bryan',
#   'Bryana',
#   'Bryanna',
#   'Bryanne',
#   'Bryce',
#   'Brylee',
#   'Bryleigh',
#   'Brylie',
#   'Bryn'],
#  ['Bryna',
#   'Brynlee',
#   'Brynleigh',
#   'Brynley',
#   'Brynn',
#   'Brynna',
#   'Brynne',
#   'Buelah',
#   'Buffy',
#   'Bula',
#   'Bulah',
#   'Bunny',
#   'Burnice',
#   'Cadence',
#   'Cady',
#   'Caelyn'],
#  ['Caidence',
#   'Caila',
#   'Cailee',
#   'Caileigh',
#   'Cailey',
#   'Cailin',
#   'Cailyn',
#   'Cailynn',
#   'Caitlan',
#   'Caitlin',
#   'Caitlyn',
#   'Caitlynn',
#   'Calandra',
#   'Caleigh',
#   'Caley',
#   'Cali'],
#  ['Calie',
#   'Calista',
#   'Caliyah',
#   'Calla',
#   'Callan',
#   'Calleigh',
#   'Calli',
#   'Callie',
#   'Calliope',
#   'Callista',
#   'Cally',
#   'Calvin',
#   'Cambree',
#   'Cambria',
#   'Cambrie',
#   'Camden'],
#  ['Camdyn',
#   'Camelia',
#   'Camella',
#   'Camellia',
#   'Cameo',
#   'Cameron',
#   'Cameryn',
#   'Cami',
#   'Camie',
#   'Camila',
#   'Camilla',
#   'Camille',
#   'Camillia',
#   'Camisha',
#   'Cammie',
#   'Cammy'],
#  ['Campbell',
#   'Camry',
#   'Camryn',
#   'Candace',
#   'Candance',
#   'Candelaria',
#   'Candi',
#   'Candice',
#   'Candida',
#   'Candie',
#   'Candis',
#   'Candise',
#   'Candra',
#   'Candy',
#   'Candyce',
#   'Capri'],
#  ['Caprice',
#   'Cara',
#   'Caralyn',
#   'Caren',
#   'Caressa',
#   'Carey',
#   'Cari',
#   'Caridad',
#   'Carie',
#   'Carin',
#   'Carina',
#   'Caris',
#   'Carisa',
#   'Carissa',
#   'Carita',
#   'Carl'],
#  ['Carla',
#   'Carlee',
#   'Carleen',
#   'Carleigh',
#   'Carlena',
#   'Carlene',
#   'Carletta',
#   'Carlette',
#   'Carley',
#   'Carli',
#   'Carlie',
#   'Carlin',
#   'Carlina',
#   'Carline',
#   'Carlisa',
#   'Carlita'],
#  ['Carlos',
#   'Carlota',
#   'Carlotta',
#   'Carly',
#   'Carlye',
#   'Carlyn',
#   'Carma',
#   'Carman',
#   'Carmel',
#   'Carmela',
#   'Carmelina',
#   'Carmelita',
#   'Carmella',
#   'Carmen',
#   'Carmina',
#   'Carmon'],
#  ['Carol',
#   'Carola',
#   'Carolann',
#   'Carolanne',
#   'Carole',
#   'Carolee',
#   'Carolin',
#   'Carolina',
#   'Caroline',
#   'Caroll',
#   'Carolyn',
#   'Carolyne',
#   'Carolynn',
#   'Carolynne',
#   'Caron',
#   'Carra'],
#  ['Carri',
#   'Carrie',
#   'Carrigan',
#   'Carrington',
#   'Carrissa',
#   'Carrol',
#   'Carroll',
#   'Carry',
#   'Carson',
#   'Carsyn',
#   'Carter',
#   'Cary',
#   'Caryl',
#   'Caryn',
#   'Carys',
#   'Casandra'],
#  ['Casey',
#   'Casi',
#   'Casie',
#   'Casondra',
#   'Cassady',
#   'Cassandra',
#   'Cassaundra',
#   'Cassey',
#   'Cassi',
#   'Cassia',
#   'Cassidy',
#   'Cassie',
#   'Cassondra',
#   'Cassy',
#   'Cataleya',
#   'Catalina'],
#  ['Catarina',
#   'Cate',
#   'Catelyn',
#   'Caterina',
#   'Catharine',
#   'Catherin',
#   'Catherine',
#   'Cathern',
#   'Catheryn',
#   'Cathey',
#   'Cathi',
#   'Cathie',
#   'Cathleen',
#   'Cathrine',
#   'Cathryn',
#   'Cathy'],
#  ['Catie',
#   'Catina',
#   'Catlin',
#   'Catrice',
#   'Catrina',
#   'Cayce',
#   'Cayden',
#   'Caydence',
#   'Cayla',
#   'Caylee',
#   'Cayleigh',
#   'Cayley',
#   'Caylie',
#   'Caylin',
#   'Ceara',
#   'Cecelia'],
#  ['Cecil',
#   'Cecile',
#   'Cecilia',
#   'Cecily',
#   'Cedar',
#   'Celena',
#   'Celene',
#   'Celest',
#   'Celesta',
#   'Celeste',
#   'Celestia',
#   'Celestina',
#   'Celestine',
#   'Celia',
#   'Celina',
#   'Celinda'],
#  ['Celine',
#   'Ceola',
#   'Cera',
#   'Cerenity',
#   'Cesia',
#   'Chad',
#   'Chana',
#   'Chance',
#   'Chanda',
#   'Chandler',
#   'Chandra',
#   'Chanel',
#   'Chanell',
#   'Chanelle',
#   'Chaney',
#   'Channel'],
#  ['Channing',
#   'Chantal',
#   'Chantay',
#   'Chante',
#   'Chantel',
#   'Chantell',
#   'Chantelle',
#   'Chara',
#   'Chari',
#   'Charis',
#   'Charise',
#   'Charisma',
#   'Charissa',
#   'Charisse',
#   'Charita',
#   'Charity'],
#  ['Charla',
#   'Charlean',
#   'Charlee',
#   'Charleen',
#   'Charleigh',
#   'Charlena',
#   'Charlene',
#   'Charles',
#   'Charlesetta',
#   'Charletta',
#   'Charlette',
#   'Charley',
#   'Charli',
#   'Charlie',
#   'Charline',
#   'Charlize'],
#  ['Charlotte',
#   'Charlsie',
#   'Charly',
#   'Charlyn',
#   'Charlyne',
#   'Charmain',
#   'Charmaine',
#   'Charmayne',
#   'Charolette',
#   'Charon',
#   'Chase',
#   'Chasidy',
#   'Chasity',
#   'Chassidy',
#   'Chassity',
#   'Chastity'],
#  ['Chava',
#   'Chaya',
#   'Chelsa',
#   'Chelsea',
#   'Chelsee',
#   'Chelsey',
#   'Chelsi',
#   'Chelsie',
#   'Chelsy',
#   'Chenoa',
#   'Cher',
#   'Chere',
#   'Cheree',
#   'Cherelle',
#   'Cheri',
#   'Cherice'],
#  ['Cherie',
#   'Cherilyn',
#   'Cherise',
#   'Cherish',
#   'Cherisse',
#   'Cherita',
#   'Cherly',
#   'Cherlyn',
#   'Cherokee',
#   'Cherrelle',
#   'Cherri',
#   'Cherrie',
#   'Cherry',
#   'Cherryl',
#   'Cheryl',
#   'Cherylann'],
#  ['Cheryle',
#   'Cheryll',
#   'Chesney',
#   'Chevelle',
#   'Cheyann',
#   'Cheyanna',
#   'Cheyanne',
#   'Cheyenne',
#   'Chiara',
#   'China',
#   'Chiquita',
#   'Chloe',
#   'Chloee',
#   'Chloey',
#   'Chloie',
#   'Chole'],
#  ['Chris',
#   'Chrissie',
#   'Chrissy',
#   'Christa',
#   'Christal',
#   'Christan',
#   'Christeen',
#   'Christel',
#   'Christelle',
#   'Christen',
#   'Christena',
#   'Christene',
#   'Christi',
#   'Christian',
#   'Christiana',
#   'Christiane'],
#  ['Christianna',
#   'Christianne',
#   'Christie',
#   'Christin',
#   'Christina',
#   'Christine',
#   'Christinia',
#   'Christopher',
#   'Christy',
#   'Christyn',
#   'Chrystal',
#   'Chyanne',
#   'Chyenne',
#   'Chyna',
#   'Chynna',
#   'Ciana'],
#  ['Cianna',
#   'Ciara',
#   'Ciarra',
#   'Cicely',
#   'Cielo',
#   'Cienna',
#   'Ciera',
#   'Cierra',
#   'Cinda',
#   'Cindi',
#   'Cindie',
#   'Cindy',
#   'Cinnamon',
#   'Cinthia',
#   'Cinthya',
#   'Citlali'],
#  ['Citlalli',
#   'Citlaly',
#   'Clair',
#   'Claira',
#   'Claire',
#   'Clara',
#   'Clarabelle',
#   'Clare',
#   'Clarence',
#   'Claretha',
#   'Claribel',
#   'Clarice',
#   'Clarinda',
#   'Clarine',
#   'Clarisa',
#   'Clarise'],
#  ['Clarissa',
#   'Clarisse',
#   'Clarita',
#   'Classie',
#   'Claudette',
#   'Claudia',
#   'Claudie',
#   'Claudine',
#   'Cleda',
#   'Clementina',
#   'Clementine',
#   'Clemmie',
#   'Cleo',
#   'Cleola',
#   'Cleone',
#   'Cleopatra'],
#  ['Cleora',
#   'Cleta',
#   'Clifford',
#   'Cloe',
#   'Cloey',
#   'Cloie',
#   'Clora',
#   'Clorinda',
#   'Clotilde',
#   'Clover',
#   'Clyde',
#   'Coco',
#   'Codi',
#   'Codie',
#   'Cody',
#   'Colbie'],
#  ['Colby',
#   'Coleen',
#   'Colene',
#   'Coletta',
#   'Colette',
#   'Colleen',
#   'Collene',
#   'Collette',
#   'Collins',
#   'Concepcion',
#   'Concetta',
#   'Concha',
#   'Conchita',
#   'Connie',
#   'Connor',
#   'Constance'],
#  ['Consuela',
#   'Consuelo',
#   'Contessa',
#   'Cooper',
#   'Cora',
#   'Coral',
#   'Coralee',
#   'Coralie',
#   'Coraline',
#   'Cordelia',
#   'Cordia',
#   'Cordie',
#   'Coreen',
#   'Corena',
#   'Corene',
#   'Coretta'],
#  ['Corey',
#   'Cori',
#   'Corie',
#   'Corin',
#   'Corina',
#   'Corine',
#   'Corinna',
#   'Corinne',
#   'Corinthia',
#   'Corissa',
#   'Corliss',
#   'Cornelia',
#   'Corrie',
#   'Corrin',
#   'Corrina',
#   'Corrine'],
#  ['Corrinne',
#   'Cortney',
#   'Cory',
#   'Cosette',
#   'Courtenay',
#   'Courteney',
#   'Courtnee',
#   'Courtney',
#   'Courtni',
#   'Courtnie',
#   'Cozette',
#   'Craig',
#   'Creola',
#   'Crimson',
#   'Cris',
#   'Criselda'],
#  ['Crissy',
#   'Crista',
#   'Cristal',
#   'Cristen',
#   'Cristi',
#   'Cristian',
#   'Cristie',
#   'Cristin',
#   'Cristina',
#   'Cristine',
#   'Cristy',
#   'Cruz',
#   'Crysta',
#   'Crystal',
#   'Crystle',
#   'Curtis'],
#  ['Cydney',
#   'Cyndi',
#   'Cyndy',
#   'Cynthia',
#   'Cyrstal',
#   'Dacia',
#   'Daelyn',
#   'Dafne',
#   'Dagmar',
#   'Dagny',
#   'Dahlia',
#   'Daiana',
#   'Daija',
#   'Daijah',
#   'Dailyn',
#   'Daina'],
#  ['Daira',
#   'Daisey',
#   'Daisha',
#   'Daisie',
#   'Daisy',
#   'Daja',
#   'Dajah',
#   'Dakota',
#   'Dakotah',
#   'Dalary',
#   'Dale',
#   'Dalena',
#   'Dalene',
#   'Daleyza',
#   'Dalia',
#   'Dalila'],
#  ['Dalilah',
#   'Dallas',
#   'Damara',
#   'Damaris',
#   'Damia',
#   'Damita',
#   'Damya',
#   'Dana',
#   'Danae',
#   'Danah',
#   'Danasia',
#   'Daneen',
#   'Danell',
#   'Danelle',
#   'Danesha',
#   'Danette'],
#  ['Dani',
#   'Dania',
#   'Danica',
#   'Daniel',
#   'Daniela',
#   'Daniele',
#   'Daniell',
#   'Daniella',
#   'Danielle',
#   'Danika',
#   'Danisha',
#   'Danita',
#   'Daniya',
#   'Daniyah',
#   'Dann',
#   'Danna'],
#  ['Dannette',
#   'Danni',
#   'Dannie',
#   'Dannielle',
#   'Danny',
#   'Danya',
#   'Danyel',
#   'Danyell',
#   'Danyelle',
#   'Daphine',
#   'Daphne',
#   'Daphney',
#   'Dara',
#   'Darby',
#   'Darcel',
#   'Darcey'],
#  ['Darci',
#   'Darcie',
#   'Darcy',
#   'Daria',
#   'Darian',
#   'Dariana',
#   'Darice',
#   'Darien',
#   'Darla',
#   'Darleen',
#   'Darlena',
#   'Darlene',
#   'Darline',
#   'Darlyn',
#   'Darlyne',
#   'Darnell'],
#  ['Darrell',
#   'Darryl',
#   'Darya',
#   'Daryl',
#   'Dasani',
#   'Dasha',
#   'Dasia',
#   'Dava',
#   'Davia',
#   'David',
#   'Davida',
#   'Davina',
#   'Dawn',
#   'Dawna',
#   'Dawne',
#   'Dayana'],
#  ['Dayanara',
#   'Dayanna',
#   'Dayla',
#   'Dayle',
#   'Daylin',
#   'Dayna',
#   'Dayra',
#   'Daysha',
#   'Daysi',
#   'Dea',
#   'Deadra',
#   'Dean',
#   'Deana',
#   'Deandra',
#   'Deandrea',
#   'Deane'],
#  ['Deangela',
#   'Deann',
#   'Deanna',
#   'Deanne',
#   'Deasia',
#   'Deb',
#   'Debbi',
#   'Debbie',
#   'Debbra',
#   'Debby',
#   'Debera',
#   'Debi',
#   'Debora',
#   'Deborah',
#   'Deborha',
#   'Debra'],
#  ['Debrah',
#   'Debroah',
#   'December',
#   'Dede',
#   'Dedra',
#   'Dee',
#   'Deeann',
#   'Deeanna',
#   'Deedee',
#   'Deedra',
#   'Deena',
#   'Deetta',
#   'Deidra',
#   'Deidre',
#   'Deirdra',
#   'Deirdre'],
#  ['Deisy',
#   'Deitra',
#   'Deja',
#   'Dejah',
#   'Dejanae',
#   'Delaina',
#   'Delaine',
#   'Delainey',
#   'Delana',
#   'Delaney',
#   'Delani',
#   'Delanie',
#   'Delcie',
#   'Delena',
#   'Delfina',
#   'Delia'],
#  ['Deliah',
#   'Delicia',
#   'Delight',
#   'Delila',
#   'Delilah',
#   'Delina',
#   'Delinda',
#   'Delisa',
#   'Delisha',
#   'Dell',
#   'Della',
#   'Delma',
#   'Delois',
#   'Deloise',
#   'Delora',
#   'Delores'],
#  ['Delories',
#   'Deloris',
#   'Delorise',
#   'Delorse',
#   'Delpha',
#   'Delphia',
#   'Delphine',
#   'Delsie',
#   'Delta',
#   'Delylah',
#   'Demaris',
#   'Demetra',
#   'Demetria',
#   'Demetrice',
#   'Demetrius',
#   'Demi'],
#  ['Dena',
#   'Denae',
#   'Denali',
#   'Deneen',
#   'Denese',
#   'Denia',
#   'Denice',
#   'Deniece',
#   'Denielle',
#   'Denise',
#   'Denisha',
#   'Denisse',
#   'Denita',
#   'Denna',
#   'Dennis',
#   'Dennise'],
#  ['Denver',
#   'Denyse',
#   'Deon',
#   'Deona',
#   'Deondra',
#   'Deonna',
#   'Derrick',
#   'Desarae',
#   'Desaray',
#   'Deserae',
#   'Deseree',
#   'Deshawn',
#   'Desirae',
#   'Desiray',
#   'Desire',
#   'Desirea'],
#  ['Desiree',
#   'Despina',
#   'Dessa',
#   'Dessie',
#   'Destani',
#   'Destanie',
#   'Destany',
#   'Desteny',
#   'Destine',
#   'Destinee',
#   'Destiney',
#   'Destini',
#   'Destinie',
#   'Destiny',
#   'Destyni',
#   'Detra'],
#  ['Devan',
#   'Deven',
#   'Devin',
#   'Devina',
#   'Devon',
#   'Devona',
#   'Devonna',
#   'Devora',
#   'Devorah',
#   'Devyn',
#   'Deyanira',
#   'Deysi',
#   'Dezarae',
#   'Dezirae',
#   'Deziree',
#   'Dia'],
#  ['Diamond',
#   'Dian',
#   'Diana',
#   'Diandra',
#   'Diane',
#   'Diann',
#   'Dianna',
#   'Dianne',
#   'Dicie',
#   'Diedra',
#   'Diedre',
#   'Dierdre',
#   'Dimple',
#   'Dina',
#   'Dinah',
#   'Dion'],
#  ['Diona',
#   'Dione',
#   'Dionna',
#   'Dionne',
#   'Dior',
#   'Divina',
#   'Divine',
#   'Divya',
#   'Dixie',
#   'Diya',
#   'Docia',
#   'Dodie',
#   'Dollie',
#   'Dolly',
#   'Dolores',
#   'Doloris'],
#  ['Domenica',
#   'Dominga',
#   'Dominic',
#   'Dominica',
#   'Dominique',
#   'Dominque',
#   'Domonique',
#   'Don',
#   'Dona',
#   'Donald',
#   'Donella',
#   'Donelle',
#   'Donetta',
#   'Donette',
#   'Donia',
#   'Donielle'],
#  ['Donisha',
#   'Donita',
#   'Donna',
#   'Donnamarie',
#   'Donnell',
#   'Donnetta',
#   'Donnette',
#   'Donnie',
#   'Donnis',
#   'Donya',
#   'Dora',
#   'Dorathy',
#   'Dorcas',
#   'Doreatha',
#   'Doreen',
#   'Dorene'],
#  ['Doretha',
#   'Dorethea',
#   'Doretta',
#   'Dori',
#   'Doria',
#   'Dorian',
#   'Dorie',
#   'Dorinda',
#   'Dorine',
#   'Doris',
#   'Dorla',
#   'Dorotha',
#   'Dorothea',
#   'Dorothey',
#   'Dorothy',
#   'Dorris'],
#  ['Dortha',
#   'Dorthea',
#   'Dorthey',
#   'Dorthy',
#   'Dot',
#   'Dottie',
#   'Dotty',
#   'Douglas',
#   'Dovie',
#   'Dream',
#   'Dreama',
#   'Drema',
#   'Drew',
#   'Dru',
#   'Drucilla',
#   'Drusilla'],
#  ['Duane',
#   'Dulce',
#   'Dulcie',
#   'Dusti',
#   'Dustin',
#   'Dusty',
#   'Dwana',
#   'Dyamond',
#   'Dyan',
#   'Dyana',
#   'Dyani',
#   'Dyann',
#   'Dyanna',
#   'Dylan',
#   'Dymond',
#   'Dynasty'],
#  ['Earl',
#   'Earlean',
#   'Earleen',
#   'Earlene',
#   'Earlie',
#   'Earline',
#   'Earnestine',
#   'Eartha',
#   'Easter',
#   'Ebone',
#   'Ebonee',
#   'Eboni',
#   'Ebonie',
#   'Ebony',
#   'Echo',
#   'Eda'],
#  ['Eddie',
#   'Eden',
#   'Edie',
#   'Edith',
#   'Edna',
#   'Edra',
#   'Edward',
#   'Edwin',
#   'Edwina',
#   'Edyth',
#   'Edythe',
#   'Effie',
#   'Egypt',
#   'Eila',
#   'Eileen',
#   'Eilene'],
#  ['Eisley',
#   'Ela',
#   'Elaina',
#   'Elaine',
#   'Elana',
#   'Elani',
#   'Elanor',
#   'Elayna',
#   'Elayne',
#   'Elba',
#   'Elberta',
#   'Elda',
#   'Eldora',
#   'Eleana',
#   'Eleanor',
#   'Eleanora'],
#  ['Eleanore',
#   'Elease',
#   'Electa',
#   'Electra',
#   'Elena',
#   'Elene',
#   'Eleni',
#   'Elenor',
#   'Elenora',
#   'Elenore',
#   'Eleonora',
#   'Elexis',
#   'Elexus',
#   'Elfrieda',
#   'Elia',
#   'Eliana'],
#  ['Elianna',
#   'Elicia',
#   'Elida',
#   'Elijah',
#   'Elin',
#   'Elina',
#   'Elinor',
#   'Elinore',
#   'Elisa',
#   'Elisabet',
#   'Elisabeth',
#   'Elise',
#   'Elisha',
#   'Elisheva',
#   'Elisia',
#   'Elissa'],
#  ['Eliza',
#   'Elizabet',
#   'Elizabeth',
#   'Elizbeth',
#   'Elizebeth',
#   'Elke',
#   'Ella',
#   'Ellamae',
#   'Elle',
#   'Ellee',
#   'Ellen',
#   'Ellena',
#   'Ellery',
#   'Elli',
#   'Ellia',
#   'Elliana'],
#  ['Ellianna',
#   'Ellie',
#   'Elliette',
#   'Elliot',
#   'Elliott',
#   'Ellis',
#   'Ellison',
#   'Elly',
#   'Ellyana',
#   'Ellyn',
#   'Elma',
#   'Elmer',
#   'Elmira',
#   'Elna',
#   'Elnora',
#   'Elodia'],
#  ['Elodie',
#   'Elois',
#   'Eloisa',
#   'Eloise',
#   'Elona',
#   'Elora',
#   'Elouise',
#   'Elsa',
#   'Elsie',
#   'Elsy',
#   'Elta',
#   'Elva',
#   'Elvera',
#   'Elvia',
#   'Elvie',
#   'Elvina'],
#  ['Elvira',
#   'Elwanda',
#   'Elyana',
#   'Elysa',
#   'Elyse',
#   'Elysia',
#   'Elyssa',
#   'Ema',
#   'Emalee',
#   'Emaleigh',
#   'Emalie',
#   'Emaline',
#   'Emalyn',
#   'Eman',
#   'Emani',
#   'Ember'],
#  ['Emberly',
#   'Emberlynn',
#   'Emelda',
#   'Emeli',
#   'Emelia',
#   'Emelie',
#   'Emeline',
#   'Emely',
#   'Emelyn',
#   'Emerald',
#   'Emeri',
#   'Emerie',
#   'Emerson',
#   'Emersyn',
#   'Emery',
#   'Emi'],
#  ['Emiko',
#   'Emilee',
#   'Emileigh',
#   'Emiley',
#   'Emili',
#   'Emilia',
#   'Emiliana',
#   'Emilie',
#   'Emilly',
#   'Emily',
#   'Emilyn',
#   'Emma',
#   'Emmalee',
#   'Emmaleigh',
#   'Emmaline',
#   'Emmalyn'],
#  ['Emmalynn',
#   'Emmanuella',
#   'Emmanuelle',
#   'Emmarie',
#   'Emme',
#   'Emmeline',
#   'Emmer',
#   'Emmerson',
#   'Emmi',
#   'Emmie',
#   'Emmy',
#   'Emogene',
#   'Emoni',
#   'Emory',
#   'Emrie',
#   'Emry'],
#  ['Emy',
#   'Ena',
#   'Endia',
#   'Enedina',
#   'Enid',
#   'Enola',
#   'Enriqueta',
#   'Ensley',
#   'Enya',
#   'Eowyn',
#   'Era',
#   'Eriana',
#   'Erianna',
#   'Eric',
#   'Erica',
#   'Ericka'],
#  ['Erie',
#   'Erika',
#   'Erikka',
#   'Erin',
#   'Erinn',
#   'Eris',
#   'Erlene',
#   'Erlinda',
#   'Erline',
#   'Erma',
#   'Ermelinda',
#   'Erminia',
#   'Erna',
#   'Ernest',
#   'Ernestina',
#   'Ernestine'],
#  ['Eryka',
#   'Erykah',
#   'Eryn',
#   'Erynn',
#   'Esha',
#   'Esme',
#   'Esmeralda',
#   'Esperanza',
#   'Essence',
#   'Essie',
#   'Esta',
#   'Estefana',
#   'Estefani',
#   'Estefania',
#   'Estefany',
#   'Estela'],
#  ['Estell',
#   'Estella',
#   'Estelle',
#   'Estephanie',
#   'Ester',
#   'Esther',
#   'Estrella',
#   'Estrellita',
#   'Eternity',
#   'Etha',
#   'Ethel',
#   'Ethelene',
#   'Ethelyn',
#   'Ether',
#   'Ethyl',
#   'Etta'],
#  ['Ettie',
#   'Eudora',
#   'Eugena',
#   'Eugene',
#   'Eugenia',
#   'Eugenie',
#   'Eula',
#   'Eulah',
#   'Eulalia',
#   'Euna',
#   'Eunice',
#   'Eura',
#   'Eva',
#   'Evalee',
#   'Evalena',
#   'Evalina'],
#  ['Evaline',
#   'Evalyn',
#   'Evalynn',
#   'Evan',
#   'Evangelia',
#   'Evangelina',
#   'Evangeline',
#   'Eve',
#   'Evelena',
#   'Evelia',
#   'Evelin',
#   'Evelina',
#   'Eveline',
#   'Evelyn',
#   'Evelyne',
#   'Evelynn'],
#  ['Evelynne',
#   'Ever',
#   'Everlee',
#   'Everleigh',
#   'Everlena',
#   'Everley',
#   'Everly',
#   'Evette',
#   'Evie',
#   'Evita',
#   'Evolet',
#   'Evon',
#   'Evonne',
#   'Evy',
#   'Exie',
#   'Ezra'],
#  ['Fabiana',
#   'Fabiola',
#   'Fae',
#   'Faiga',
#   'Faigy',
#   'Fairy',
#   'Faith',
#   'Fallon',
#   'Fallyn',
#   'Falon',
#   'Falyn',
#   'Fannie',
#   'Fanny',
#   'Fantasia',
#   'Fara',
#   'Farah'],
#  ['Farrah',
#   'Fatima',
#   'Fatimah',
#   'Fatoumata',
#   'Faustina',
#   'Faviola',
#   'Fawn',
#   'Fay',
#   'Faye',
#   'Fayetta',
#   'Fayth',
#   'Felecia',
#   'Felica',
#   'Felice',
#   'Felicia',
#   'Felicita'],
#  ['Felicitas',
#   'Felicity',
#   'Felipa',
#   'Felisa',
#   'Felisha',
#   'Female',
#   'Fern',
#   'Fernanda',
#   'Ferne',
#   'Filomena',
#   'Finley',
#   'Finnley',
#   'Fiona',
#   'Fiorella',
#   'Flavia',
#   'Fleta'],
#  ['Flo',
#   'Flonnie',
#   'Flor',
#   'Flora',
#   'Florance',
#   'Florence',
#   'Florencia',
#   'Florene',
#   'Florentina',
#   'Floretta',
#   'Floria',
#   'Florida',
#   'Florinda',
#   'Florine',
#   'Florrie',
#   'Flossie'],
#  ['Floy',
#   'Floyd',
#   'Fonda',
#   'Fran',
#   'France',
#   'Francene',
#   'Frances',
#   'Francesca',
#   'Franchesca',
#   'Francheska',
#   'Francie',
#   'Francina',
#   'Francine',
#   'Francis',
#   'Francisca',
#   'Frank'],
#  ['Franki',
#   'Frankie',
#   'Fred',
#   'Freda',
#   'Fredda',
#   'Freddie',
#   'Frederica',
#   'Frederick',
#   'Fredericka',
#   'Fredia',
#   'Fredricka',
#   'Freeda',
#   'Freedom',
#   'Freida',
#   'Freya',
#   'Freyja'],
#  ['Frida',
#   'Frieda',
#   'Gabriel',
#   'Gabriela',
#   'Gabriele',
#   'Gabriell',
#   'Gabriella',
#   'Gabrielle',
#   'Gaby',
#   'Gaia',
#   'Gail',
#   'Gala',
#   'Gale',
#   'Galilea',
#   'Gardenia',
#   'Garnet'],
#  ['Garnett',
#   'Gary',
#   'Gay',
#   'Gaye',
#   'Gayla',
#   'Gayle',
#   'Gaylene',
#   'Gaynell',
#   'Gaynelle',
#   'Gearldine',
#   'Geena',
#   'Gema',
#   'Gemma',
#   'Gena',
#   'Gene',
#   'Genell'],
#  ['Genelle',
#   'Genesis',
#   'Genessis',
#   'Geneva',
#   'Genevia',
#   'Genevie',
#   'Genevieve',
#   'Genevive',
#   'Genia',
#   'Genie',
#   'Genna',
#   'Gennie',
#   'Gennifer',
#   'Genny',
#   'Genoveva',
#   'Gentry'],
#  ['Georgann',
#   'Georganna',
#   'Georganne',
#   'George',
#   'Georgeann',
#   'Georgeanna',
#   'Georgeanne',
#   'Georgene',
#   'Georgetta',
#   'Georgette',
#   'Georgia',
#   'Georgiana',
#   'Georgiann',
#   'Georgianna',
#   'Georgianne',
#   'Georgie'],
#  ['Georgina',
#   'Georgine',
#   'Gerald',
#   'Geraldine',
#   'Geralyn',
#   'Gerda',
#   'Geri',
#   'Germaine',
#   'Gerri',
#   'Gerrie',
#   'Gerry',
#   'Gertha',
#   'Gertie',
#   'Gertrude',
#   'Gia',
#   'Giada'],
#  ['Giana',
#   'Gianna',
#   'Gianni',
#   'Giavanna',
#   'Giavonna',
#   'Gidget',
#   'Gigi',
#   'Gilda',
#   'Gillian',
#   'Gina',
#   'Ginamarie',
#   'Ginger',
#   'Ginny',
#   'Giovanna',
#   'Gisel',
#   'Gisela'],
#  ['Gisele',
#   'Gisell',
#   'Gisella',
#   'Giselle',
#   'Gissel',
#   'Gissell',
#   'Gisselle',
#   'Gittel',
#   'Gitty',
#   'Giulia',
#   'Giuliana',
#   'Giulianna',
#   'Giuseppina',
#   'Gizelle',
#   'Gladis',
#   'Gladyce'],
#  ['Gladys',
#   'Glen',
#   'Glena',
#   'Glenda',
#   'Glendora',
#   'Glenn',
#   'Glenna',
#   'Glennie',
#   'Glennis',
#   'Glenys',
#   'Glinda',
#   'Gloria',
#   'Glory',
#   'Glynda',
#   'Glynis',
#   'Golda'],
#  ['Golden',
#   'Goldia',
#   'Goldie',
#   'Goldy',
#   'Grace',
#   'Gracee',
#   'Gracelyn',
#   'Gracelynn',
#   'Gracen',
#   'Gracey',
#   'Graci',
#   'Gracia',
#   'Gracie',
#   'Graciela',
#   'Gracy',
#   'Gracyn'],
#  ['Grayce',
#   'Grayson',
#   'Grecia',
#   'Greer',
#   'Gregoria',
#   'Gregory',
#   'Greta',
#   'Gretchen',
#   'Gretel',
#   'Gretta',
#   'Gricelda',
#   'Grisel',
#   'Griselda',
#   'Guadalupe',
#   'Guillermina',
#   'Guinevere'],
#  ['Gurleen',
#   'Gussie',
#   'Gwen',
#   'Gwenda',
#   'Gwendalyn',
#   'Gwendolyn',
#   'Gwendolynn',
#   'Gweneth',
#   'Gwenn',
#   'Gwenyth',
#   'Gwyn',
#   'Gwyneth',
#   'Gwynne',
#   'Gypsy',
#   'Hadassah',
#   'Haddie'],
#  ['Hadlee',
#   'Hadleigh',
#   'Hadley',
#   'Hafsa',
#   'Haiden',
#   'Haidyn',
#   'Hailee',
#   'Haileigh',
#   'Hailey',
#   'Hailie',
#   'Haily',
#   'Hala',
#   'Halee',
#   'Haleigh',
#   'Haley',
#   'Hali'],
#  ['Halie',
#   'Halima',
#   'Halle',
#   'Hallee',
#   'Halley',
#   'Halli',
#   'Hallie',
#   'Halo',
#   'Hana',
#   'Hanah',
#   'Hanan',
#   'Haneen',
#   'Hanna',
#   'Hannah',
#   'Harlee',
#   'Harleen'],
#  ['Harleigh',
#   'Harlene',
#   'Harley',
#   'Harli',
#   'Harlie',
#   'Harlow',
#   'Harmoni',
#   'Harmonie',
#   'Harmony',
#   'Harold',
#   'Harper',
#   'Harriet',
#   'Harriett',
#   'Harriette',
#   'Harry',
#   'Hartley'],
#  ['Hassie',
#   'Hattie',
#   'Havana',
#   'Haven',
#   'Hawa',
#   'Haya',
#   'Haydee',
#   'Hayden',
#   'Hayle',
#   'Haylee',
#   'Hayleigh',
#   'Hayley',
#   'Hayli',
#   'Haylie',
#   'Hazel',
#   'Hazle'],
#  ['Heather',
#   'Heaven',
#   'Heavenly',
#   'Heba',
#   'Hedwig',
#   'Hedy',
#   'Heide',
#   'Heidi',
#   'Heidy',
#   'Helaine',
#   'Helen',
#   'Helena',
#   'Helene',
#   'Helga',
#   'Hellen',
#   'Helyn'],
#  ['Henley',
#   'Henna',
#   'Hennessy',
#   'Henretta',
#   'Henrietta',
#   'Henriette',
#   'Henry',
#   'Hensley',
#   'Herbert',
#   'Herlinda',
#   'Hermelinda',
#   'Hermina',
#   'Hermine',
#   'Herminia',
#   'Hermione',
#   'Hertha'],
#  ['Hessie',
#   'Hester',
#   'Hettie',
#   'Hiba',
#   'Hiedi',
#   'Hilary',
#   'Hilda',
#   'Hildegard',
#   'Hildegarde',
#   'Hildred',
#   'Hillary',
#   'Hilma',
#   'Hinda',
#   'Hindy',
#   'Holland',
#   'Holley'],
#  ['Holli',
#   'Hollie',
#   'Hollis',
#   'Holly',
#   'Hollyn',
#   'Honesty',
#   'Honey',
#   'Honor',
#   'Honora',
#   'Hope',
#   'Hortencia',
#   'Hortense',
#   'Hortensia',
#   'Hosanna',
#   'Howard',
#   'Huda'],
#  ['Hudson',
#   'Hulda',
#   'Hunter',
#   'Icie',
#   'Icy',
#   'Ida',
#   'Idalia',
#   'Idell',
#   'Idella',
#   'Iesha',
#   'Ieshia',
#   'Ignacia',
#   'Ila',
#   'Ilah',
#   'Ilana',
#   'Ilda'],
#  ['Ileana',
#   'Ileen',
#   'Ilene',
#   'Iliana',
#   'Illa',
#   'Illiana',
#   'Ilona',
#   'Ilse',
#   'Ima',
#   'Iman',
#   'Imani',
#   'Imari',
#   'Imelda',
#   'Imogen',
#   'Imogene',
#   'Ina'],
#  ['Inara',
#   'Inaya',
#   'India',
#   'Indiana',
#   'Indie',
#   'Indigo',
#   'Indira',
#   'Indya',
#   'Inell',
#   'Ines',
#   'Inez',
#   'Infant',
#   'Inga',
#   'Inger',
#   'Ingrid',
#   'Iola'],
#  ['Iona',
#   'Ione',
#   'Iqra',
#   'Ira',
#   'Ireland',
#   'Irelyn',
#   'Irelynn',
#   'Irena',
#   'Irene',
#   'Irie',
#   'Irina',
#   'Irine',
#   'Iris',
#   'Irish',
#   'Irma',
#   'Isa'],
#  ['Isabel',
#   'Isabela',
#   'Isabell',
#   'Isabella',
#   'Isabelle',
#   'Isadora',
#   'Isamar',
#   'Isaura',
#   'Isela',
#   'Isha',
#   'Isis',
#   'Isla',
#   'Isobel',
#   'Isra',
#   'Israel',
#   'Issabella'],
#  ['Italia',
#   'Italy',
#   'Itzayana',
#   'Itzel',
#   'Iva',
#   'Ivana',
#   'Ivanna',
#   'Ivelisse',
#   'Ivette',
#   'Ivey',
#   'Ivie',
#   'Ivon',
#   'Ivonne',
#   'Ivory',
#   'Ivy',
#   'Iyana'],
#  ['Iyanna',
#   'Iyla',
#   'Iyonna',
#   'Izabel',
#   'Izabela',
#   'Izabell',
#   'Izabella',
#   'Izabelle',
#   'Izel',
#   'Izetta',
#   'Izola',
#   'Izora',
#   'Izzabella',
#   'Jabria',
#   'Jacalyn',
#   'Jacee'],
#  ['Jacelyn',
#   'Jacey',
#   'Jaci',
#   'Jacie',
#   'Jacinda',
#   'Jacinta',
#   'Jack',
#   'Jackelin',
#   'Jackeline',
#   'Jackelyn',
#   'Jacki',
#   'Jackie',
#   'Jacklyn',
#   'Jacklynn',
#   'Jackqueline',
#   'Jacky'],
#  ['Jaclyn',
#   'Jaclynn',
#   'Jacob',
#   'Jacqualine',
#   'Jacqualyn',
#   'Jacque',
#   'Jacquelene',
#   'Jacquelin',
#   'Jacqueline',
#   'Jacquelyn',
#   'Jacquelyne',
#   'Jacquelynn',
#   'Jacquetta',
#   'Jacquie',
#   'Jacquline',
#   'Jacqulyn'],
#  ['Jacy',
#   'Jada',
#   'Jadah',
#   'Jade',
#   'Jadelyn',
#   'Jadelynn',
#   'Jaden',
#   'Jadyn',
#   'Jae',
#   'Jaeda',
#   'Jaedyn',
#   'Jael',
#   'Jaela',
#   'Jaelyn',
#   'Jaelynn',
#   'Jahaira'],
#  ['Jahzara',
#   'Jai',
#   'Jaida',
#   'Jaide',
#   'Jaiden',
#   'Jaidyn',
#   'Jaila',
#   'Jailah',
#   'Jailene',
#   'Jailyn',
#   'Jailynn',
#   'Jaime',
#   'Jaimee',
#   'Jaimi',
#   'Jaimie',
#   'Jaina'],
#  ['Jakayla',
#   'Jakia',
#   'Jakira',
#   'Jakiya',
#   'Jakiyah',
#   'Jakyra',
#   'Jala',
#   'Jalaya',
#   'Jalayah',
#   'Jaleah',
#   'Jaleesa',
#   'Jalen',
#   'Jalena',
#   'Jalene',
#   'Jalia',
#   'Jalisa'],
#  ['Jalissa',
#   'Jaliyah',
#   'Jalyn',
#   'Jalynn',
#   'Jalyssa',
#   'Jama',
#   'Jamaica',
#   'Jamaria',
#   'Jamaya',
#   'Jamee',
#   'Jameelah',
#   'Jameka',
#   'James',
#   'Jamesha',
#   'Jamey',
#   'Jami'],
#  ['Jamia',
#   'Jamiah',
#   'Jamie',
#   'Jamika',
#   'Jamila',
#   'Jamilah',
#   'Jamilla',
#   'Jamillah',
#   'Jamira',
#   'Jamison',
#   'Jamiya',
#   'Jamiyah',
#   'Jammie',
#   'Jamya',
#   'Jamyah',
#   'Jan'],
#  ['Jana',
#   'Janae',
#   'Janai',
#   'Janalee',
#   'Janasia',
#   'Janay',
#   'Janaya',
#   'Jane',
#   'Janea',
#   'Janean',
#   'Janee',
#   'Janeen',
#   'Janel',
#   'Janell',
#   'Janella',
#   'Janelle'],
#  ['Janelly',
#   'Janely',
#   'Janene',
#   'Janese',
#   'Janessa',
#   'Janet',
#   'Janeth',
#   'Janett',
#   'Janetta',
#   'Janette',
#   'Janey',
#   'Jani',
#   'Jania',
#   'Janiah',
#   'Janice',
#   'Janie'],
#  ['Janiece',
#   'Janina',
#   'Janine',
#   'Janis',
#   'Janise',
#   'Janita',
#   'Janiya',
#   'Janiyah',
#   'Jann',
#   'Janna',
#   'Jannah',
#   'Jannelle',
#   'Jannet',
#   'Jannett',
#   'Jannette',
#   'Jannie'],
#  ['January',
#   'Janya',
#   'Janyah',
#   'Janyce',
#   'Janyla',
#   'Jaquelin',
#   'Jaqueline',
#   'Jaquelyn',
#   'Jariah',
#   'Jasleen',
#   'Jaslene',
#   'Jaslyn',
#   'Jaslynn',
#   'Jasmin',
#   'Jasmina',
#   'Jasmine'],
#  ['Jasmyn',
#   'Jasmyne',
#   'Jason',
#   'Jaunita',
#   'Jay',
#   'Jaya',
#   'Jayana',
#   'Jayanna',
#   'Jayce',
#   'Jaycee',
#   'Jayci',
#   'Jaycie',
#   'Jayda',
#   'Jaydah',
#   'Jayde',
#   'Jayden'],
#  ['Jaydin',
#   'Jaye',
#   'Jayla',
#   'Jaylah',
#   'Jaylani',
#   'Jaylee',
#   'Jayleen',
#   'Jayleigh',
#   'Jaylen',
#   'Jaylene',
#   'Jaylin',
#   'Jaylyn',
#   'Jaylynn',
#   'Jayme',
#   'Jaymee',
#   'Jaymi'],
#  ['Jaymie',
#   'Jayna',
#   'Jayne',
#   'Jaynie',
#   'Jazelle',
#   'Jazleen',
#   'Jazlene',
#   'Jazlin',
#   'Jazlyn',
#   'Jazlynn',
#   'Jazmen',
#   'Jazmin',
#   'Jazmine',
#   'Jazmyn',
#   'Jazmyne',
#   'Jazzlyn'],
#  ['Jazzlynn',
#   'Jazzmin',
#   'Jazzmine',
#   'Jazzmyn',
#   'Jean',
#   'Jeana',
#   'Jeane',
#   'Jeanelle',
#   'Jeanene',
#   'Jeanett',
#   'Jeanetta',
#   'Jeanette',
#   'Jeanice',
#   'Jeanie',
#   'Jeanine',
#   'Jeanmarie'],
#  ['Jeanna',
#   'Jeanne',
#   'Jeannetta',
#   'Jeannette',
#   'Jeannie',
#   'Jeannine',
#   'Jeffery',
#   'Jeffie',
#   'Jeffrey',
#   'Jelena',
#   'Jelisa',
#   'Jemima',
#   'Jemma',
#   'Jena',
#   'Jenae',
#   'Jenaya'],
#  ['Jene',
#   'Jenee',
#   'Jeneen',
#   'Jenell',
#   'Jenelle',
#   'Jenesis',
#   'Jenessa',
#   'Jenette',
#   'Jeneva',
#   'Jenevieve',
#   'Jeni',
#   'Jenica',
#   'Jenice',
#   'Jenifer',
#   'Jeniffer',
#   'Jenine'],
#  ['Jenise',
#   'Jenna',
#   'Jennafer',
#   'Jennah',
#   'Jennefer',
#   'Jennell',
#   'Jennelle',
#   'Jennette',
#   'Jenni',
#   'Jennica',
#   'Jennie',
#   'Jennifer',
#   'Jenniffer',
#   'Jennine',
#   'Jenny',
#   'Jennyfer'],
#  ['Jensen',
#   'Jeraldine',
#   'Jeralyn',
#   'Jere',
#   'Jeremy',
#   'Jeri',
#   'Jerica',
#   'Jerika',
#   'Jerilyn',
#   'Jerilynn',
#   'Jerline',
#   'Jermaine',
#   'Jerome',
#   'Jerri',
#   'Jerrica',
#   'Jerrie'],
#  ['Jerrilyn',
#   'Jerry',
#   'Jersey',
#   'Jerusha',
#   'Jeryl',
#   'Jesenia',
#   'Jesica',
#   'Jesika',
#   'Jeslyn',
#   'Jessa',
#   'Jessalyn',
#   'Jesse',
#   'Jesseca',
#   'Jessenia',
#   'Jessi',
#   'Jessica'],
#  ['Jessie',
#   'Jessika',
#   'Jesslyn',
#   'Jessy',
#   'Jessyca',
#   'Jestine',
#   'Jesus',
#   'Jesusa',
#   'Jesusita',
#   'Jetta',
#   'Jettie',
#   'Jewel',
#   'Jewell',
#   'Jia',
#   'Jianna',
#   'Jill'],
#  ['Jillian',
#   'Jimena',
#   'Jimmie',
#   'Jimmy',
#   'Jina',
#   'Jiselle',
#   'Jiya',
#   'Jo',
#   'Jo-Ann',
#   'Jo-Anne',
#   'Joan',
#   'Joana',
#   'Joane',
#   'Joanie',
#   'Joann',
#   'Joanna'],
#  ['Joanne',
#   'Joannie',
#   'Jocelin',
#   'Joceline',
#   'Jocelyn',
#   'Jocelyne',
#   'Jocelynn',
#   'Jodee',
#   'Jodi',
#   'Jodie',
#   'Jody',
#   'Joe',
#   'Joeann',
#   'Joel',
#   'Joelene',
#   'Joell'],
#  ['Joella',
#   'Joelle',
#   'Joellen',
#   'Joely',
#   'Joetta',
#   'Joette',
#   'Joey',
#   'Johana',
#   'Johanna',
#   'Johannah',
#   'Johanne',
#   'John',
#   'Johna',
#   'Johnetta',
#   'Johnette',
#   'Johnie'],
#  ['Johnna',
#   'Johnnie',
#   'Johnny',
#   'Johnsie',
#   'Joi',
#   'Joie',
#   'Jolanda',
#   'Jolee',
#   'Joleen',
#   'Jolena',
#   'Jolene',
#   'Joli',
#   'Jolie',
#   'Jolinda',
#   'Joline',
#   'Jolyn'],
#  ['Jolynn',
#   'Jon',
#   'Jona',
#   'Jonae',
#   'Jonathan',
#   'Jonell',
#   'Jonelle',
#   'Jonette',
#   'Joni',
#   'Jonie',
#   'Jonna',
#   'Jonni',
#   'Jonnie',
#   'Jordan',
#   'Jordana',
#   'Jordann'],
#  ['Jorden',
#   'Jordin',
#   'Jordon',
#   'Jordyn',
#   'Jordynn',
#   'Joretta',
#   'Jori',
#   'Jorie',
#   'Jorja',
#   'Josalyn',
#   'Joscelyn',
#   'Jose',
#   'Josefa',
#   'Josefina',
#   'Joselin',
#   'Joseline'],
#  ['Joselyn',
#   'Joselyne',
#   'Joselynn',
#   'Joseph',
#   'Josephina',
#   'Josephine',
#   'Josette',
#   'Josey',
#   'Joshlyn',
#   'Joshua',
#   'Josie',
#   'Josiephine',
#   'Josilyn',
#   'Joslin',
#   'Joslyn',
#   'Joslynn'],
#  ['Josselyn',
#   'Jossie',
#   'Josslyn',
#   'Jourdan',
#   'Journee',
#   'Journei',
#   'Journey',
#   'Journi',
#   'Journie',
#   'Jovan',
#   'Jovana',
#   'Jovanna',
#   'Jovie',
#   'Jovita',
#   'Joy',
#   'Joya'],
#  ['Joyce',
#   'Joycelyn',
#   'Joye',
#   'Jozlyn',
#   'Juan',
#   'Juana',
#   'Juanita',
#   'Jubilee',
#   'Jude',
#   'Judi',
#   'Judie',
#   'Judith',
#   'Judy',
#   'Jule',
#   'Julee',
#   'Julene'],
#  ['Jules',
#   'Juli',
#   'Julia',
#   'Julian',
#   'Juliana',
#   'Juliane',
#   'Juliann',
#   'Julianna',
#   'Julianne',
#   'Julie',
#   'Julieann',
#   'Julieanna',
#   'Julieanne',
#   'Julienne',
#   'Juliet',
#   'Julieta'],
#  ['Julietta',
#   'Juliette',
#   'Julisa',
#   'Julissa',
#   'Jullian',
#   'June',
#   'Junie',
#   'Juniper',
#   'Junita',
#   'Jurnee',
#   'Justice',
#   'Justin',
#   'Justina',
#   'Justine',
#   'Justyce',
#   'Kacee'],
#  ['Kacey',
#   'Kaci',
#   'Kacie',
#   'Kacy',
#   'Kadee',
#   'Kaden',
#   'Kadence',
#   'Kadie',
#   'Kadijah',
#   'Kady',
#   'Kadyn',
#   'Kaela',
#   'Kaelee',
#   'Kaeleigh',
#   'Kaeli',
#   'Kaelin'],
#  ['Kaelyn',
#   'Kaelynn',
#   'Kahlan',
#   'Kahlia',
#   'Kai',
#   'Kaia',
#   'Kaiden',
#   'Kaidence',
#   'Kaidyn',
#   'Kaila',
#   'Kailah',
#   'Kailani',
#   'Kailee',
#   'Kaileigh',
#   'Kailey',
#   'Kaili'],
#  ['Kailie',
#   'Kailin',
#   'Kaily',
#   'Kailyn',
#   'Kailynn',
#   'Kaira',
#   'Kairi',
#   'Kaisha',
#   'Kaitlan',
#   'Kaitlin',
#   'Kaitlyn',
#   'Kaitlynn',
#   'Kaiya',
#   'Kala',
#   'Kalani',
#   'Kalea'],
#  ['Kaleah',
#   'Kalee',
#   'Kaleena',
#   'Kalei',
#   'Kaleigh',
#   'Kalen',
#   'Kalena',
#   'Kaley',
#   'Kali',
#   'Kalia',
#   'Kaliah',
#   'Kalie',
#   'Kalin',
#   'Kalina',
#   'Kalisha',
#   'Kalissa'],
#  ['Kalista',
#   'Kaliyah',
#   'Kalli',
#   'Kallie',
#   'Kally',
#   'Kalyn',
#   'Kalynn',
#   'Kamala',
#   'Kamara',
#   'Kamari',
#   'Kamaria',
#   'Kamaya',
#   'Kambree',
#   'Kambria',
#   'Kamdyn',
#   'Kameron'],
#  ['Kameryn',
#   'Kamesha',
#   'Kami',
#   'Kamia',
#   'Kamiah',
#   'Kamie',
#   'Kamila',
#   'Kamilah',
#   'Kamilla',
#   'Kamille',
#   'Kamisha',
#   'Kamiya',
#   'Kamiyah',
#   'Kamora',
#   'Kamri',
#   'Kamryn'],
#  ['Kamya',
#   'Kandace',
#   'Kandi',
#   'Kandice',
#   'Kandie',
#   'Kandis',
#   'Kandra',
#   'Kandy',
#   'Kandyce',
#   'Kaneisha',
#   'Kanesha',
#   'Kanika',
#   'Kanisha',
#   'Kaniya',
#   'Kaniyah',
#   'Kansas'],
#  ['Kara',
#   'Karah',
#   'Karalee',
#   'Karalyn',
#   'Karan',
#   'Kareen',
#   'Kareena',
#   'Karel',
#   'Karely',
#   'Karen',
#   'Karena',
#   'Karey',
#   'Kari',
#   'Karianne',
#   'Karie',
#   'Karima'],
#  ['Karime',
#   'Karin',
#   'Karina',
#   'Karine',
#   'Karis',
#   'Karisa',
#   'Karishma',
#   'Karisma',
#   'Karissa',
#   'Karizma',
#   'Karla',
#   'Karlee',
#   'Karleen',
#   'Karleigh',
#   'Karlene',
#   'Karley'],
#  ['Karli',
#   'Karlie',
#   'Karly',
#   'Karlyn',
#   'Karma',
#   'Karmen',
#   'Karmyn',
#   'Karol',
#   'Karolina',
#   'Karoline',
#   'Karolyn',
#   'Karon',
#   'Karra',
#   'Karren',
#   'Karri',
#   'Karrie'],
#  ['Karrington',
#   'Karry',
#   'Karsen',
#   'Karson',
#   'Karsyn',
#   'Karter',
#   'Kary',
#   'Karyl',
#   'Karyme',
#   'Karyn',
#   'Kasandra',
#   'Kasey',
#   'Kasha',
#   'Kasi',
#   'Kasia',
#   'Kasie'],
#  ['Kassandra',
#   'Kassi',
#   'Kassidi',
#   'Kassidy',
#   'Kassie',
#   'Kataleya',
#   'Katalina',
#   'Katana',
#   'Katara',
#   'Katarina',
#   'Kate',
#   'Katelin',
#   'Katelyn',
#   'Katelynn',
#   'Katelynne',
#   'Kateri'],
#  ['Katerina',
#   'Katey',
#   'Kathaleen',
#   'Katharina',
#   'Katharine',
#   'Katharyn',
#   'Kathe',
#   'Katheleen',
#   'Katherin',
#   'Katherina',
#   'Katherine',
#   'Kathern',
#   'Katheryn',
#   'Katheryne',
#   'Kathey',
#   'Kathi'],
#  ['Kathia',
#   'Kathie',
#   'Kathleen',
#   'Kathlene',
#   'Kathlyn',
#   'Kathrin',
#   'Kathrine',
#   'Kathryn',
#   'Kathryne',
#   'Kathy',
#   'Kathyrn',
#   'Kati',
#   'Katia',
#   'Katie',
#   'Katilyn',
#   'Katina'],
#  ['Katlin',
#   'Katlyn',
#   'Katlynn',
#   'Katrena',
#   'Katrice',
#   'Katrin',
#   'Katrina',
#   'Kattie',
#   'Katy',
#   'Katya',
#   'Kavya',
#   'Kawana',
#   'Kay',
#   'Kaya',
#   'Kayce',
#   'Kaycee'],
#  ['Kayci',
#   'Kaycie',
#   'Kaydance',
#   'Kaydee',
#   'Kayden',
#   'Kaydence',
#   'Kaye',
#   'Kayla',
#   'Kaylah',
#   'Kaylan',
#   'Kaylani',
#   'Kayle',
#   'Kaylea',
#   'Kaylee',
#   'Kayleen',
#   'Kaylei'],
#  ['Kayleigh',
#   'Kaylen',
#   'Kaylene',
#   'Kayley',
#   'Kayli',
#   'Kaylie',
#   'Kaylin',
#   'Kaylyn',
#   'Kaylynn',
#   'Kaysha',
#   'Kaysie',
#   'Kaytlin',
#   'Kaytlyn',
#   'Kaytlynn',
#   'Keagan',
#   'Keaira'],
#  ['Keana',
#   'Keandra',
#   'Keanna',
#   'Keara',
#   'Keasia',
#   'Keaton',
#   'Kecia',
#   'Keegan',
#   'Keela',
#   'Keeley',
#   'Keeli',
#   'Keelie',
#   'Keelin',
#   'Keely',
#   'Keena',
#   'Keesha'],
#  ['Kehlani',
#   'Keiana',
#   'Keianna',
#   'Keiara',
#   'Keiko',
#   'Keila',
#   'Keilah',
#   'Keilani',
#   'Keily',
#   'Keira',
#   'Keirra',
#   'Keirsten',
#   'Keiry',
#   'Keisha',
#   'Keith',
#   'Keitha'],
#  ['Kelby',
#   'Kelcey',
#   'Kelci',
#   'Kelcie',
#   'Keli',
#   'Kelis',
#   'Kelle',
#   'Kellee',
#   'Kellen',
#   'Kelley',
#   'Kelli',
#   'Kellie',
#   'Kelly',
#   'Kellyann',
#   'Kellye',
#   'Kellyn'],
#  ['Kelsea',
#   'Kelsee',
#   'Kelsey',
#   'Kelsi',
#   'Kelsie',
#   'Kelsy',
#   'Kemberly',
#   'Kena',
#   'Kenadee',
#   'Kenadi',
#   'Kenadie',
#   'Kenda',
#   'Kendal',
#   'Kendall',
#   'Kendell',
#   'Kendra'],
#  ['Kendria',
#   'Kendyl',
#   'Kendyll',
#   'Kenesha',
#   'Kenia',
#   'Kenisha',
#   'Kenlee',
#   'Kenleigh',
#   'Kenley',
#   'Kenna',
#   'Kennadi',
#   'Kennady',
#   'Kennedi',
#   'Kennedie',
#   'Kennedy',
#   'Kenneth'],
#  ['Kensington',
#   'Kensley',
#   'Kenya',
# ...
#   'Rosana',
#   'Rosann',
#   'Rosanna',
#   'Rosanne',
#   'Rosaria',
#   'Rosario',
#   'Rosaura',
#   'Rose'],
#  ['Roseann',
#   'Roseanna',
#   'Roseanne',
#   'Roselee',
#   'Roseline',
#   'Rosella',
#   'Roselle',
#   'Roselyn',
#   'Roselynn',
#   'Rosemarie',
#   'Rosemary',
#   'Rosena',
#   'Rosetta',
#   'Rosey',
#   'Roshanda',
#   'Roshni'],
#  ['Roshonda',
#   'Rosia',
#   'Rosie',
#   'Rosina',
#   'Rosio',
#   'Rosita',
#   'Roslyn',
#   'Roslynn',
#   'Rossie',
#   'Rosslyn',
#   'Rosy',
#   'Rowan',
#   'Rowen',
#   'Rowena',
#   'Rowyn',
#   'Roxana'],
#  ['Roxane',
#   'Roxann',
#   'Roxanna',
#   'Roxanne',
#   'Roxie',
#   'Roxy',
#   'Roy',
#   'Roya',
#   'Royal',
#   'Royalty',
#   'Royce',
#   'Rozanne',
#   'Rozella',
#   'Rozlyn',
#   'Rubi',
#   'Rubie'],
#  ['Ruby',
#   'Rubye',
#   'Rudy',
#   'Rufina',
#   'Russell',
#   'Ruth',
#   'Rutha',
#   'Ruthann',
#   'Ruthanne',
#   'Ruthe',
#   'Ruthie',
#   'Rya',
#   'Ryan',
#   'Ryann',
#   'Ryanna',
#   'Ryanne'],
#  ['Ryder',
#   'Rylan',
#   'Rylea',
#   'Rylee',
#   'Ryleigh',
#   'Ryley',
#   'Rylie',
#   'Rylin',
#   'Rylynn',
#   'Saanvi',
#   'Saba',
#   'Sabina',
#   'Sabine',
#   'Sable',
#   'Sabra',
#   'Sabrena'],
#  ['Sabrina',
#   'Sacha',
#   'Sada',
#   'Sade',
#   'Sadia',
#   'Sadie',
#   'Sadye',
#   'Safa',
#   'Safia',
#   'Safiya',
#   'Sage',
#   'Sahana',
#   'Sahar',
#   'Sahara',
#   'Sahasra',
#   'Saida'],
#  ['Saige',
#   'Sailor',
#   'Saira',
#   'Sakina',
#   'Sakinah',
#   'Sakura',
#   'Salem',
#   'Salena',
#   'Salina',
#   'Sallie',
#   'Sally',
#   'Sallyann',
#   'Sallye',
#   'Salma',
#   'Salome',
#   'Sam'],
#  ['Samanta',
#   'Samantha',
#   'Samara',
#   'Samarah',
#   'Samari',
#   'Samaria',
#   'Samatha',
#   'Samaya',
#   'Sami',
#   'Samia',
#   'Samiah',
#   'Samira',
#   'Samirah',
#   'Samiya',
#   'Samiyah',
#   'Sammantha'],
#  ['Sammi',
#   'Sammie',
#   'Sammy',
#   'Samone',
#   'Samuel',
#   'Samya',
#   'San',
#   'Sana',
#   'Sanaa',
#   'Sanai',
#   'Sanaya',
#   'Sandee',
#   'Sandi',
#   'Sandie',
#   'Sandra',
#   'Sandy'],
#  ['Sania',
#   'Saniah',
#   'Saniya',
#   'Saniyah',
#   'Sanjana',
#   'Sanjuana',
#   'Sanjuanita',
#   'Santa',
#   'Santana',
#   'Santina',
#   'Santos',
#   'Sanvi',
#   'Sanya',
#   'Saoirse',
#   'Saphira',
#   'Sapphire'],
#  ['Sara',
#   'Sarabeth',
#   'Sarah',
#   'Sarahi',
#   'Sarai',
#   'Saralyn',
#   'Saray',
#   'Saraya',
#   'Sarena',
#   'Sari',
#   'Sariah',
#   'Sarina',
#   'Sarita',
#   'Sariya',
#   'Sariyah',
#   'Sarrah'],
#  ['Sascha',
#   'Sasha',
#   'Saskia',
#   'Saundra',
#   'Savana',
#   'Savanah',
#   'Savanna',
#   'Savannah',
#   'Savina',
#   'Sawyer',
#   'Saya',
#   'Saydee',
#   'Saylor',
#   'Sayra',
#   'Sayuri',
#   'Scarlet'],
#  ['Scarlett',
#   'Scarlette',
#   'Schuyler',
#   'Scott',
#   'Scottie',
#   'Scout',
#   'Sean',
#   'Seana',
#   'Seanna',
#   'Season',
#   'Sebrina',
#   'Sedona',
#   'Seema',
#   'Sela',
#   'Selah',
#   'Selena'],
#  ['Selene',
#   'Selina',
#   'Selma',
#   'Semaj',
#   'Sena',
#   'Senaida',
#   'Seneca',
#   'Senora',
#   'September',
#   'Sequoia',
#   'Sera',
#   'Serafina',
#   'Seraphina',
#   'Serena',
#   'Serene',
#   'Serenity'],
#  ['Serina',
#   'Serinity',
#   'Serita',
#   'Shae',
#   'Shaela',
#   'Shaelyn',
#   'Shaelynn',
#   'Shai',
#   'Shaila',
#   'Shaina',
#   'Shaindy',
#   'Shakayla',
#   'Shakera',
#   'Shakeria',
#   'Shakia',
#   'Shakira'],
#  ['Shakita',
#   'Shakyra',
#   'Shala',
#   'Shalanda',
#   'Shalee',
#   'Shalena',
#   'Shalon',
#   'Shalonda',
#   'Shalyn',
#   'Shalynn',
#   'Shamara',
#   'Shamari',
#   'Shameeka',
#   'Shameka',
#   'Shamekia',
#   'Shamia'],
#  ['Shamika',
#   'Shamira',
#   'Shamiya',
#   'Shamya',
#   'Shana',
#   'Shanae',
#   'Shanay',
#   'Shanaya',
#   'Shanda',
#   'Shandi',
#   'Shandra',
#   'Shane',
#   'Shanea',
#   'Shanee',
#   'Shaneka',
#   'Shanel'],
#  ['Shanell',
#   'Shanelle',
#   'Shanequa',
#   'Shani',
#   'Shania',
#   'Shaniah',
#   'Shanice',
#   'Shaniece',
#   'Shanika',
#   'Shaniqua',
#   'Shanique',
#   'Shanise',
#   'Shanita',
#   'Shaniya',
#   'Shaniyah',
#   'Shanna'],
#  ['Shannah',
#   'Shannan',
#   'Shannel',
#   'Shannen',
#   'Shannon',
#   'Shanon',
#   'Shanta',
#   'Shantae',
#   'Shantal',
#   'Shantay',
#   'Shante',
#   'Shantel',
#   'Shantell',
#   'Shantelle',
#   'Shanti',
#   'Shantia'],
#  ['Shanya',
#   'Shaquana',
#   'Shaquita',
#   'Shara',
#   'Sharae',
#   'Sharan',
#   'Shardae',
#   'Sharday',
#   'Sharde',
#   'Sharee',
#   'Shareen',
#   'Sharell',
#   'Sharen',
#   'Sharhonda',
#   'Shari',
#   'Sharice'],
#  ['Sharie',
#   'Sharika',
#   'Sharilyn',
#   'Sharina',
#   'Sharita',
#   'Sharla',
#   'Sharleen',
#   'Sharlene',
#   'Sharlyn',
#   'Sharmaine',
#   'Sharman',
#   'Sharolyn',
#   'Sharon',
#   'Sharonda',
#   'Sharri',
#   'Sharron'],
#  ['Sharyl',
#   'Sharyn',
#   'Shasta',
#   'Shatara',
#   'Shaun',
#   'Shauna',
#   'Shaunda',
#   'Shaundra',
#   'Shaunna',
#   'Shaunta',
#   'Shaunte',
#   'Shavon',
#   'Shavonda',
#   'Shavonne',
#   'Shawana',
#   'Shawanda'],
#  ['Shawanna',
#   'Shawn',
#   'Shawna',
#   'Shawnda',
#   'Shawnee',
#   'Shawnna',
#   'Shawnta',
#   'Shawnte',
#   'Shawntel',
#   'Shay',
#   'Shaye',
#   'Shayla',
#   'Shaylee',
#   'Shaylene',
#   'Shaylin',
#   'Shaylyn'],
#  ['Shaylynn',
#   'Shayna',
#   'Shayne',
#   'Shea',
#   'Shealyn',
#   'Sheba',
#   'Sheena',
#   'Sheila',
#   'Sheilah',
#   'Shekinah',
#   'Shela',
#   'Shelba',
#   'Shelbi',
#   'Shelbie',
#   'Shelby',
#   'Shelia'],
#  ['Shella',
#   'Shelley',
#   'Shelli',
#   'Shellie',
#   'Shelly',
#   'Shelva',
#   'Shemeka',
#   'Shemika',
#   'Shena',
#   'Shenika',
#   'Shenita',
#   'Shenna',
#   'Shera',
#   'Sheree',
#   'Shereen',
#   'Sherell'],
#  ['Sherelle',
#   'Sherese',
#   'Sheri',
#   'Sherice',
#   'Sherida',
#   'Sheridan',
#   'Sherie',
#   'Sherika',
#   'Sherill',
#   'Sherilyn',
#   'Sherise',
#   'Sherita',
#   'Sherlene',
#   'Sherley',
#   'Sherlyn',
#   'Sheron'],
#  ['Sheronda',
#   'Sherree',
#   'Sherrell',
#   'Sherri',
#   'Sherrie',
#   'Sherril',
#   'Sherrill',
#   'Sherron',
#   'Sherry',
#   'Sherryl',
#   'Sheryl',
#   'Sheryle',
#   'Sheryll',
#   'Sheyenne',
#   'Sheyla',
#   'Shiann'],
#  ['Shianne',
#   'Shiela',
#   'Shifra',
#   'Shila',
#   'Shilo',
#   'Shiloh',
#   'Shira',
#   'Shireen',
#   'Shirl',
#   'Shirlee',
#   'Shirleen',
#   'Shirlene',
#   'Shirley',
#   'Shirlie',
#   'Shirly',
#   'Shivani'],
#  ['Shona',
#   'Shonda',
#   'Shondra',
#   'Shonna',
#   'Shonta',
#   'Shonte',
#   'Shoshana',
#   'Shreya',
#   'Shriya',
#   'Shruti',
#   'Shyann',
#   'Shyanna',
#   'Shyanne',
#   'Shyla',
#   'Shylah',
#   'Sia'],
#  ['Siani',
#   'Sianna',
#   'Siara',
#   'Sibyl',
#   'Sicily',
#   'Sidney',
#   'Sidra',
#   'Siena',
#   'Sienna',
#   'Siera',
#   'Sierra',
#   'Sierrah',
#   'Signe',
#   'Sigrid',
#   'Silvana',
#   'Silver'],
#  ['Silvia',
#   'Sima',
#   'Simona',
#   'Simone',
#   'Simran',
#   'Sina',
#   'Sinai',
#   'Sincere',
#   'Sindy',
#   'Sinead',
#   'Siobhan',
#   'Sirena',
#   'Siri',
#   'Siya',
#   'Sky',
#   'Skye'],
#  ['Skyla',
#   'Skylah',
#   'Skylar',
#   'Skylee',
#   'Skyler',
#   'Skylynn',
#   'Skyy',
#   'Sloan',
#   'Sloane',
#   'Sneha',
#   'Socorro',
#   'Sofia',
#   'Sofie',
#   'Sol',
#   'Solana',
#   'Solange'],
#  ['Soledad',
#   'Soleil',
#   'Somer',
#   'Sommer',
#   'Sona',
#   'Sonali',
#   'Sondra',
#   'Sonia',
#   'Sonja',
#   'Sonjia',
#   'Sonora',
#   'Sonya',
#   'Sophia',
#   'Sophie',
#   'Sophronia',
#   'Sora'],
#  ['Soraya',
#   'Sparkle',
#   'Spencer',
#   'Spring',
#   'Stacee',
#   'Stacey',
#   'Staci',
#   'Stacia',
#   'Stacie',
#   'Stacy',
#   'Stanley',
#   'Star',
#   'Starla',
#   'Starlene',
#   'Starlet',
#   'Starr'],
#  ['Stasia',
#   'Stefani',
#   'Stefania',
#   'Stefanie',
#   'Stefany',
#   'Steffani',
#   'Steffanie',
#   'Steffany',
#   'Stella',
#   'Stephaine',
#   'Stephane',
#   'Stephani',
#   'Stephania',
#   'Stephanie',
#   'Stephannie',
#   'Stephany'],
#  ['Stephen',
#   'Stephenie',
#   'Stephine',
#   'Sterling',
#   'Steven',
#   'Stevi',
#   'Stevie',
#   'Storm',
#   'Stormi',
#   'Stormie',
#   'Stormy',
#   'Story',
#   'Suanne',
#   'Sudie',
#   'Sue',
#   'Sueann'],
#  ['Suellen',
#   'Sula',
#   'Sulema',
#   'Sumaya',
#   'Sumer',
#   'Summer',
#   'Sunday',
#   'Sunni',
#   'Sunnie',
#   'Sunny',
#   'Sunshine',
#   'Suri',
#   'Susan',
#   'Susana',
#   'Susann',
#   'Susanna'],
#  ['Susannah',
#   'Susanne',
#   'Susette',
#   'Susie',
#   'Susy',
#   'Sutton',
#   'Suzan',
#   'Suzana',
#   'Suzann',
#   'Suzanna',
#   'Suzannah',
#   'Suzanne',
#   'Suzette',
#   'Suzi',
#   'Suzie',
#   'Suzy'],
#  ['Sybil',
#   'Syble',
#   'Sydnee',
#   'Sydney',
#   'Sydni',
#   'Sydnie',
#   'Syeda',
#   'Sylvia',
#   'Sylvie',
#   'Symone',
#   'Symphony',
#   'Synthia',
#   'Syreeta',
#   'Tabatha',
#   'Tabetha',
#   'Tabitha'],
#  ['Taegan',
#   'Taelor',
#   'Taelyn',
#   'Taelynn',
#   'Tahira',
#   'Tahlia',
#   'Tahnee',
#   'Tai',
#   'Taina',
#   'Taira',
#   'Taisha',
#   'Taja',
#   'Tajuana',
#   'Takara',
#   'Takayla',
#   'Takeisha'],
#  ['Takesha',
#   'Takia',
#   'Takisha',
#   'Takiya',
#   'Takiyah',
#   'Tala',
#   'Talaya',
#   'Taleah',
#   'Tali',
#   'Talia',
#   'Taliah',
#   'Talina',
#   'Talisa',
#   'Talisha',
#   'Talitha',
#   'Taliyah'],
#  ['Tallulah',
#   'Talya',
#   'Tama',
#   'Tamala',
#   'Tamar',
#   'Tamara',
#   'Tamarah',
#   'Tamarra',
#   'Tamatha',
#   'Tamaya',
#   'Tambra',
#   'Tameeka',
#   'Tameika',
#   'Tameka',
#   'Tamekia',
#   'Tamela'],
#  ['Tamera',
#   'Tamesha',
#   'Tami',
#   'Tamia',
#   'Tamica',
#   'Tamie',
#   'Tamika',
#   'Tamiko',
#   'Tamira',
#   'Tamisha',
#   'Tamiya',
#   'Tamiyah',
#   'Tammara',
#   'Tammera',
#   'Tammi',
#   'Tammie'],
#  ['Tammy',
#   'Tamra',
#   'Tamya',
#   'Tamyra',
#   'Tana',
#   'Tanasia',
#   'Tanaya',
#   'Tandra',
#   'Tandy',
#   'Taneisha',
#   'Taneka',
#   'Tanesha',
#   'Taneshia',
#   'Tangela',
#   'Tangie',
#   'Tani'],
#  ['Tania',
#   'Tanika',
#   'Tanis',
#   'Tanisha',
#   'Taniya',
#   'Taniyah',
#   'Tanja',
#   'Tanna',
#   'Tanner',
#   'Tanvi',
#   'Tanya',
#   'Tara',
#   'Tarah',
#   'Taraji',
#   'Taren',
#   'Tari'],
#  ['Tarra',
#   'Tarrah',
#   'Tarsha',
#   'Taryn',
#   'Tasha',
#   'Tashara',
#   'Tashia',
#   'Tashina',
#   'Tasia',
#   'Tasneem',
#   'Tate',
#   'Tatiana',
#   'Tatianna',
#   'Tatiyana',
#   'Tatum',
#   'Tatyana'],
#  ['Tatyanna',
#   'Taunya',
#   'Tausha',
#   'Tavia',
#   'Tawana',
#   'Tawanda',
#   'Tawanna',
#   'Tawni',
#   'Tawny',
#   'Tawnya',
#   'Taya',
#   'Tayah',
#   'Tayla',
#   'Taylar',
#   'Taylee',
#   'Tayler'],
#  ['Taylin',
#   'Taylor',
#   'Taytum',
#   'Tea',
#   'Teagan',
#   'Teah',
#   'Teaira',
#   'Teal',
#   'Teana',
#   'Teanna',
#   'Teara',
#   'Teddi',
#   'Teddy',
#   'Teegan',
#   'Teela',
#   'Teena'],
#  ['Tegan',
#   'Tehya',
#   'Teia',
#   'Teisha',
#   'Telisa',
#   'Telisha',
#   'Temeka',
#   'Temperance',
#   'Tempest',
#   'Tempie',
#   'Temple',
#   'Tena',
#   'Tenesha',
#   'Tenia',
#   'Tenika',
#   'Tenille'],
#  ['Tenisha',
#   'Tenley',
#   'Tennie',
#   'Tennille',
#   'Teodora',
#   'Teonna',
#   'Tequila',
#   'Tera',
#   'Terah',
#   'Tereasa',
#   'Teresa',
#   'Terese',
#   'Teresia',
#   'Teresita',
#   'Teressa',
#   'Teri'],
#  ['Terica',
#   'Terina',
#   'Terisa',
#   'Terra',
#   'Terrell',
#   'Terresa',
#   'Terri',
#   'Terria',
#   'Terrica',
#   'Terrie',
#   'Terry',
#   'Teryn',
#   'Tesa',
#   'Tesha',
#   'Tesia',
#   'Tesla'],
#  ['Tess',
#   'Tessa',
#   'Tessie',
#   'Teya',
#   'Thais',
#   'Thalia',
#   'Thania',
#   'Thao',
#   'Thea',
#   'Theda',
#   'Thelma',
#   'Theo',
#   'Theodora',
#   'Theodosia',
#   'Theola',
#   'Theresa'],
#  ['Therese',
#   'Theresia',
#   'Theressa',
#   'Thersa',
#   'Thomas',
#   'Thomasina',
#   'Thomasine',
#   'Thora',
#   'Thresa',
#   'Thressa',
#   'Thuy',
#   'Thyra',
#   'Tia',
#   'Tiana',
#   'Tianna',
#   'Tiara'],
#  ['Tiare',
#   'Tiarra',
#   'Tiera',
#   'Tierney',
#   'Tierra',
#   'Tiesha',
#   'Tifany',
#   'Tiffaney',
#   'Tiffani',
#   'Tiffanie',
#   'Tiffany',
#   'Tiffiney',
#   'Tiffini',
#   'Tiffiny',
#   'Tiffney',
#   'Tijuana'],
#  ['Tilda',
#   'Tillie',
#   'Tilly',
#   'Timber',
#   'Timeka',
#   'Timia',
#   'Timika',
#   'Timothy',
#   'Tina',
#   'Tinamarie',
#   'Tinisha',
#   'Tinley',
#   'Tinsley',
#   'Tiny',
#   'Tiona',
#   'Tionna'],
#  ['Tira',
#   'Tirzah',
#   'Tisa',
#   'Tisha',
#   'Tiyana',
#   'Tkeyah',
#   'Tobi',
#   'Tobie',
#   'Toby',
#   'Toccara',
#   'Todd',
#   'Toi',
#   'Tomasa',
#   'Tomeka',
#   'Tomi',
#   'Tomika'],
#  ['Tommi',
#   'Tommie',
#   'Tommy',
#   'Tommye',
#   'Tona',
#   'Tonda',
#   'Tonette',
#   'Toni',
#   'Tonia',
#   'Toniann',
#   'Tonie',
#   'Tonisha',
#   'Tonita',
#   'Tonja',
#   'Tony',
#   'Tonya'],
#  ['Torey',
#   'Tori',
#   'Toria',
#   'Torie',
#   'Torrey',
#   'Torri',
#   'Torrie',
#   'Tory',
#   'Tosha',
#   'Toshia',
#   'Tova',
#   'Towanda',
#   'Toya',
#   'Tracee',
#   'Tracey',
#   'Traci'],
#  ['Tracie',
#   'Tracy',
#   'Tracye',
#   'Trang',
#   'Travis',
#   'Treasa',
#   'Treasure',
#   'Treena',
#   'Trena',
#   'Tresa',
#   'Tressa',
#   'Tressie',
#   'Treva',
#   'Tricia',
#   'Trina',
#   'Trinidad'],
#  ['Trinitee',
#   'Triniti',
#   'Trinity',
#   'Trish',
#   'Trisha',
#   'Trista',
#   'Tristan',
#   'Tristen',
#   'Tristin',
#   'Tristyn',
#   'Trixie',
#   'Troy',
#   'Trudi',
#   'Trudie',
#   'Trudy',
#   'Trula'],
#  ['Tuesday',
#   'Tula',
#   'Twana',
#   'Twanda',
#   'Twanna',
#   'Twila',
#   'Twilla',
#   'Twyla',
#   'Tyana',
#   'Tyanna',
#   'Tyasia',
#   'Tyeisha',
#   'Tyesha',
#   'Tyeshia',
#   'Tyisha',
#   'Tyla'],
#  ['Tylar',
#   'Tylee',
#   'Tyler',
#   'Tynesha',
#   'Tynisha',
#   'Tyonna',
#   'Tyra',
#   'Tytiana',
#   'Tytianna',
#   'Tzipora',
#   'Ula',
#   'Uma',
#   'Una',
#   'Unique',
#   'Unknown',
#   'Unnamed'],
#  ['Ursula',
#   'Vada',
#   'Val',
#   'Valarie',
#   'Valda',
#   'Valencia',
#   'Valentina',
#   'Valentine',
#   'Valera',
#   'Valeri',
#   'Valeria',
#   'Valerie',
#   'Valery',
#   'Valinda',
#   'Vallerie',
#   'Vallie'],
#  ['Valorie',
#   'Van',
#   'Vanda',
#   'Vanesa',
#   'Vanessa',
#   'Vanetta',
#   'Vania',
#   'Vanita',
#   'Vanity',
#   'Vanna',
#   'Vannesa',
#   'Vannessa',
#   'Vashti',
#   'Vasiliki',
#   'Vayda',
#   'Veda'],
#  ['Velda',
#   'Velia',
#   'Vella',
#   'Velma',
#   'Velta',
#   'Velva',
#   'Velvet',
#   'Vena',
#   'Venessa',
#   'Venetia',
#   'Venetta',
#   'Venice',
#   'Venita',
#   'Vennie',
#   'Venus',
#   'Veola'],
#  ['Vera',
#   'Verda',
#   'Verdell',
#   'Verdie',
#   'Verena',
#   'Verenice',
#   'Vergie',
#   'Verity',
#   'Verla',
#   'Verlene',
#   'Verlie',
#   'Verline',
#   'Verna',
#   'Vernell',
#   'Vernelle',
#   'Vernetta'],
#  ['Vernette',
#   'Vernia',
#   'Vernice',
#   'Vernie',
#   'Vernita',
#   'Vernon',
#   'Verona',
#   'Veronica',
#   'Veronika',
#   'Veronique',
#   'Versie',
#   'Verta',
#   'Vertie',
#   'Vesta',
#   'Veta',
#   'Veva'],
#  ['Vianca',
#   'Vianey',
#   'Vianna',
#   'Vianney',
#   'Vicenta',
#   'Vickey',
#   'Vicki',
#   'Vickie',
#   'Vicky',
#   'Victor',
#   'Victoria',
#   'Victory',
#   'Vida',
#   'Vienna',
#   'Viki',
#   'Vikki'],
#  ['Viktoria',
#   'Vilma',
#   'Vina',
#   'Vincent',
#   'Vincenza',
#   'Vinita',
#   'Vinnie',
#   'Viola',
#   'Violet',
#   'Violeta',
#   'Violetta',
#   'Violette',
#   'Vira',
#   'Virgia',
#   'Virgie',
#   'Virgil'],
#  ['Virgina',
#   'Virginia',
#   'Viridiana',
#   'Vita',
#   'Vittoria',
#   'Viva',
#   'Vivian',
#   'Viviana',
#   'Vivianna',
#   'Vivianne',
#   'Vivien',
#   'Vivienne',
#   'Voncile',
#   'Vonda',
#   'Vonna',
#   'Vonnie'],
#  ['Vy',
#   'Walter',
#   'Wanda',
#   'Waneta',
#   'Wanetta',
#   'Wanita',
#   'Wava',
#   'Waverly',
#   'Wayne',
#   'Wednesday',
#   'Wenda',
#   'Wende',
#   'Wendi',
#   'Wendie',
#   'Wendolyn',
#   'Wendy'],
#  ['Wenona',
#   'Wesley',
#   'Whitley',
#   'Whitney',
#   'Whittney',
#   'Wilda',
#   'Wilhelmenia',
#   'Wilhelmina',
#   'Willa',
#   'Willena',
#   'Willene',
#   'Willetta',
#   'Willette',
#   'Willia',
#   'William',
#   'Willie'],
#  ['Willodean',
#   'Willow',
#   'Wilma',
#   'Windy',
#   'Winifred',
#   'Winnie',
#   'Winnifred',
#   'Winona',
#   'Winter',
#   'Wonda',
#   'Wren',
#   'Wynell',
#   'Wynne',
#   'Wynona',
#   'Wynter',
#   'Xena'],
#  ['Xenia',
#   'Ximena',
#   'Xiomara',
#   'Xitlali',
#   'Xitlaly',
#   'Xochilt',
#   'Xochitl',
#   'Yadhira',
#   'Yadira',
#   'Yael',
#   'Yahaira',
#   'Yajaira',
#   'Yalonda',
#   'Yamile',
#   'Yamilet',
#   'Yamileth'],
#  ['Yamilex',
#   'Yana',
#   'Yaneli',
#   'Yanely',
#   'Yanet',
#   'Yanira',
#   'Yaquelin',
#   'Yara',
#   'Yareli',
#   'Yarely',
#   'Yaretzi',
#   'Yaretzy',
#   'Yaritza',
#   'Yashica',
#   'Yasmeen',
#   'Yasmin'],
#  ['Yasmina',
#   'Yasmine',
#   'Yazmin',
#   'Yazmine',
#   'Yecenia',
#   'Yehudis',
#   'Yelena',
#   'Yenifer',
#   'Yesenia',
#   'Yesica',
#   'Yessenia',
#   'Yessica',
#   'Yetta',
#   'Yitty',
#   'Yoana',
#   'Yocelin'],
#  ['Yocheved',
#   'Yohana',
#   'Yolanda',
#   'Yolande',
#   'Yolonda',
#   'Yoselin',
#   'Yoselyn',
#   'Yoshiko',
#   'Ysabel',
#   'Ysabella',
#   'Yulanda',
#   'Yuliana',
#   'Yulianna',
#   'Yulisa',
#   'Yulissa',
#   'Yuna'],
#  ['Yuri',
#   'Yuridia',
#   'Yusra',
#   'Yvette',
#   'Yvonna',
#   'Yvonne',
#   'Zabrina',
#   'Zachary',
#   'Zada',
#   'Zadie',
#   'Zahara',
#   'Zahra',
#   'Zaida',
#   'Zaina',
#   'Zainab',
#   'Zaira'],
#  ['Zaire',
#   'Zakia',
#   'Zakiya',
#   'Zakiyah',
#   'Zakiyyah',
#   'Zana',
#   'Zandra',
#   'Zaniah',
#   'Zaniya',
#   'Zaniyah',
#   'Zara',
#   'Zarah',
#   'Zaria',
#   'Zariah',
#   'Zarina',
#   'Zariya'],
#  ['Zariyah',
#   'Zaya',
#   'Zayda',
#   'Zayla',
#   'Zaylee',
#   'Zayna',
#   'Zaynab',
#   'Zayra',
#   'Zeinab',
#   'Zelda',
#   'Zelia',
#   'Zella',
#   'Zelma',
#   'Zena',
#   'Zenaida',
#   'Zendaya'],
#  ['Zenia',
#   'Zenobia',
#   'Zeta',
#   'Zetta',
#   'Zettie',
#   'Zhane',
#   'Zia',
#   'Zina',
#   'Zinnia',
#   'Zion',
#   'Zipporah',
#   'Zita',
#   'Ziva',
#   'Zoe',
#   'Zoee',
#   'Zoey'],
#  ['Zofia',
#   'Zoie',
#   'Zoila',
#   'Zola',
#   'Zona',
#   'Zora',
#   'Zoraida',
#   'Zoya',
#   'Zula',
#   'Zuleika',
#   'Zulema',
#   'Zuleyka',
#   'Zulma',
#   'Zuri']]

# %% [markdown]
# If you still have lists pending to be generated, you can uncomment and run the following cell, which will check which are the pending lists and run the generation only for them.

# %%
# # Run generation for remaining lists
# async def produce_names_json_async():
#     # List of lists of baby names to be computed (16 names each in order not to hit Gemini's output context limits)
#     remaining_list = process_remaining_girl_names('../data/generated/reviewed/cleaned', all_girl_names_list)

#     results = await process_all_lists(remaining_list)
#     print(f"All lists processed successfully. Results: {results}")

# await produce_names_json_async()

# %% [markdown]
# ## Create Master JSON

# %% [markdown]
# The following cell will create a master JSON file with all JSONs inside a folder, merging files by starting letter -e.g. all files starting with a "G" will be merged into the `G_master.json` (girls master) file-.

# %%
merge_json_files_by_letter('../data/generated/cleaned')

# %% [markdown]
# ## Enhance master JSON
#
# To allow users to make more granular name findings (and therefore make Gemini's search more optimal) we will enhance the data by adding attributes based on keywords for each name (e.g. if a name's meaning or additional info has the words `God`, `faith`, `religion` or `angel`, it'll be given the attribute `Religious`). All attributes are defined in the `add_attributes_field` function inside `utils.py`.

# %%
# Enrich the master JSON with attributes

# Example usage
master_json_path = '../data/generated/cleaned/G_master_initial.json'
output_json_name = 'G_master_attr.json'
add_attributes_field(master_json_path, output_json_name)

# Print example of the modified JSON (specific fields)
output_json_path = os.path.join(os.path.dirname(master_json_path), output_json_name)
with open(output_json_path, 'r') as file:
    modified_data = json.load(file)
    
    # Get the first name and its details
    first_name, first_details = next(iter(modified_data.items()))
    
    print(f"Name: {first_name}")
    print(f"Meaning: {first_details.get('meaning', 'N/A')}")
    print(f"Other Info: {first_details.get('other_info', 'N/A')}")
    print(f"Attributes: {first_details.get('attributes', 'N/A')}")
# Out:
# Name: Abbie
# Meaning: God is my father
# Other Info: Abbie is a diminutive of Abigail. It has been in use since the Middle Ages and has a sweet and simple sound. It is a good choice for parents who are looking for a name that is both classic and modern.
# Attributes: ['Religious', 'Classic', 'Modern']

# %% [markdown]
# ## Clean Master JSON file
#
# ### Remove duplicated info
#
# Some likely liked, famous, and variations elements in the master array are duplicated, let's remove them.

# %%
input_json_path = '../data/generated/cleaned/G_master_attr.json'
output_json_path = '../data/generated/cleaned/G_master_attr_no_dupl.json'
remove_duplicates_from_json(input_json_path, output_json_path)

# %% [markdown]
# Let's also remove whole names that may be duplicate in the master JSON (in case we accidentally run the generation more than once for the same list).

# %%
# Remove duplicates and get the deleted names
unique_data, deleted_names = remove_duplicate_names('../data/generated/cleaned/G_master_attr_no_dupl.json')

# Print the deleted names and their counts
for name, count in deleted_names.items():
    print(f"Deleted {count} instances of the name '{name}'")

# Save the unique data back to the same JSON file
with open('../data/generated/cleaned/G_master_attr_no_dupl.json', 'w') as file:
    json.dump(unique_data, file, indent=4, ensure_ascii=False)

# %% [markdown]
# ## Spot boy/man names and erase them

# %% [markdown]
# Now let's compare these names with a list of Masculine names we've got from Kaggle, to see which of these list are typically masculine, which feminine, and which gender-neutral. We will only leave feminine and gender-neutral names.

# %%
# Load the CSV, filter for girl names with a count higher than 1000
df = pd.read_csv("../data/raw/gender_name.csv", usecols=["Name", "Gender", "Count"])

filtered_df_girl = df.query("Gender == 'F' and Count > 1000")
all_girl_names_list = filtered_df_girl["Name"].dropna().tolist()
all_girl_names_list.sort()

#  Filter for boy names with a count higher than 1000
filtered_df_boy = df.query("Gender == 'M' and Count > 1000")
all_boy_names_list = filtered_df_boy["Name"].dropna().tolist()
all_boy_names_list.sort()

print(all_boy_names_list)
# Out:
# ['Aaden', 'Aakash', 'Aamir', 'Aarav', 'Aaron', 'Aarron', 'Aarush', 'Aaryan', 'Aayan', 'Aayden', 'Aayush', 'Abbas', 'Abbott', 'Abdallah', 'Abdiel', 'Abdirahman', 'Abdul', 'Abdulaziz', 'Abdullah', 'Abdullahi', 'Abdulrahman', 'Abe', 'Abel', 'Abelardo', 'Abhinav', 'Abiel', 'Abimael', 'Abner', 'Abraham', 'Abram', 'Abran', 'Ace', 'Achilles', 'Acie', 'Adair', 'Adalberto', 'Adam', 'Adams', 'Adan', 'Adarius', 'Addison', 'Adel', 'Adelbert', 'Adell', 'Adem', 'Aden', 'Adian', 'Adiel', 'Adil', 'Adin', 'Aditya', 'Adler', 'Adnan', 'Adolf', 'Adolfo', 'Adolph', 'Adolphus', 'Adonis', 'Adrain', 'Adrian', 'Adriano', 'Adriel', 'Adrien', 'Adron', 'Adryan', 'Adyn', 'Aedan', 'Aeden', 'Agapito', 'Agustin', 'Aharon', 'Ahmad', 'Ahmed', 'Ahmir', 'Aidan', 'Aiden', 'Aidyn', 'Aj', 'Ajani', 'Ajay', 'Akash', 'Akeem', 'Akhil', 'Akil', 'Akira', 'Akiva', 'Akram', 'Aksel', 'Akshay', 'Al', 'Alain', 'Alan', 'Alaric', 'Alastair', 'Albert', 'Alberto', 'Albin', 'Albino', 'Aldair', 'Alden', 'Aldo', 'Aldon', 'Alec', 'Aleck', 'Aleczander', 'Alejandro', 'Alek', 'Aleksandar', 'Aleksander', 'Aleksandr', 'Alen', 'Alessandro', 'Alessio', 'Alex', 'Alexander', 'Alexandre', 'Alexandro', 'Alexandros', 'Alexavier', 'Alexei', 'Alexi', 'Alexis', 'Alexsander', 'Alexzander', 'Alf', 'Alfonse', 'Alfonso', 'Alfonza', 'Alfonzo', 'Alford', 'Alfred', 'Alfredo', 'Algernon', 'Algie', 'Ali', 'Alice', 'Alijah', 'Alistair', 'Alister', 'Allan', 'Allen', 'Allie', 'Allison', 'Allyn', 'Alma', 'Almon', 'Alois', 'Alon', 'Alonso', 'Alonza', 'Alonzo', 'Aloysius', 'Alpha', 'Alphonse', 'Alphonso', 'Alphonzo', 'Alston', 'Alton', 'Alva', 'Alvah', 'Alvan', 'Alvaro', 'Alvie', 'Alvin', 'Alvino', 'Alvis', 'Amadeo', 'Amadeus', 'Amado', 'Amador', 'Aman', 'Amanda', 'Amando', 'Amani', 'Amar', 'Amare', 'Amari', 'Amarion', 'Amauri', 'Amaury', 'Amber', 'Ambrose', 'Ameen', 'Ameer', 'Amer', 'Americo', 'Ames', 'Amiel', 'Amin', 'Amir', 'Amit', 'Ammar', 'Ammon', 'Amon', 'Amos', 'Amy', 'An', 'Anakin', 'Anand', 'Anas', 'Anastacio', 'Anastasios', 'Ancil', 'Ander', 'Anders', 'Anderson', 'Andra', 'Andrae', 'Andre', 'Andrea', 'Andreas', 'Andrei', 'Andres', 'Andrew', 'Andrey', 'Andrez', 'Andru', 'Andy', 'Anfernee', 'Angel', 'Angela', 'Angelo', 'Angus', 'Anibal', 'Anil', 'Anirudh', 'Anish', 'Anjel', 'Ann', 'Anna', 'Annie', 'Ansel', 'Anselmo', 'Ansh', 'Anson', 'Anthoney', 'Anthony', 'Antione', 'Antoine', 'Anton', 'Antone', 'Antoni', 'Antonia', 'Antonino', 'Antonio', 'Antony', 'Antron', 'Antuan', 'Antwain', 'Antwan', 'Antwaun', 'Antwoine', 'Antwon', 'Antwone', 'Anwar', 'Apolinar', 'Apollo', 'Apolonio', 'Ara', 'Aram', 'Aramis', 'Arcadio', 'Arch', 'Archer', 'Archibald', 'Archie', 'Ardell', 'Arden', 'Ardis', 'Aren', 'Ares', 'Arham', 'Ari', 'Arian', 'Aric', 'Arie', 'Ariel', 'Aries', 'Arik', 'Arin', 'Arion', 'Aris', 'Arjun', 'Arlan', 'Arland', 'Arlen', 'Arley', 'Arlie', 'Arlin', 'Arlington', 'Arlis', 'Arlo', 'Arlon', 'Arlyn', 'Armaan', 'Arman', 'Armand', 'Armando', 'Armani', 'Armen', 'Armin', 'Armon', 'Armond', 'Armondo', 'Arnaldo', 'Arnav', 'Arne', 'Arnell', 'Arnett', 'Arnie', 'Arno', 'Arnold', 'Arnoldo', 'Arnulfo', 'Aron', 'Arron', 'Arsenio', 'Art', 'Artemio', 'Arther', 'Arthur', 'Artie', 'Artis', 'Arturo', 'Arun', 'Arvel', 'Arvid', 'Arvil', 'Arvin', 'Arya', 'Aryan', 'Aryeh', 'Asa', 'Asad', 'Asael', 'Ash', 'Ashby', 'Asher', 'Ashley', 'Ashten', 'Ashtin', 'Ashton', 'Ashtyn', 'Ashwin', 'Asim', 'Aspen', 'Aston', 'Athan', 'Athanasios', 'Atlas', 'Atlee', 'Atreyu', 'Atticus', 'Attilio', 'Aubrey', 'Aubry', 'Auden', 'Audie', 'Audrey', 'August', 'Augusta', 'Augustin', 'Augustine', 'Augusto', 'Augustus', 'Aundre', 'Aurelio', 'Austen', 'Austin', 'Auston', 'Austyn', 'Auther', 'Author', 'Authur', 'Autry', 'Avelino', 'Aven', 'Avery', 'Avi', 'Avian', 'Avion', 'Avon', 'Avraham', 'Avrohom', 'Axel', 'Axl', 'Axton', 'Ayaan', 'Ayan', 'Aydan', 'Ayden', 'Aydin', 'Ayman', 'Ayub', 'Ayush', 'Azael', 'Azariah', 'Aziz', 'Azriel', 'Baby', 'Babyboy', 'Bailey', 'Bakari', 'Baker', 'Baldemar', 'Baldomero', 'Ballard', 'Baltazar', 'Banks', 'Barbara', 'Barnett', 'Barney' ...

# %%
girl_names_set = set(all_girl_names_list)
boy_names_set = set(all_boy_names_list)
gender_neutral_names_set = girl_names_set.intersection(boy_names_set)

gender_neutral_names_list = list(gender_neutral_names_set)
print(gender_neutral_names_list)
# Out:
# ['Deborah', 'Linden', 'Ellie', 'Amani', 'Darrell', 'Jaydin', 'Jamey', 'Laine', 'Marvin', 'Timothy', 'Yuri', 'Erie', 'Johnny', 'Cadence', 'Michel', 'Juan', 'Arin', 'Jaylin', 'Shanon', 'Lois', 'Donnie', 'Mark', 'Brittany', 'Kori', 'Kamari', 'Karol', 'Shirley', 'Heather', 'Tristin', 'Holly', 'Ramsey', 'Val', 'Zion', 'Jennifer', 'Royal', 'Tory', 'Mary', 'Carmen', 'Marshall', 'Artie', 'Jacqueline', 'Floyd', 'Sky', 'Quinn', 'Howard', 'Devyn', 'Emily', 'Micaiah', 'Amari', 'Frances', 'Betty', 'Korey', 'Jewell', 'Kaiden', 'Melvin', 'Sarah', 'Jean', 'Dee', 'Braylin', 'Christopher', 'Raleigh', 'Richard', 'Lane', 'Lloyd', 'Ozell', 'Norman', 'Gail', 'Kathryn', 'Jensen', 'Blair', 'Channing', 'Cris', 'Juanita', 'Connor', 'Joe', 'Ora', 'Jordon', 'Jackie', 'Kelby', 'Karter', 'Winifred', 'Hudson', 'Noel', 'Albert', 'Diane', 'Gary', 'Dominique', 'Sheridan', 'Meredith', 'Emory', 'Rylan', 'Stephanie', 'Carmel', 'Rian', 'Archie', 'Lashawn', 'Micha', 'Carolyn', 'Audie', 'Brighton', 'Callan', 'Deven', 'Joey', 'Jalen', 'Jon', 'Marion', 'Azariah', 'Carlos', 'Jadyn', 'Louise', 'Yael', 'Edward', 'Elliott', 'Carroll', 'Ashtin', 'Corey', 'Kim', 'Eva', 'Ellery', 'George', 'Jaidyn', 'Carrie', 'Laken', 'Reilly', 'Rory', 'Elmer', 'Joshua', 'London', 'Shaun', 'Rylee', 'Tracy', 'Berlin', 'Kai', 'Oakley', 'Kristin', 'Bernie', 'Ossie', 'Semaj', 'Kimani', 'Rosa', 'Troy', 'Maxie', 'Blakely', 'Dorris', 'Brooklyn', 'Kiran', 'Sloan', 'Dawn', 'Tanner', 'Nancy', 'Austyn', 'Cristian', 'Phillip', 'Grace', 'Henry', 'Storm', 'Cruz', 'Ricky', 'Rio', 'Keith', 'Gayle', 'Marty', 'Wendy', 'Hayden', 'Virgil', 'Remi', 'Briley', 'Mika', 'Billy', 'Russell', 'Rickie', 'Louis', 'Terrell', 'Dru', 'Merritt', 'Ruth', 'Adrien', 'Marilyn', 'Nicole', 'Marvis', 'Wesley', 'Brett', 'Kasey', 'Marcell', 'Luca', 'Evan', 'Julia', 'Devan', 'Brandon', 'Julian', 'Dusty', 'Mildred', 'Hollis', 'Steven', 'Aubry', 'Lee', 'Karsyn', 'Maddox', 'Harry', 'Infant', 'Cheryl', 'Jere', 'Linda', 'Nikita', 'Kendell', 'Tate', 'Glenn', 'Jeffrey', 'Victor', 'Delaney', 'Pat', 'Finley', 'Avery', 'Tristen', 'Henley', 'Lorenza', 'Annie', 'Carsyn', 'Waverly', 'Jordan', 'Arian', 'Kenley', 'Jewel', 'Eunice', 'Raymond', 'Courtney', 'Pamela', 'Shane', 'Brennan', 'Jodie', 'Mikel', 'Marie', 'James', 'Tristan', 'Janice', 'Doris', 'Shai', 'Joseph', 'Carman', 'Peyton', 'Edwin', 'Gianni', 'Jacob', 'Mason', 'Baby', 'Unknown', 'Karen', 'Thelma', 'Ryley', 'Leroy', 'Kolby', 'Ezra', 'Laurie', 'Dominic', 'Ernest', 'Darnell', 'Nakia', 'Armani', 'Jody', 'Bernice', 'Sasha', 'Arlyn', 'Ray', 'Bradley', 'Gerald', 'Marian', 'Jerry', 'Jules', 'Kylin', 'Ricki', 'Trinity', 'Christan', 'Teegan', 'Karsen', 'Ann', 'Clifford', 'June', 'Adair', 'Kimberly', 'Cooper', 'Chris', 'Alfred', 'Lindy', 'Bentley', 'Beryl', 'Kennedy', 'Catherine', 'Payton', 'Shelby', 'Dell', 'Sandy', 'Charles', 'Tammy', 'Arie', 'Ira', 'Lynn', 'Jason', 'Nicola', 'Tayler', 'Alexi', 'Ocean', 'Garnet', 'Kaidyn', 'Kerry', 'Vernon', 'Briar', 'Kaylen', 'Lavelle', 'Rose', 'Antonio', 'Hazel', 'Kodie', 'Bennie', 'Camdyn', 'Kayden', 'Lonie', 'Michal', 'Andre', 'Jimmy', 'Marvel', 'Nicky', 'Odell', 'Antonia', 'Kellen', 'Jermaine', 'Torrey', 'Parker', 'Asa', 'Reese', 'Keaton', 'Deane', 'Arlie', 'Lisa', 'Mckinley', 'Brady', 'Rachel', 'Alan', 'Lillian', 'Christin', 'Drew', 'Kay', 'Aubrey', 'Harlow', 'Renee', 'Kenya', 'Miguel', 'Jessi', 'Arden', 'Sincere', 'Jessie', 'Remy', 'Andrew', 'Karson', 'Kadence', 'Terry', 'Ashtyn', 'Wayne', 'Kieran', 'Jose', 'Reagan', 'Divine', 'John', 'Montana', 'Cheyenne', 'Christian', 'Kyle', 'Dylan', 'Kit', 'Rowen', 'Willie', 'Tyler', 'Kalen', 'Kristian', 'Joan', 'Robert', 'Ethel', 'Sol', 'Jaycee', 'Bailey', 'Hadley', 'Dorian', 'Milan', 'Justine', 'Paxton', 'Britt', 'Shelly', 'Finnley', 'Clara', 'Vernell', 'Baylor', 'Skye', 'Nova', 'Kelsey', 'Christy', 'Darby', 'An', 'Ronald', 'Robin', 'Charly', 'Sam', 'Allen', 'Ronnie', 'Kory', 'Ruby', 'Tori', 'Ashton', 'Nathan', 'Fred', 'Tiffany', 'Teddy', 'Gerry', 'Victoria', 'Cory', 'Kacey', 'Freddie', 'Beverly', 'Guadalupe', 'Tai', ...

# %% [markdown]
# After human verification, we saw some theoretically gender-neutral names that don't seem right. Let's manually create a list of those and remove them from the gender-neutral names list:

# %%
to_remove = ['Peter', 'Tommie', 'Jennifer', 'Delma', 'Nikita', 'Fred', 'Robert', 'Victor', 'David', 'Maria', 'Jose', 'Norma', 'Sasha', 'Amy', 'Teresa', 'William', 'Scott', 'Evelyn', 'Sarah', 'Lindsay', 'Freddie', 'Allison', 'Sandy', 'Carmen', 'Lindsey', 'Thelma', 'Amanda', 'Claire', 'Katherine', 'Laura', 'Vincent', 'Anna', 'Ashley', 'Adrien', 'Carl', 'Donald', 'Erica', 'Eric', 'Andrea', 'Martin', 'Edward', 'Mitchell', 'Isabel', 'Noa', 'Leo', 'Michael', 'Roy', 'Page', 'Samuel', 'Marie', 'Charles', 'Gerald', 'Phillip', 'Dana', 'Cristian', 'Leon', 'Angel', 'Timothy', 'Mickey', 'Edwin', 'Joe', 'Hillary', 'Theo', 'Larry', 'Stacey', 'Steven', 'Kendal', 'Albert', 'Clara', 'Sara', 'Helen', 'Bobby', 'Gabriel', 'Harry', 'Karen', 'Elisabeth', 'Michele', 'Jesus', 'Jessie','Jonnie', 'Johnie', 'Brittany', 'Juanita', 'Rickie', 'Don', 'Gregory', 'Emily', 'Frankie', 'Augusta', 'Carol', 'Lisa', 'Cynthia', 'Gloria', 'Troy', 'Oscar', 'Thomas', 'Donna', 'Rachel', 'Rebecca', 'Judith', 'Betty', 'Guadalupe', 'Brenda', 'Pamela', 'Julie', 'Virginia', 'Patricia', 'Ruth', 'Daniel', 'Leonard', 'Frank', 'Justin', 'Mario', 'Jonathan', 'Johnnie', 'Paige', 'Seneca', 'Deborah', 'Irene', 'Mikel', 'Rosario', 'Paul', 'Andrew', 'Kendall', 'Bobbie', 'Robbie', 'Martha', 'Luca', 'Israel', 'Monica', 'Eva', 'Antonia', 'Diana', 'Richard', 'Isa', 'Melissa', 'Dolores', 'Miguel', 'Raymond', 'Johnny', 'Frederick', 'Raymond', 'Linda', 'Angela', 'Joseph', 'Rosa', 'Tiffany', 'Diane', 'Carlos', 'Connor', 'James', 'Emma', 'Julian' ,'Alfred', 'Annie', 'Philip', 'Manuel', 'Rose', 'Ernest', 'Santos', 'Stacy', 'Samantha', 'Susan', 'Dennis', 'Lorenza', 'Sandra', 'Adrian', 'Julia', 'Kevin', 'Michelle', 'Jack', 'Jessica', 'George', 'Nicholas', 'Aubrey', 'Juan', 'Lauren', 'Carolyn', 'Jerome', 'Victoria', 'Theresa', 'Darrell', 'Vanessa']

# Remove visually inspected non-gender-neutral names:
for name in to_remove:
    if name in gender_neutral_names_list:
        gender_neutral_names_list.remove(name)

gender_neutral_names_set = set(gender_neutral_names_list)

print(gender_neutral_names_list)
# Out:
# ['Linden', 'Ellie', 'Amani', 'Jaydin', 'Jamey', 'Laine', 'Marvin', 'Yuri', 'Erie', 'Cadence', 'Michel', 'Arin', 'Jaylin', 'Shanon', 'Lois', 'Donnie', 'Mark', 'Kori', 'Kamari', 'Karol', 'Shirley', 'Heather', 'Tristin', 'Holly', 'Ramsey', 'Val', 'Zion', 'Royal', 'Tory', 'Mary', 'Marshall', 'Artie', 'Jacqueline', 'Floyd', 'Sky', 'Quinn', 'Howard', 'Devyn', 'Micaiah', 'Amari', 'Frances', 'Korey', 'Jewell', 'Kaiden', 'Melvin', 'Jean', 'Dee', 'Braylin', 'Christopher', 'Raleigh', 'Lane', 'Lloyd', 'Ozell', 'Norman', 'Gail', 'Kathryn', 'Jensen', 'Blair', 'Channing', 'Cris', 'Ora', 'Jordon', 'Jackie', 'Kelby', 'Karter', 'Winifred', 'Hudson', 'Noel', 'Gary', 'Dominique', 'Sheridan', 'Meredith', 'Emory', 'Rylan', 'Stephanie', 'Carmel', 'Rian', 'Archie', 'Lashawn', 'Micha', 'Audie', 'Brighton', 'Callan', 'Deven', 'Joey', 'Jalen', 'Jon', 'Marion', 'Azariah', 'Jadyn', 'Louise', 'Yael', 'Elliott', 'Carroll', 'Ashtin', 'Corey', 'Kim', 'Ellery', 'Jaidyn', 'Carrie', 'Laken', 'Reilly', 'Rory', 'Elmer', 'Joshua', 'London', 'Shaun', 'Rylee', 'Tracy', 'Berlin', 'Kai', 'Oakley', 'Kristin', 'Bernie', 'Ossie', 'Semaj', 'Kimani', 'Maxie', 'Blakely', 'Dorris', 'Brooklyn', 'Kiran', 'Sloan', 'Dawn', 'Tanner', 'Nancy', 'Austyn', 'Grace', 'Henry', 'Storm', 'Cruz', 'Ricky', 'Rio', 'Keith', 'Gayle', 'Marty', 'Wendy', 'Hayden', 'Virgil', 'Remi', 'Briley', 'Mika', 'Billy', 'Russell', 'Louis', 'Terrell', 'Dru', 'Merritt', 'Marilyn', 'Nicole', 'Marvis', 'Wesley', 'Brett', 'Kasey', 'Marcell', 'Evan', 'Devan', 'Brandon', 'Dusty', 'Mildred', 'Hollis', 'Aubry', 'Lee', 'Karsyn', 'Maddox', 'Infant', 'Cheryl', 'Jere', 'Kendell', 'Tate', 'Glenn', 'Jeffrey', 'Delaney', 'Pat', 'Finley', 'Avery', 'Tristen', 'Henley', 'Carsyn', 'Waverly', 'Jordan', 'Arian', 'Kenley', 'Jewel', 'Eunice', 'Courtney', 'Shane', 'Brennan', 'Jodie', 'Tristan', 'Janice', 'Doris', 'Shai', 'Carman', 'Peyton', 'Gianni', 'Jacob', 'Mason', 'Baby', 'Unknown', 'Ryley', 'Leroy', 'Kolby', 'Ezra', 'Laurie', 'Dominic', 'Darnell', 'Nakia', 'Armani', 'Jody', 'Bernice', 'Arlyn', 'Ray', 'Bradley', 'Marian', 'Jerry', 'Jules', 'Kylin', 'Ricki', 'Trinity', 'Christan', 'Teegan', 'Karsen', 'Ann', 'Clifford', 'June', 'Adair', 'Kimberly', 'Cooper', 'Chris', 'Lindy', 'Bentley', 'Beryl', 'Kennedy', 'Catherine', 'Payton', 'Shelby', 'Dell', 'Tammy', 'Arie', 'Ira', 'Lynn', 'Jason', 'Nicola', 'Tayler', 'Alexi', 'Ocean', 'Garnet', 'Kaidyn', 'Kerry', 'Vernon', 'Briar', 'Kaylen', 'Lavelle', 'Antonio', 'Hazel', 'Kodie', 'Bennie', 'Camdyn', 'Kayden', 'Lonie', 'Michal', 'Andre', 'Jimmy', 'Marvel', 'Nicky', 'Odell', 'Kellen', 'Jermaine', 'Torrey', 'Parker', 'Asa', 'Reese', 'Keaton', 'Deane', 'Arlie', 'Mckinley', 'Brady', 'Alan', 'Lillian', 'Christin', 'Drew', 'Kay', 'Harlow', 'Renee', 'Kenya', 'Jessi', 'Arden', 'Sincere', 'Remy', 'Karson', 'Kadence', 'Terry', 'Ashtyn', 'Wayne', 'Kieran', 'Reagan', 'Divine', 'John', 'Montana', 'Cheyenne', 'Christian', 'Kyle', 'Dylan', 'Kit', 'Rowen', 'Willie', 'Tyler', 'Kalen', 'Kristian', 'Joan', 'Ethel', 'Sol', 'Jaycee', 'Bailey', 'Hadley', 'Dorian', 'Milan', 'Justine', 'Paxton', 'Britt', 'Shelly', 'Finnley', 'Vernell', 'Baylor', 'Skye', 'Nova', 'Kelsey', 'Christy', 'Darby', 'An', 'Ronald', 'Robin', 'Charly', 'Sam', 'Allen', 'Ronnie', 'Kory', 'Ruby', 'Tori', 'Ashton', 'Nathan', 'Teddy', 'Gerry', 'Cory', 'Kacey', 'Beverly', 'Tai', 'Bryan', 'Santana', 'Elisha', 'Cassidy', 'Darryl', 'Addison', 'Unnamed', 'Kelly', 'Sterling', 'Jaye', 'Marlowe', 'Jai', 'Sharon', 'Harley', 'Francis', 'Lakota', 'Jeremy', 'Carlie', 'Luis', 'Eddie', 'Kameron', 'Rhyan', 'Sammie', 'Micheal', 'Jude', 'Otha', 'Vernie', 'Barbara', 'Mikah', 'Shay', 'Merrill', 'Robyn', 'Keegan', 'Cary', 'Mackenzie', 'Odie', 'Nathaniel', 'Scottie', 'Lou', 'Calvin', 'Marcus', 'Corrie', 'Shelley', 'Colby', 'Ralph', 'Charlie', 'Skyler', 'Britton', 'Stephen', 'Verdell', 'Jalyn', 'Dakotah', 'Camille', 'Kiley', 'Todd', 'Harper', 'Golden', 'Elijah', 'Kristen', 'Marlin', 'Shea', 'Loren', 'Ellis', 'Jae', 'Lawrence', 'Valentine', 'Kadyn', 'Randy', 'Brooke', 'A ...

# %% [markdown]
# And let's now keep only girls and gender-neutral names:

# %%
# Remove all names in all_boys_names_list from all_girls_names_list and add back gender-neutral names
final_girls_names_set = (girl_names_set - boy_names_set).union(gender_neutral_names_set)

# Convert the set back to a list
final_girls_names_list = list(final_girls_names_set)

# %%
# Remove all boy-only names from Girls Master JSON
input_path = '../data/generated/cleaned/G_master_attr_no_dupl.json'
output_path = input_path

keep_names_in_json(input_path, final_girls_names_list, output_path)

# %% [markdown]
# *Et voilà!* We have our Girl names synthetic dataset ready 👶🏽
#
# Let's now uploaded to GCS, where our main process (Cloud Function) will pick it up from:

# %%
source_file_name = '../data/generated/cleaned/G_master_attr_no_dupl.json'
destination_blob_name = 'G_master_test.json'

upload_to_gcs(source_file_name, destination_blob_name)
# Out:
# File ../data/generated/cleaned/G_master_attr_no_dupl.json uploaded to G_master_test.json.
